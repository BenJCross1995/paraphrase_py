# %%
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# Define the SCOPES. If modifying it,
# delete the token.pickle file.
SCOPES = ['https://www.googleapis.com/auth/drive']


def get_credentials():
    """Get user credentials or create new ones if needed."""
    creds = None

    # Check if file token.pickle exists
    if os.path.exists('token.pickle'):
        # Read the token from the file
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)

    # If no valid credentials are available, request the user to log in.
    if not creds or not creds.valid:
        # If token is expired, refresh it, else, request a new one.
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                '../google_credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)

        # Save the access token in token.pickle file for future usage
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    return creds


def connect_to_drive():
    """Connect to the Google Drive API service."""
    # Get user credentials
    creds = get_credentials()
    # Connect to the API service
    service = build('drive', 'v3', credentials=creds)
    return service


def get_file_list(service, N):
    """Get a list of first N files or folders from Google Drive."""
    # Request a list of first N files or folders with name and id from the API.
    resource = service.files()
    result = resource.list(pageSize=N, fields="files(id, kind, name, fullFileExtension, parents)").execute()
    # Return the result dictionary containing the information about the files
    return result

def search_file_by_name(service, file_name):
    """Search for a file by name and return its data."""
    # Define the query to search for the file by name
    query = f"name='{file_name}'"
    
    # Request files matching the search query
    resource = service.files()
    result = resource.list(q=query, fields="files(id, kind, name, fullFileExtension, parents)").execute()
    
    # Extract the list of files from the result
    files = result.get('files', [])
    
    if files:
        # Return the data of the first file found
        return files[0]
    else:
        # If no file is found, return None
        return None

def get_files_in_folder(service, parent_folder_id):
    """Get a list of files within a specific parent folder."""
    # Define the query to retrieve files within the parent folder
    query = f"'{parent_folder_id}' in parents"
    
    # Request files matching the query
    resource = service.files()
    result = resource.list(q=query, fields="files(id, kind, name, fullFileExtension, parents)").execute()
    
    # Extract the list of files from the result
    files = result.get('files', [])
    
    return files
    
def print_file_names(file_list):
    """Print names of files in the provided file list."""
    # Extract the list from the dictionary
    files = file_list.get('files')
    print(files)
    # Print every file's name
    for file in files:
        print(file['name'])

# %%
service = connect_to_drive()

# %%
result_dict = get_file_list(service, 500)

# %%
datasets_id = search_file_by_name(service, 'datasets')['id']

# %%
datasets_files = get_files_in_folder(service, datasets_id)

# %%
guardian_id = [file_data for file_data in datasets_files if file_data['name'] == 'guardian'][0]['id']

# %%
guardian_files = get_files_in_folder(service, guardian_id)

# %%
guardian_files
# Out:
# [{'kind': 'drive#file',
#   'parents': ['1m9Ne7xC3YBPvdTWQpnmhNtICffIZeli5'],
#   'id': '1woC5Xhs0kG44lAFTLPbiSimSTSiUfJEa',
#   'name': 'guardian_preprocessed.jsonl',
#   'fullFileExtension': 'jsonl'},
#  {'kind': 'drive#file',
#   'parents': ['1m9Ne7xC3YBPvdTWQpnmhNtICffIZeli5'],
#   'id': '1b7_fUsIPhF4XLOhnE6_U4nI6MBxkE_Fk',
#   'name': 'guardian_phi'}]

# %%
print_file_names(result_dict)
# Out:
# [{'kind': 'drive#file', 'parents': ['1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H'], 'id': '17K45HhGZdVrt9M--nr7HtFKCfra-S7_z', 'name': 'doc_1_chunk_181.jsonl', 'fullFileExtension': 'jsonl'}, {'kind': 'drive#file', 'parents': ['1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H'], 'id': '1n4mlNZpXmqJYtn0gfyftjIH63VG7B51u', 'name': 'doc_1_chunk_157.jsonl', 'fullFileExtension': 'jsonl'}, {'kind': 'drive#file', 'parents': ['1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H'], 'id': '132e4HjogHtEec8gdd13bU_5ZpjfsX9iB', 'name': 'doc_1_chunk_177.jsonl', 'fullFileExtension': 'jsonl'}, {'kind': 'drive#file', 'parents': ['1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H'], 'id': '
# doc_1_chunk_9.jsonl
# doc_1_chunk_91.jsonl
# doc_1_chunk_91.jsonl
# doc_1_chunk_7.jsonl
# doc_1_chunk_88.jsonl
# doc_1_chunk_70.jsonl
# doc_1_chunk_75.jsonl
# doc_1_chunk_89.jsonl
# doc_1_chunk_87.jsonl
# doc_1_chunk_75.jsonl
# doc_1_chunk_65.jsonl
# doc_1_chunk_90.jsonl
# doc_1_chunk_8.jsonl
# doc_1_chunk_74.jsonl
# doc_1_chunk_85.jsonl
# doc_1_chunk_72.jsonl
# doc_1_chunk_67.jsonl
# doc_1_chunk_79.jsonl
# doc_1_chunk_67.jsonl
# doc_1_chunk_87.jsonl
# doc_1_chunk_70.jsonl
# doc_1_chunk_72.jsonl
# doc_1_chunk_79.jsonl
# doc_1_chunk_84.jsonl
# doc_1_chunk_86.jsonl
# doc_1_chunk_90.jsonl
# doc_1_chunk_66.jsonl
# doc_1_chunk_69.jsonl
# doc_1_chunk_85.jsonl
# doc_1_chunk_7.jsonl
# doc_1_chunk_80.jsonl
# doc_1_chunk_86.jsonl
# doc_1_chunk_83.jsonl
# doc_1_chunk_68.jsonl
# doc_1_chunk_8.jsonl
# doc_1_chunk_80.jsonl
# doc_1_chunk_65.jsonl
# doc_1_chunk_89.jsonl
# doc_1_chunk_66.jsonl
# doc_1_chunk_73.jsonl
# doc_1_chunk_81.jsonl
# doc_1_chunk_9.jsonl
# doc_1_chunk_74.jsonl
# doc_1_chunk_71.jsonl
# doc_1_chunk_83.jsonl
# doc_1_chunk_73.jsonl
# doc_1_chunk_71.jsonl
# doc_1_chunk_69.jsonl
# doc_1_chunk_84.jsonl
# doc_1_chunk_68.jsonl
# doc_1_chunk_98.jsonl
# doc_1_chunk_96.jsonl
# doc_1_chunk_98.jsonl
# doc_1_chunk_95.jsonl
# doc_1_chunk_94.jsonl
# doc_1_chunk_99.jsonl
# doc_1_chunk_94.jsonl
# doc_1_chunk_97.jsonl
# doc_1_chunk_93.jsonl
# doc_1_chunk_93.jsonl
# doc_1_chunk_95.jsonl
# doc_1_chunk_92.jsonl
# doc_1_chunk_96.jsonl
# doc_1_chunk_99.jsonl
# doc_1_chunk_92.jsonl
# doc_1_chunk_97.jsonl
# Returns Label.pdf
# SQL Question: Calculating Retention Metrics
# RCourseLinks-20230413
# Demo-AWQ-transformers.ipynb
# Interview instructions and slide template.pptx
# Copy of Eligibility Questionnaire Consent Form 1
# Copy of Eligibility Questionnaire Consent Form 1.docx
# Eligibility Questionnaire Consent Form 1.docx
# Sza Sza Porn Video
# Summer - Large-Scale Computing for Data Analytics.zip
# [EPUB][PDF] Interpretable AI Building explainable machine learning systems by Ajay Thampi on Ipad New Chapters.ipynb
# Harvard CS197 Lecture 3 Notes
# PhD Documents
# setlist_functions.R
# Deep_Learning_with_R_Second_Edition (1)
# PhD Cover Letter
# Resume
# Deep_Learning_with_R_Second_Edition (1)
# Deep_Learning_with_R_Second_Edition (1).pdf
# GroupPoroject_PeerReview.docx
# punctual-rhea
# To-do list
# test
# Matching Data providers and Journals.ipynb
# BERTScore Default Layer Performance on WMT16
# 9789391030889.pdf
# Summer - Data Mining and Machine Learning 2.zip
# CORE identifiers in Data Provider
# Star Wars (Trans.) - Uke Duke.pdf
# Revision Plan
# Data for Student Hiring Project - Citizen Science
# Summary Booklet - Blanks.pdf
# Getting started
# 3DS 11.8 Homebrew Files.zip

# %%
import pandas as pd

def get_files_in_folder_recursive(service, parent_folder_id, parent_folder_name=None):
    """Recursively get all files and folders within a parent folder."""
    # Initialize an empty list to store file and folder data
    files_data = []
    
    # Get a list of files and folders within the parent folder
    files_in_folder = get_files_in_folder(service, parent_folder_id)
    
    # Iterate through the list of files and folders
    for file_data in files_in_folder:
        # Append the file or folder data to the list
        files_data.append({
            'Parent Folder ID': parent_folder_id,
            'Parent Folder Name': parent_folder_name,
            'ID': file_data['id'],
            'Name': file_data['name'],
            'Kind': file_data['kind'],
            'File Extension': file_data.get('fullFileExtension', ''),
            'Is Folder': file_data.get('fullFileExtension') is None
        })
        
        # If the item is a folder, recursively get files and folders within it
        if file_data['kind'] == 'drive#folder':
            folder_id = file_data['id']
            folder_name = file_data['name']
            files_data.extend(get_files_in_folder_recursive(service, folder_id, folder_name))
    
    return files_data

# %%
files_data = get_files_in_folder_recursive(service, datasets_id, 'datasets')

# %%
files_data
# Out:
# [{'Parent Folder ID': '1pT_SGjJ7CDVsONq932Y-5ONVE4q21paj',
#   'Parent Folder Name': 'datasets',
#   'ID': '1m9Ne7xC3YBPvdTWQpnmhNtICffIZeli5',
#   'Name': 'guardian',
#   'Kind': 'drive#file',
#   'File Extension': '',
#   'Is Folder': True}]

# %%
import pandas as pd

def get_files_in_folder_recursive(service, parent_folder_id, parent_folder_name=None):
    """Recursively get all files and folders within a parent folder."""
    # Initialize an empty list to store file and folder data
    files_data = []
    
    # Initialize a stack to store folders to be processed
    folders_to_process = [(parent_folder_id, parent_folder_name)]
    
    # Process folders until the stack is empty
    while folders_to_process:
        # Pop the last folder from the stack
        folder_id, folder_name = folders_to_process.pop()
        
        # Get a list of files and folders within the current folder
        files_in_folder = get_files_in_folder(service, folder_id)
        
        # Iterate through the list of files and folders
        for file_data in files_in_folder:
            # Append the file or folder data to the list
            files_data.append({
                'parent_folder_id': folder_id,
                'parent_folder_name': folder_name,
                'id': file_data['id'],
                'name': file_data['name'],
                'kind': file_data['kind'],
                'file_extension': file_data.get('fullFileExtension', ''),
                'is_folder': file_data.get('fullFileExtension') is None
            })
            
            # If the item is a folder, add it to the stack to be processed later
            if file_data.get('fullFileExtension') is None:
                subfolder_id = file_data['id']
                subfolder_name = file_data['name']
                folders_to_process.append((subfolder_id, subfolder_name))
    
    return files_data

# %%
files_data = get_files_in_folder_recursive(service, datasets_id, 'datasets')

# %%
files_data
# Out:
# [{'parent_folder_id': '1pT_SGjJ7CDVsONq932Y-5ONVE4q21paj',
#   'parent_folder_name': 'datasets',
#   'id': '1m9Ne7xC3YBPvdTWQpnmhNtICffIZeli5',
#   'name': 'guardian',
#   'kind': 'drive#file',
#   'file_extension': '',
#   'is_folder': True},
#  {'parent_folder_id': '1m9Ne7xC3YBPvdTWQpnmhNtICffIZeli5',
#   'parent_folder_name': 'guardian',
#   'id': '1woC5Xhs0kG44lAFTLPbiSimSTSiUfJEa',
#   'name': 'guardian_preprocessed.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1m9Ne7xC3YBPvdTWQpnmhNtICffIZeli5',
#   'parent_folder_name': 'guardian',
#   'id': '1b7_fUsIPhF4XLOhnE6_U4nI6MBxkE_Fk',
#   'name': 'guardian_phi',
#   'kind': 'drive#file',
#   'file_extension': '',
#   'is_folder': True},
#  {'parent_folder_id': '1b7_fUsIPhF4XLOhnE6_U4nI6MBxkE_Fk',
#   'parent_folder_name': 'guardian_phi',
#   'id': '1-nR_X8osU42pgEQGjCQDVgyf-f_PMXUx',
#   'name': 'doc_1.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1b7_fUsIPhF4XLOhnE6_U4nI6MBxkE_Fk',
#   'parent_folder_name': 'guardian_phi',
#   'id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'name': 'raw',
#   'kind': 'drive#file',
#   'file_extension': '',
#   'is_folder': True},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '17K45HhGZdVrt9M--nr7HtFKCfra-S7_z',
#   'name': 'doc_1_chunk_181.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1n4mlNZpXmqJYtn0gfyftjIH63VG7B51u',
#   'name': 'doc_1_chunk_157.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '132e4HjogHtEec8gdd13bU_5ZpjfsX9iB',
#   'name': 'doc_1_chunk_177.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1TgaKG5InoSlblWPTbsLvvxPZMgboST9a',
#   'name': 'doc_1_chunk_156.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '11lnPvsxr0WIgrzovYSTcNGTvRemiTw1n',
#   'name': 'doc_1_chunk_165.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1UfLqAyHHPcPb4Q4nnP_TipQNaGY3JOyP',
#   'name': 'doc_1_chunk_12.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1SN2gGTm8YfN-tgeVv1xFqtr-_X6UIpE_',
#   'name': 'doc_1_chunk_19.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1BIsguF1ALgoAY0DJLg9ndz2_xBNPR8Sl',
#   'name': 'doc_1_chunk_102.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '11-Qhwlq3eot6M0zPuFZ9x2VQeVb2hFo0',
#   'name': 'doc_1_chunk_104.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1hoBREs-GC6rUz1C1RG1V8nvpQK1MuDfe',
#   'name': 'doc_1_chunk_53.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1J1SfplLptalixq0ZB_I-OVHB2k_toyLx',
#   'name': 'doc_1_chunk_78.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1feQiKbX_uxWMz6hgmwBo6NoU4JoQMHbm',
#   'name': 'doc_1_chunk_146.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '168HV7z7poBaSdxRj7t8XT82Ka14_v6Eu',
#   'name': 'doc_1_chunk_82.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1D8E5s3FkjZjlzxMWQTtnZDckpx5E36Lr',
#   'name': 'doc_1_chunk_128.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1QqwZHmppn7D2fDkXnPI7TMWVgXT0NJ5b',
#   'name': 'doc_1_chunk_184.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1oLHy2rNXjkJ_EUUEBgbV0FWhh-QCO7_O',
#   'name': 'doc_1_chunk_140.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '10W_IQE24ZkLBZy54d7m5R4rJoZ0zFTyp',
#   'name': 'doc_1_chunk_48.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1DD37pklmQz29dpUyYyCtB1CNj4H9vwLR',
#   'name': 'doc_1_chunk_62.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '116A-2VJnM46EtmlLhxo0x4boEfUAxsXr',
#   'name': 'doc_1_chunk_58.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1dIlRd6p-eZUtB0s0MB1CQKtRoenC_xS0',
#   'name': 'doc_1_chunk_22.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1H4McXMpDdFfTwkOmcTohwy-TBkMpoB3E',
#   'name': 'doc_1_chunk_77.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1ja3cQb4S8Ay8gef0Sc_tjwQDDrb9T1C8',
#   'name': 'doc_1_chunk_106.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1n9HO8dqoDujVSK-bHmo2ag_QA_l7GXVH',
#   'name': 'doc_1_chunk_131.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1ZAsjQd-FLsOo6fqNmT1zmaN1ucaz7oC9',
#   'name': 'doc_1_chunk_118.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1AIPKFE9-Xq-kCEaZ6-mfHUGckGlta37M',
#   'name': 'doc_1_chunk_76.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1DOXzqR0I--xFZHjLZOYImE44J0mYwCua',
#   'name': 'doc_1_chunk_141.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1JNMIylr9LGPYxzijA5u1KPUwvRF7l56s',
#   'name': 'doc_1_chunk_136.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1gxApJ47t7hBsJCeIZMpTWKrvzomc2JgR',
#   'name': 'doc_1_chunk_24.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1XlHZLKdEDSCbDiS8U9zza-cxTmN5MKjf',
#   'name': 'doc_1_chunk_42.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1lLCPGoQT0p2VEikXy0Xu2Lo-GgaNNBwy',
#   'name': 'doc_1_chunk_39.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1vrcbJyu6I5CGSDD3nPTVJOylYwrdC5So',
#   'name': 'doc_1_chunk_191.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '118INQaZ37NGkNcII1_Uq_3RvYBnlFji5',
#   'name': 'doc_1_chunk_64.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1B1HWSNtAKDbNA9ti3TLeOQT4zaO0Zy7T',
#   'name': 'doc_1_chunk_100.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '15hIFwN-YPyoKfNucQgopJz3MCQPjfVCS',
#   'name': 'doc_1_chunk_107.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '12ey8OQf-HhNSwKBHcpKkWVMeAkMYaa-Q',
#   'name': 'doc_1_chunk_0.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1OHiU5yGmaqu42vTO0SG2w-l_Q61yL4dW',
#   'name': 'doc_1_chunk_109.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1sFLjSBlAUivSbKwKsjmwspeYI3svjIrO',
#   'name': 'doc_1_chunk_103.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1aJXS2wuMqDjF9cC-Rad2AVynR1sIxgwU',
#   'name': 'doc_1_chunk_109.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '17zqbHXLj6B8ulZRkUcIH7FjF-naaVwPI',
#   'name': 'doc_1_chunk_108.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1b6q7LwBP5t84efhQXlHjY0zOI4rY3ScX',
#   'name': 'doc_1_chunk_105.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '13bPLbUwuD_fWLZzAWkpOZsUtSqlSgmKL',
#   'name': 'doc_1_chunk_101.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '19b4p_jzViJtD_j76A39oq8FdkqD6019F',
#   'name': 'doc_1_chunk_10.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1_V7ZORZ0wJcXcSc7T0_z3kRtqQFIxWaG',
#   'name': 'doc_1_chunk_105.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1z8Uk3QuAnP5z6ypndgJRvYennEOqn7aD',
#   'name': 'doc_1_chunk_1.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '17hKvg9PS07OHIJnvIMZwRTbf_jFf0GOW',
#   'name': 'doc_1_chunk_1.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1wg_-jUDP76cgbU_Z-4CD9zbJhEJueVAI',
#   'name': 'doc_1_chunk_103.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1RQOMIB6alMWgEUzXnJr84XzDlJfkwC_t',
#   'name': 'doc_1_chunk_10.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '128UN-3wHSia8wSBgSaDLNdozVwB_wTii',
#   'name': 'doc_1_chunk_101.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1cWFZLFm5kfzdify15KZh993DCE7XxerX',
#   'name': 'doc_1_chunk_107.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1HhnHaCSPK6vOzOTnihB83n8MOl9EAGSp',
#   'name': 'doc_1_chunk_108.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1btk_jV7ldrVd9LBf8EzZV3rGUaYHy61I',
#   'name': 'doc_1_chunk_0.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1Ylc2gp8uQ-j4X4-8MFONCh3o7bFI2GOI',
#   'name': 'doc_1_chunk_100.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1fJIWTzEHe84J4f1HUtzYdykpAQ1JNi2i',
#   'name': 'doc_1_chunk_116.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1mnnvMIVgybtNm7ZaloOH5kZcawPAl6q1',
#   'name': 'doc_1_chunk_110.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1YVriyWtsRRcx8SCM2lkxRX03-WfxIbzw',
#   'name': 'doc_1_chunk_115.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1r2cBokBASbHJW8nk-D7jmNLbURduC_fd',
#   'name': 'doc_1_chunk_112.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1H_dreRoszFwWHY7gofstW_VzmZ95Q16F',
#   'name': 'doc_1_chunk_116.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '16Ol2-9Uyq0wTWnSG_bXR4FzG2cawTYeF',
#   'name': 'doc_1_chunk_114.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1dwvx7BU3fAwTXKu6KADC_Sy-pVhwRxf9',
#   'name': 'doc_1_chunk_114.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1xSTXcCkiq5Tp545-K4muRZtsVOikgTd0',
#   'name': 'doc_1_chunk_111.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1RM9VHuqBni3ixvPfny8z3tTJIcWHZNn8',
#   'name': 'doc_1_chunk_11.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1SlJ7K9AFKkFZrXn1IDm4UGNa7X3NDpFt',
#   'name': 'doc_1_chunk_112.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1Qg7av0g5gqjy3CNhAttZSKvTz9nkNk0g',
#   'name': 'doc_1_chunk_111.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '12S2ULFBhGogN7w43mSGkuDIoNmDtueHg',
#   'name': 'doc_1_chunk_115.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1t6S8FYkqIFNiB0pTvFFMUZ_SEyvoeeJq',
#   'name': 'doc_1_chunk_113.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1myDAAy1epiHfioZjdVbybLDKa2QMz0iN',
#   'name': 'doc_1_chunk_110.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1Tm2iY9DdsDRGqNrrxh-_RuUZWTSofp6w',
#   'name': 'doc_1_chunk_113.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1ZxKtZJ4-5FeaQveVgrAMRa7p04oJF4C9',
#   'name': 'doc_1_chunk_11.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '18sCbcKNdMvKOCCzLVCsEz4cvp4V0bWe9',
#   'name': 'doc_1_chunk_117.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1Q8e2Sc4HQxTFvIATGupOIuBAhCwVfXg1',
#   'name': 'doc_1_chunk_119.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1qfI3MZv9mV6HVMngzQJFFEXX58nMHcWM',
#   'name': 'doc_1_chunk_120.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '18GrLPCG6ThIfrrJYCLy-JjZ9iuWzUpp3',
#   'name': 'doc_1_chunk_121.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1i7mphW3vvthNKF4HARZvP0DORD2GkpzI',
#   'name': 'doc_1_chunk_123.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '17UZSBRRbSbqmWnbwAzK89v9ngMRlJf1g',
#   'name': 'doc_1_chunk_121.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1H1sSGZT0bi52vbzILKkBQZxTnGJegnnX',
#   'name': 'doc_1_chunk_120.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1htjHdqPsLbufQ3_QL4BFVld0FjUSyI3I',
#   'name': 'doc_1_chunk_122.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1sF93lcoWSxYXYJ31YZ0o_kN9ExVhc9aq',
#   'name': 'doc_1_chunk_123.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1GxrlF3pnmVbxaslizqTnnZPpR5VqsIue',
#   'name': 'doc_1_chunk_119.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '12GVLDfoBP-hJzhmQVjadkGo69lFM4cTU',
#   'name': 'doc_1_chunk_117.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1ua6wUu_saH_LucQ8BSqiok97jrQtZyOc',
#   'name': 'doc_1_chunk_122.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '16MTn2isTOg4qIcYTy2ztK_rZwGNoaJY2',
#   'name': 'doc_1_chunk_127.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1fdlk2_JcyvDW-a10xLihQeeVcA3NJHPR',
#   'name': 'doc_1_chunk_129.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1gaL20BwJK9d0WUYu3wKqE91tYW0jpKDM',
#   'name': 'doc_1_chunk_124.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '13TBY_M29mcMM-lYRgWpoCjD1ttA9ML1P',
#   'name': 'doc_1_chunk_124.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1LcsVhZfoRdJw6a7vOvN2S8lkTir05Fft',
#   'name': 'doc_1_chunk_126.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1BpX67UNNp3z-TCo7ajS44jagCja1QZ7v',
#   'name': 'doc_1_chunk_126.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1qPHZZseoV5SFdd4st9uv3OaHndY144PM',
#   'name': 'doc_1_chunk_125.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1BNg_hMtyJdOVtE6kd3otm7KMmKeBSy1R',
#   'name': 'doc_1_chunk_129.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1Ofny0aNhW_IWhEwmD3cbQTej1rGmHd0e',
#   'name': 'doc_1_chunk_127.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1v3rhewA3xNzY1Y_-MaqPJEe51ZPyXNSS',
#   'name': 'doc_1_chunk_125.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '13CydWtIP8DUed538RNtUfy41ssgVB8AZ',
#   'name': 'doc_1_chunk_135.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1SZ-HpGA2qj5cnTlCICGnOwpC361T5UAy',
#   'name': 'doc_1_chunk_133.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '148Cen_v6pIgKcUbJsP9ljfd_cfEpOuwP',
#   'name': 'doc_1_chunk_130.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '11cTOYF0hOgmCPldTbx15zuV9IM_tjCrP',
#   'name': 'doc_1_chunk_135.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1nuEsaThWnroK75WIurNzloLhkTqY6dG2',
#   'name': 'doc_1_chunk_133.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '17lNIMPJLbGSFDziFRH0yfIaLjXSPYHDJ',
#   'name': 'doc_1_chunk_130.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1P6nJaIBXYKXK1sB4SZ41JgYlX5uUmmEf',
#   'name': 'doc_1_chunk_134.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1qFstoCbkeZkuL9Zp_Ufb6ECaa4hA75ni',
#   'name': 'doc_1_chunk_132.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1r8y2TCCCCo8oNKxN8WuLqmLN2F_4KrL1',
#   'name': 'doc_1_chunk_132.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False},
#  {'parent_folder_id': '1Xr_FrDDnyOnFpgkhXggzlfAzYSVHhu7H',
#   'parent_folder_name': 'raw',
#   'id': '1j_3j1ODq0SilFqpAIRSGQkG9ZbQ2xfWS',
#   'name': 'doc_1_chunk_13.jsonl',
#   'kind': 'drive#file',
#   'file_extension': 'jsonl',
#   'is_folder': False}]

# %%
files_df = pd.DataFrame(files_data)

# %%
files_df[files_df['
