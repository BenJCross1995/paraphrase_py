# %%
from pathlib import Path
import os
import sys
import pandas as pd
import re

# %% [markdown]
# ## Import other modules without running main

# %%
# Dynamically determine the current script's directory and add the parent directory to sys.path
current_dir = Path().resolve()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

# Import combine (ensure that it has the required functions)
import combine_rephrased
import read_and_write_docs

# %%
def create_temp_doc_id(input_text):
    # Extract everything between the brackets
    match = re.search(r'\[(.*?)\]', input_text)
    if match:
        extracted_text = match.group(1)
        # Replace all punctuation and spaces with "_"
        cleaned_text = re.sub(r'[^\w]', '_', extracted_text)
        # Replace multiple underscores with a single "_"
        final_text = re.sub(r'_{2,}', '_', cleaned_text)
        return final_text.lower()
    return None

def process_and_combine(old_df, file_paths, num_impostors=1000, score_table=False, score_col=None, seed=None):
    """
    Process a list of file paths, filter the old DataFrame based on doc_id, 
    and combine the results into a single DataFrame.
    
    Parameters:
    - old_df: The old DataFrame to filter.
    - file_paths: List of file paths to process.
    - num_impostors: Parameter for the combine function.
    - score_table: Does the rephrased table have a score column.
    - score_col: If table has score column what is the column name.
    
    Returns:
    - result_df: Combined DataFrame.
    """
    
    result_dfs = []
    
    for file_path in file_paths:

        # Read the new DataFrame from the file
        new_df = read_and_write_docs.read_jsonl_file(file_path)
        
        new_df = new_df.rename(columns={
            'original': 'original_sentence', 
            'rephrased': 'result'})

        # Convert columns to numeric
        new_df['doc_id'] = pd.to_numeric(new_df['doc_id'], errors='coerce')
        new_df['chunk_id'] = pd.to_numeric(new_df['chunk_id'], errors='coerce')
        
        # Ensure 'doc_id' is in the DataFrame
        if 'doc_id' not in new_df.columns:
            raise ValueError(f"The file {file_path} does not contain a 'doc_id' column.")
        
        # Get the unique doc_id from the new DataFrame
        new_doc_id = int(new_df['doc_id'].unique()[0])

        # Filter the old DataFrame for the doc_id
        filtered_old_df = old_df[old_df['doc_id'] == new_doc_id].copy()
        print(f"Sampling Doc: {new_doc_id}")

        if score_table == False:
            # Combine the filtered old DataFrame with the new DataFrame
            combined_df = combine_rephrased.chunk_single_rephrased(filtered_old_df, new_df, num_impostors=num_impostors,
                                                                   seed=seed)
        else:
            combined_df = combine_rephrased.chunk_single_rephrased_with_scores_list(filtered_old_df, new_df,
                                                                                    score_col, num_impostors=num_impostors,
                                                                                    seed=seed)
        
        # Append the combined DataFrame to the list of result DataFrames
        result_dfs.append(combined_df)
    
    # Concatenate all the result DataFrames into a single DataFrame
    result_df = pd.concat(result_dfs, ignore_index=True)
    
    return result_df

# %%
rephrased_preprocessed = "/Volumes/BCross/datasets/author_verification/training/The Telegraph/known_processed.jsonl"
df = read_and_write_docs.read_jsonl(rephrased_preprocessed)

# %%
df['doc_id'] = df['doc_id'].apply(create_temp_doc_id)

# %%
df
# Out:
#              corpus               doc_id  chunk_id        author texttype  \
# 0     The Telegraph  adrianbridge_text_1         1  AdrianBridge    known
# 1     The Telegraph  adrianbridge_text_1         2  AdrianBridge    known
# 2     The Telegraph  adrianbridge_text_1         3  AdrianBridge    known
# 3     The Telegraph  adrianbridge_text_1         4  AdrianBridge    known
# 4     The Telegraph  adrianbridge_text_1         5  AdrianBridge    known
# ...             ...                  ...       ...           ...      ...
# 6477  The Telegraph    hughmorris_text_3        14    HughMorris    known
# 6478  The Telegraph    hughmorris_text_3        15    HughMorris    known
# 6479  The Telegraph    hughmorris_text_3        16    HughMorris    known
# 6480  The Telegraph    hughmorris_text_3        17    HughMorris    known
# 6481  The Telegraph    hughmorris_text_3        18    HughMorris    known
#
#                                                sentence
# 0     Its fame and popularity means that the Oktober...
# 1     That said, it is still possible to plan a trip...
# 2     Oktoberfest guide Just when does the Oktoberfe...
# 3     Although the festival concludes in October, mo...
# 4     The original Oktoberfest in October 1810 was h...
# ...                                                 ...
# 6477  According to French newspaper Le Figaro, Dutch...
# 6478  The centre, planned for a 230-metre, man-made ...
# 6479  The real people who have the money to go this ...
# 6480  In the meantime, a planning application for th...
# 6481  Travel Guides app Download the free Telegraph ...
#
# [6482 rows x 6 columns]

# %%
df = df[df['doc_id'] == 'gabywood_text_2']
df
# Out:
#              corpus           doc_id  chunk_id    author texttype  \
# 4672  The Telegraph  gabywood_text_2         1  GabyWood    known
# 4673  The Telegraph  gabywood_text_2         2  GabyWood    known
# 4674  The Telegraph  gabywood_text_2         3  GabyWood    known
# 4675  The Telegraph  gabywood_text_2         4  GabyWood    known
# 4676  The Telegraph  gabywood_text_2         5  GabyWood    known
# 4677  The Telegraph  gabywood_text_2         6  GabyWood    known
# 4678  The Telegraph  gabywood_text_2         7  GabyWood    known
# 4679  The Telegraph  gabywood_text_2         8  GabyWood    known
# 4680  The Telegraph  gabywood_text_2         9  GabyWood    known
# 4681  The Telegraph  gabywood_text_2        10  GabyWood    known
# 4682  The Telegraph  gabywood_text_2        11  GabyWood    known
# 4683  The Telegraph  gabywood_text_2        12  GabyWood    known
# 4684  The Telegraph  gabywood_text_2        13  GabyWood    known
# 4685  The Telegraph  gabywood_text_2        14  GabyWood    known
# 4686  The Telegraph  gabywood_text_2        15  GabyWood    known
# 4687  The Telegraph  gabywood_text_2        16  GabyWood    known
# 4688  The Telegraph  gabywood_text_2        17  GabyWood    known
# 4689  The Telegraph  gabywood_text_2        18  GabyWood    known
# 4690  The Telegraph  gabywood_text_2        19  GabyWood    known
# 4691  The Telegraph  gabywood_text_2        20  GabyWood    known
# 4692  The Telegraph  gabywood_text_2        21  GabyWood    known
# 4693  The Telegraph  gabywood_text_2        22  GabyWood    known
# 4694  The Telegraph  gabywood_text_2        23  GabyWood    known
# 4695  The Telegraph  gabywood_text_2        24  GabyWood    known
#
#                                                sentence
# 4672  This week, a photography studio advertised a s...
# 4673  Though they complained that such advertisement...
# 4674           There are two aspects to the difficulty.
# 4675  One is cultural, to do with the way we now exp...
# 4676  The first is a knotty problem that feminists h...
# 4677  Photographs of women have been retouched for p...
# 4678  Why display a dress with a model that the dres...
# 4679  Why make actresses look so different on film p...
# 4680               But this is the visual currency now.
# 4681  Ask any glossy magazine editor, and she will t...
# 4682  But I suspect the transaction is more complica...
# 4683  Many years ago, one of my daughters produced t...
# 4684                  Has photography become a monster?
# 4685     Can we do more with it now than we ever could?
# 4686  Digital means have made things faster and chea...
# 4687  In the final picture her skin was like ivory; ...
# 4688  The adapted negative was like a sculpture, or ...
# 4689  Last year, the Metropolitan Museum of Art in N...
# 4690  The 19th century was fond of photographing fai...
# 4691  Annie Leibovitz, often criticised for her enha...
# 4692  A few years ago, I learnt the 19th-century wet...
# 4693  So every Victorian photograph of a woman in bl...
# 4694  With that knowledge, history takes on a differ...
# 4695  For 175 years we have known how to trap light ...

# %%
parascore_loc = '/Volumes/BCross/datasets/author_verification/training/The Telegraph/batch_parascore/'
parascore_files = [
    f for f in os.listdir(parascore_loc)
    if os.path.isfile(os.path.join(parascore_loc, f)) and f.endswith('.jsonl')
]

# %%
test = parascore_files[0]

# %%
result = process_and_combine(df, test, num_impostors=1000,
                             score_table=True, score_col='parascore_free')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = process_and_combine(df, test, num_impostors=1000,
#       2                              score_table=True, score_col='parascore_free')
#
# Cell In[5], line 34, in process_and_combine(old_df, file_paths, num_impostors, score_table, score_col, seed)
#      29 result_dfs = []
#      31 for file_path in file_paths:
#      32
#      33     # Read the new DataFrame from the file
# ---> 34     new_df = read_and_write_docs.read_jsonl_file(file_path)
#      36     new_df = new_df.rename(columns={
#      37         'original': 'original_sentence',
#      38         'rephrased': 'result'})
#      40     # Convert columns to numeric
#
# AttributeError: module 'read_and_write_docs' has no attribute 'read_jsonl_file'
