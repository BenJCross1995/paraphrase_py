# %%
from pathlib import Path
import os
import sys
import pandas as pd
import re
import random

# %% [markdown]
# ## Import other modules without running main

# %%
# Dynamically determine the current script's directory and add the parent directory to sys.path
current_dir = Path().resolve()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

# Import combine (ensure that it has the required functions)
import combine_rephrased
import read_and_write_docs

# %%
def create_temp_doc_id(input_text):
    # Extract everything between the brackets
    match = re.search(r'\[(.*?)\]', input_text)
    if match:
        extracted_text = match.group(1)
        # Replace all punctuation and spaces with "_"
        cleaned_text = re.sub(r'[^\w]', '_', extracted_text)
        # Replace multiple underscores with a single "_"
        final_text = re.sub(r'_{2,}', '_', cleaned_text)
        return final_text.lower()
    return None

def process_and_combine(old_df, file_paths, num_impostors=1000, score_table=False, score_col=None, seed=None):
    """
    Process a list of file paths, filter the old DataFrame based on doc_id, 
    and combine the results into a single DataFrame.
    
    Parameters:
    - old_df: The old DataFrame to filter.
    - file_paths: List of file paths to process.
    - num_impostors: Parameter for the combine function.
    - score_table: Does the rephrased table have a score column.
    - score_col: If table has score column what is the column name.
    
    Returns:
    - result_df: Combined DataFrame.
    """

    if seed is not None:
        random.seed(seed)
        
    result_dfs = []
    
    for file_path in file_paths:

        # Read the new DataFrame from the file
        new_df = read_and_write_docs.read_jsonl(file_path)

        new_df = new_df.rename(columns={
            'original': 'original_sentence', 
            'rephrased': 'result'})

        # Convert columns to numeric
        # new_df['doc_id'] = pd.to_numeric(new_df['doc_id'], errors='coerce')
        new_df['chunk_id'] = pd.to_numeric(new_df['chunk_id'], errors='coerce')
        
        # Ensure 'doc_id' is in the DataFrame
        if 'doc_id' not in new_df.columns:
            raise ValueError(f"The file {file_path} does not contain a 'doc_id' column.")
        
        # Get the unique doc_id from the new DataFrame
        new_doc_id = new_df['doc_id'].unique()[0]

        # Filter the old DataFrame for the doc_id
        filtered_old_df = old_df[old_df['doc_id'] == new_doc_id].copy()

        print(f"Sampling Doc: {new_doc_id}")

        if score_table == False:
            # Combine the filtered old DataFrame with the new DataFrame
            combined_df = combine_rephrased.chunk_single_rephrased(filtered_old_df, new_df, num_impostors=num_impostors,
                                                                   seed=seed)
        else:
            combined_df = combine_rephrased.chunk_single_rephrased_with_scores_list(filtered_old_df, new_df,
                                                                                    score_col, num_impostors=num_impostors,
                                                                                    seed=seed)
        
        # Append the combined DataFrame to the list of result DataFrames
        result_dfs.append(combined_df)
    
    # Concatenate all the result DataFrames into a single DataFrame
    result_df = pd.concat(result_dfs, ignore_index=True)
    
    return result_df

# %%
rephrased_preprocessed = "/Volumes/BCross/datasets/author_verification/training/TripAdvisor/known_processed.jsonl"
df = read_and_write_docs.read_jsonl(rephrased_preprocessed)

# %%
df['doc_id'] = df['doc_id'].apply(create_temp_doc_id)
df=df.copy()
df.rename(columns={'sentence': 'text'}, inplace=True)

# %%
df.head(2)
# Out:
#         corpus doc_id  chunk_id  author texttype  \
# 0  TripAdvisor   None         1  acbw_8    known
# 1  TripAdvisor   None         2  acbw_8    known
#
#                                                 text
# 0  I would like to have given this B&B a fantasti...
# 1  If you stay in this B&B, just make sure you ar...

# %%
parascore_loc = '/Volumes/BCross/datasets/author_verification/training/The Telegraph/batch_parascore/'
parascore_loc = '/Users/user/Documents/temp_datasets/author_verification/training/The Telegraph/batch_parascore/'
parascore_files = [
    f'{parascore_loc}{f}' for f in os.listdir(parascore_loc)
    if os.path.isfile(os.path.join(parascore_loc, f)) and f.endswith('.jsonl')
]
parascore_files = sorted(parascore_files)

# %%
result = process_and_combine(df, parascore_files, num_impostors=1000,
                             score_table=True, score_col='parascore_free',
                            seed=42)
# Out:
# Sampling Doc: adrianbridge_text_1
# Sampling Doc: adrianbridge_text_2
# Sampling Doc: aislinnlaing_text_1
# Sampling Doc: aislinnlaing_text_2
# Sampling Doc: alanhansen_text_1
# Sampling Doc: alanhansen_text_3
# Sampling Doc: alansmith_text_2
# Sampling Doc: alansmith_text_3
# Sampling Doc: alantitchmarsh_text_1
# Sampling Doc: alantitchmarsh_text_2
# Sampling Doc: alantovey_text_1
# Sampling Doc: alantovey_text_2
# Sampling Doc: alasdairreid_text_2
# Sampling Doc: alasdairreid_text_3
# Sampling Doc: alastairgood_text_1
# Sampling Doc: alastairgood_text_3
# Sampling Doc: alastairsmart_text_1
# Sampling Doc: alastairsmart_text_2
# Sampling Doc: alastairsooke_text_2
# Sampling Doc: alastairsooke_text_3
# Sampling Doc: alexjames_text_1
# Sampling Doc: alexjames_text_3
# Sampling Doc: aliceaudley_text_1
# Sampling Doc: aliceaudley_text_3
# Sampling Doc: alicephilipson_text_2
# Sampling Doc: alicephilipson_text_3
# Sampling Doc: alicevincent_text_1
# Sampling Doc: alicevincent_text_3
# Sampling Doc: allisonpearson_text_1
# Sampling Doc: allisonpearson_text_2
# Sampling Doc: allisterheath_text_1
# Sampling Doc: allisterheath_text_2
# Sampling Doc: ambroseevans_pritchard_text_1
# Sampling Doc: ambroseevans_pritchard_text_2
# Sampling Doc: andrewenglish_text_2
# Sampling Doc: andrewenglish_text_3
# Sampling Doc: andrewgilligan_text_1
# Sampling Doc: andrewgilligan_text_3
# Sampling Doc: andrewmarszal_text_1
# Sampling Doc: andrewmarszal_text_2
# Sampling Doc: annatyzack_text_1
# Sampling Doc: annatyzack_text_2
# Sampling Doc: annebillson_text_1
# Sampling Doc: annebillson_text_3
# Sampling Doc: anthonyperegrine_text_1
# Sampling Doc: anthonyperegrine_text_3
# Sampling Doc: auslancramb_text_1
# Sampling Doc: auslancramb_text_3
# Sampling Doc: beewilson_text_2
# Sampling Doc: beewilson_text_3
# Sampling Doc: benfarmer_text_2
# Sampling Doc: benfarmer_text_3
# Sampling Doc: benfogle_text_2
# Sampling Doc: benfogle_text_3
# Sampling Doc: benlawrence_text_1
# Sampling Doc: benlawrence_text_2
# Sampling Doc: benmarlow_text_1
# Sampling Doc: benmarlow_text_2
# Sampling Doc: bernadettemcnulty_text_2
# Sampling Doc: bernadettemcnulty_text_3
# Sampling Doc: beverleyturner_text_1
# Sampling Doc: beverleyturner_text_3
# Sampling Doc: borisjohnson_text_1
# Sampling Doc: borisjohnson_text_2
# Sampling Doc: brianmoore_text_2
# Sampling Doc: brianmoore_text_3
# Sampling Doc: brunowaterfield_text_2
# Sampling Doc: brunowaterfield_text_3
# Sampling Doc: bryonygordon_text_1
# Sampling Doc: bryonygordon_text_2
# Sampling Doc: bunnyguinness_text_3
# Sampling Doc: cameronmacphail_text_3
# Sampling Doc: camillaturner_text_1
# Sampling Doc: carolinekent_text_2
# Sampling Doc: carolinekent_text_3
# Sampling Doc: carolinemcghie_text_1
# Sampling Doc: carolinemcghie_text_3
# Sampling Doc: carolynhart_text_1
# Sampling Doc: carolynhart_text_2
# Sampling Doc: catalinastogdon_text_1
# Sampling Doc: catherinegee_text_1
# Sampling Doc: catherinegee_text_2
# Sampling Doc: charlesmoore_text_1
# Sampling Doc: charlesmoore_text_2
# Sampling Doc: charlesspencer_text_1
# Sampling Doc: charlesspencer_text_2
# Sampling Doc: charlottebeugge_text_1
# Sampling Doc: charlottebeugge_text_3
# Sampling Doc: charlotteruncie_text_1
# Sampling Doc: charlotteruncie_text_3
# Sampling Doc: chrisharvey_text_1
# Sampling Doc: chrisharvey_text_3
# Sampling Doc: chrisknapman_text_1
# Sampling Doc: chrisknapman_text_2
# Sampling Doc: christopherbooker_text_3
# Sampling Doc: christopherhope_text_1
# Sampling Doc: christopherhope_text_3
# Sampling Doc: christopherhowse_text_1
# Sampling Doc: christopherhowse_text_3
# Sampling Doc: christophermiddleton_text_2
# Sampling Doc: christophermiddleton_text_3
# Sampling Doc: christopherwilliams_text_1
# Sampling Doc: christopherwilliams_text_3
# Sampling Doc: clairecarter_text_1
# Sampling Doc: clairecarter_text_2
# Sampling Doc: clairecohen_text_1
# Sampling Doc: clairecohen_text_3
# Sampling Doc: claireduffin_text_2
# Sampling Doc: claireduffin_text_3
# Sampling Doc: cliveaslet_text_1
# Sampling Doc: cliveaslet_text_3
# Sampling Doc: clivejames_text_2
# Sampling Doc: colemoreton_text_1
# Sampling Doc: colinfreeman_text_2
# Sampling Doc: concoughlin_text_3
# Sampling Doc: craigmclean_text_1
# Sampling Doc: craigmclean_text_2
# Sampling Doc: daisybridgewater_text_2
# Sampling Doc: daisybridgewater_text_3
# Sampling Doc: damienmcelroy_text_1
# Sampling Doc: damienmcelroy_text_2
# Sampling Doc: danhyde_text_1
# Sampling Doc: danhyde_text_2
# Sampling Doc: danieljohnson_text_1
# Sampling Doc: danieljohnson_text_2
# Sampling Doc: davidbarrett_text_2
# Sampling Doc: davidbarrett_text_3
# Sampling Doc: davidblair_text_2
# Sampling Doc: davidblair_text_3
# Sampling Doc: davidcoulthard_text_1
# Sampling Doc: davidcoulthard_text_3
# Sampling Doc: davidgritten_text_2
# Sampling Doc: davidgritten_text_3
# Sampling Doc: deannelson_text_1
# Sampling Doc: deannelson_text_2
# Sampling Doc: derekpringle_text_1
# Sampling Doc: derekpringle_text_3
# Sampling Doc: dianahenry_text_1
# Sampling Doc: dianahenry_text_3
# Sampling Doc: edcumming_text_1
# Sampling Doc: edcumming_text_2
# Sampling Doc: elizabethgrice_text_1
# Sampling Doc: elizabethgrice_text_2
# Sampling Doc: emilygosden_text_2
# Sampling Doc: emilygosden_text_3
# Sampling Doc: erinbaker_text_3
# Sampling Doc: fionagovan_text_1
# Sampling Doc: fionagovan_text_3
# Sampling Doc: florencewaters_text_1
# Sampling Doc: florencewaters_text_2
# Sampling Doc: gabywood_text_1
# Sampling Doc: gabywood_text_2
# Sampling Doc: garethadavies_text_1
# Sampling Doc: garethadavies_text_3
# Sampling Doc: gavinmairs_text_1
# Sampling Doc: gavinmairs_text_2
# Sampling Doc: geoffreyboycott_text_1
# Sampling Doc: geoffreyboycott_text_2
# Sampling Doc: geoffreylean_text_1
# Sampling Doc: geoffreylean_text_2
# Sampling Doc: georgiadehn_text_2
# Sampling Doc: georgiadehn_text_3
# Sampling Doc: gilesmole_text_1
# Sampling Doc: gilesmole_text_3
# Sampling Doc: gillcharlton_text_1
# Sampling Doc: gillcharlton_text_3
# Sampling Doc: gillianreynolds_text_2
# Sampling Doc: gillianreynolds_text_3
# Sampling Doc: gordonrayner_text_1
# Sampling Doc: gordonrayner_text_3
# Sampling Doc: graemepaton_text_2
# Sampling Doc: graemepaton_text_3
# Sampling Doc: grahamnorton_text_1
# Sampling Doc: grahamnorton_text_2
# Sampling Doc: grahamruddick_text_1
# Sampling Doc: grahamruddick_text_2
# Sampling Doc: gregorywalton_text_1
# Sampling Doc: hannahfurness_text_1
# Sampling Doc: hannahstrange_text_1
# Sampling Doc: harrietalexander_text_1
# Sampling Doc: harrietalexander_text_3
# Sampling Doc: harrydequetteville_text_1
# Sampling Doc: harrydequetteville_text_3
# Sampling Doc: harrywallop_text_1
# Sampling Doc: harrywallop_text_2
# Sampling Doc: harrywilson_text_1
# Sampling Doc: harrywilson_text_3
# Sampling Doc: hayleydixon_text_1
# Sampling Doc: hayleydixon_text_3
# Sampling Doc: helenbrown_text_1
# Sampling Doc: helenbrown_text_3
# Sampling Doc: helencoffey_text_1
# Sampling Doc: helencoffey_text_2
# Sampling Doc: helenyemm_text_1
# Sampling Doc: helenyemm_text_3
# Sampling Doc: henrysamuel_text_1
# Sampling Doc: henrysamuel_text_2
# Sampling Doc: henrywinter_text_1
# Sampling Doc: henrywinter_text_2
# Sampling Doc: hollywatt_text_1
# Sampling Doc: hollywatt_text_2
# Sampling Doc: horatiaharrod_text_1
# Sampling Doc: horatiaharrod_text_2
# Sampling Doc: hughmorris_text_1
# Sampling Doc: hughmorris_text_3

# %%
result
# Out:
#                      doc_id  \
# 0       adrianbridge_text_1
# 1       adrianbridge_text_1
# 2       adrianbridge_text_1
# 3       adrianbridge_text_1
# 4       adrianbridge_text_1
# ...                     ...
# 204995    hughmorris_text_3
# 204996    hughmorris_text_3
# 204997    hughmorris_text_3
# 204998    hughmorris_text_3
# 204999    hughmorris_text_3
#
#                                                 rephrased  average_score  \
# 0       As a result of its popularity, Oktoberfest dra...       0.761738
# 1       Due to its popularity, Oktoberfest serves as a...       0.752489
# 2       The Oktoberfest's renown and attractiveness dr...       0.760922
# 3       Oktoberfest's significant recognition and allu...       0.757237
# 4       Oktoberfest's significant recognition and allu...       0.774004
# ...                                                   ...            ...
# 204995  Selecting players for school football teams of...       0.761087
# 204996  Team selection for schoolboy football is marke...       0.767584
# 204997  The approach to selecting players for schoolbo...       0.767634
# 204998  Selecting teams for schoolboy football is a ra...       0.766722
# 204999  The selection process for schoolboy football t...       0.779968
#
#                                                score_list  \
# 0       [0.7057556509971619, 0.7109548449516296, 0.655...
# 1       [0.6755099296569824, 0.7786570191383362, 0.809...
# 2       [0.672859787940979, 0.6357008814811707, 0.7936...
# 3       [0.707846462726593, 0.7063670754432678, 0.6801...
# 4       [0.707846462726593, 0.6910657286643982, 0.6697...
# ...                                                   ...
# 204995  [0.6976029872894287, 0.8282140493392944, 0.818...
# 204996  [0.8182606101036072, 0.8468731641769409, 0.791...
# 204997  [0.7359892129898071, 0.8274188041687012, 0.779...
# 204998  [0.8032898902893066, 0.8074444532394409, 0.857...
# 204999  [0.7422707676887512, 0.8189705610275269, 0.908...
#
#                                    original_sentence_list  \
# 0       [Its fame and popularity means that the Oktobe...
# 1       [Its fame and popularity means that the Oktobe...
# 2       [Its fame and popularity means that the Oktobe...
# 3       [Its fame and popularity means that the Oktobe...
# 4       [Its fame and popularity means that the Oktobe...
# ...                                                   ...
# 204995  [Schoolboy football team selection is a crude ...
# 204996  [Schoolboy football team selection is a crude ...
# 204997  [Schoolboy football team selection is a crude ...
# 204998  [Schoolboy football team selection is a crude ...
# 204999  [Schoolboy football team selection is a crude ...
#
#                                   rephrased_sentence_list
# 0       [As a result of its popularity, Oktoberfest dr...
# 1       [Due to its popularity, Oktoberfest serves as ...
# 2       [The Oktoberfest's renown and attractiveness d...
# 3       [Oktoberfest's significant recognition and all...
# 4       [Oktoberfest's significant recognition and all...
# ...                                                   ...
# 204995  [Selecting players for school football teams o...
# 204996  [Team selection for schoolboy football is mark...
# 204997  [The approach to selecting players for schoolb...
# 204998  [Selecting teams for schoolboy football is a r...
# 204999  [The selection process for schoolboy football ...
#
# [205000 rows x 6 columns]

# %%
result.head(5)
# Out:
#                 doc_id                                          rephrased  \
# 0  adrianbridge_text_1  As a result of its popularity, Oktoberfest dra...
# 1  adrianbridge_text_1  Due to its popularity, Oktoberfest serves as a...
# 2  adrianbridge_text_1  The Oktoberfest's renown and attractiveness dr...
# 3  adrianbridge_text_1  Oktoberfest's significant recognition and allu...
# 4  adrianbridge_text_1  Oktoberfest's significant recognition and allu...
#
#    average_score                                         score_list  \
# 0       0.761738  [0.7057556509971619, 0.7109548449516296, 0.655...
# 1       0.752489  [0.6755099296569824, 0.7786570191383362, 0.809...
# 2       0.760922  [0.672859787940979, 0.6357008814811707, 0.7936...
# 3       0.757237  [0.707846462726593, 0.7063670754432678, 0.6801...
# 4       0.774004  [0.707846462726593, 0.6910657286643982, 0.6697...
#
#                               original_sentence_list  \
# 0  [Its fame and popularity means that the Oktobe...
# 1  [Its fame and popularity means that the Oktobe...
# 2  [Its fame and popularity means that the Oktobe...
# 3  [Its fame and popularity means that the Oktobe...
# 4  [Its fame and popularity means that the Oktobe...
#
#                              rephrased_sentence_list
# 0  [As a result of its popularity, Oktoberfest dr...
# 1  [Due to its popularity, Oktoberfest serves as ...
# 2  [The Oktoberfest's renown and attractiveness d...
# 3  [Oktoberfest's significant recognition and all...
# 4  [Oktoberfest's significant recognition and all...

# %%
result_loc = "/Volumes/BCross/datasets/author_verification/training/The Telegraph/batch_sentence_impostors.jsonl"
read_and_write_docs.write_jsonl(result, result_loc)

# %%
def top_n_impostors(df, n, remove_scores=False, remove_sentence_lists=False):
    """
    Groups the dataframe by 'doc_id' and selects the top n rows per group based on 'average_score'.
    
    Parameters:
        df (pd.DataFrame): Input dataframe with 'doc_id' and 'average_score' columns.
        n (int): Number of top rows to select per group.
        remove_scores (bool): If True, removes 'average_score' and 'score_list' columns from the result.

    Returns:
        pd.DataFrame: Filtered dataframe with top n rows per 'doc_id' by 'average_score'.
    """
    grouped = df.groupby('doc_id', group_keys=False)
    top_n = grouped.apply(lambda x: x.nlargest(n, 'average_score'))
    result = top_n.reset_index(drop=True)
    
    if remove_scores:
        result = result.drop(columns=['average_score', 'score_list'], errors='ignore')

    if remove_sentence_lists:
        result = result.drop(columns=['original_sentence_list', 'rephrased_sentence_list'], errors='ignore')
    
    return result

# %%
top_500 = top_n_impostors(result, 500, remove_scores=True, remove_sentence_lists=True)
# Out:
# /var/folders/xx/hy496x3x5sn4hy9gy1fk19lw0000gp/T/ipykernel_40678/2054036389.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_n = grouped.apply(lambda x: x.nlargest(n, 'average_score'))

# %%
top_500.head(5)
# Out:
#                 doc_id                                          rephrased
# 0  adrianbridge_text_1  Oktoberfest's widespread appeal and recognitio...
# 1  adrianbridge_text_1  The Oktoberfest enjoys a high level of fame, m...
# 2  adrianbridge_text_1  The fame of the Oktoberfest ensures it is a ma...
# 3  adrianbridge_text_1  Due to its renowned reputation, Oktoberfest at...
# 4  adrianbridge_text_1  Its celebrity status means Oktoberfest easily ...

# %%
top_500_loc = "/Volumes/BCross/datasets/author_verification/training/The Telegraph/batch_sentence_impostors_top_500.jsonl"
read_and_write_docs.write_jsonl(top_500, top_500_loc)

# %%
df['doc_id'] = 'ambroseevans_pritchard_text_1'
