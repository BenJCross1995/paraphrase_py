# %%
import json
import os
import re

import pandas as pd

from openai import OpenAI

# %%
credential_loc = "../../credentials.json"

data_type = "training"
corpus = "The Telegraph"

base_loc = f"/Volumes/BCross/datasets/author_verification/"
data_loc = f"{base_loc}{data_type}/{corpus}/"
batch_loc = f"{data_loc}batch_sentence_preprocessed/"
raw_data_loc = f"{data_loc}known_raw.jsonl"
processed_data_loc = f"{data_loc}known_processed.jsonl"

# Location for data when sent to batch
batch_sent_loc = f"{data_loc}batch_sentence_sent/"
os.makedirs(batch_sent_loc, exist_ok=True)

# Location once batch complete
batch_complete_loc = f"{data_loc}batch_sentence_complete/"
os.makedirs(batch_complete_loc, exist_ok=True)

# Location once batch complete
batch_fail_loc = f"{data_loc}batch_sentence_fail/"
os.makedirs(batch_fail_loc, exist_ok=True)

# Location to save the reasons for failure
batch_fail_reason_loc = f"{data_loc}batch_fail_reasons/"
os.makedirs(batch_fail_reason_loc, exist_ok=True)

# Phone number for WhatsApp notifications
phone_number = "+447756976114"

# %% [markdown]
# ### Initialise OpenAI Clients

# %%
with open(credential_loc, 'r') as f:
    data = json.load(f)
    
os.environ["OPENAI_API_KEY"] = data['OPENAI_API_KEY']

client = OpenAI()

# %% [markdown]
# ### Helper Functions

# %%
def read_jsonl(file_path):
    """
    Reads a JSONL file and converts it into a pandas DataFrame.

    Parameters:
    - file_path: Path to the JSONL file to read.

    Returns:
    - A pandas DataFrame containing the data from the JSONL file.
    """
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            # Parse the line as JSON
            parsed_line = json.loads(line)
            # If the line is a single-element list, extract the first element
            if isinstance(parsed_line, list) and len(parsed_line) == 1:
                data.append(parsed_line[0])
            else:
                data.append(parsed_line)
    
    # Convert to a DataFrame
    data = pd.DataFrame(data)
    return data

def write_jsonl(data, output_file_path):
    with open(output_file_path, 'w') as file:
        for _, row in data.iterrows():
            json.dump(row.to_dict(), file)
            file.write('\n')

def create_temp_doc_id(input_text):
    # Extract everything between the brackets
    match = re.search(r'\[(.*?)\]', input_text)
    if match:
        extracted_text = match.group(1)
        # Replace all punctuation and spaces with "_"
        cleaned_text = re.sub(r'[^\w]', '_', extracted_text)
        # Replace multiple underscores with a single "_"
        final_text = re.sub(r'_{2,}', '_', cleaned_text)
        final_text = 'batch_' + final_text
        return final_text.lower()
    return None

# %%
def get_latest_fail_reasons(batch_fail_reason_loc):

    fail_reasons = os.listdir(batch_fail_reason_loc)

    # Sort in descending order by timestamp
    sorted_files = sorted(fail_reasons, key=lambda x: int(x.split('_')[-1].split('.')[0]), reverse=True)

    # Read the latest created document
    df = read_jsonl(f"{batch_fail_reason_loc}{sorted_files[0]}")

    return df

def get_failed_files_list(batch_fail_loc):

    files_failed = [
        f for f in os.listdir(batch_fail_loc)
        if os.path.isfile(os.path.join(batch_fail_loc, f)) and f.endswith('.jsonl')
    ]

    strings_before_filetype = [file.split('.json')[0] for file in files_failed]
    
    return strings_before_filetype

# %%
def filter_known_for_fails(processed_data_loc, batch_fail_loc):

    # Load data and create new id which is the same as batch id's
    df = read_jsonl(processed_data_loc)
    df['temp_doc_id'] = df['doc_id'].apply(create_temp_doc_id)

    failed_files = get_failed_files_list(batch_fail_loc)
    
    df = df[df['temp_doc_id'].isin(failed_files)]

    return df

# %%
df=filter_known_for_fails(processed_data_loc, batch_fail_loc)

# %%
system_prompt = """You are a paraphrasing assistant. Your task is to generate paraphrased sentences that retain the original meaning, tone, and style but demonstrate maximum lexical and structural variety.
Each paraphrase should use distinct vocabulary and sentence structures, prioritizing as much lexical difference as possible.

Guidelines:
- Create AT LEAST TWENTY unique paraphrases.
- Avoid repeating words or phrases across paraphrases, unless they are critical to meaning (e.g., names or specific technical terms).
- Use varied synonyms, alter phrasing, and experiment with different sentence structures to ensure each paraphrase feels fresh and unique.
- Examples of strategies to achieve this include: using metaphors or idioms, reordering clauses, shifting perspectives, and exploring different grammatical constructions.
- Preserve the original intent and style without adding new information or altering names.

DO NOT INCLUDE ANY NOTES OR ADDITIONAL TEXT IN THE OUTPUT.

Example in JSON format:

input: "Although the skill appears easy at first, it can take a long time to master."

Output:
{
  "original": "Although the skill appears easy at first, it can take a long time to master.",
  "paraphrase_1": "Initially, the skill may seem effortless, yet true mastery demands a lengthy commitment.",
  "paraphrase_2": "What begins as a simple-looking skill often turns into a time-consuming mastery process.",
  "paraphrase_3": "While appearing simple at the outset, mastering this skill typically requires extended effort.",
  "paraphrase_4": "Despite an easy start, reaching mastery in this skill can be a prolonged journey.",
  "paraphrase_5": "This skill, while seemingly straightforward at first glance, requires considerable time to excel in.",
  "paraphrase_6": "Even if it looks easy at the beginning, achieving expertise in this skill may be time-intensive.",
  "paraphrase_7": "Though simple in appearance, the skill demands time and practice to truly master.",
  "paraphrase_8": "Achieving proficiency in this skill can take substantial time, even if it seems easy initially.",
  "paraphrase_9": "While the skill might look easy at the start, honing it to perfection can require considerable time.",
  "paraphrase_10": "It might seem straightforward to pick up, yet mastering this skill is often a slow process.",
  "paraphrase_11": "Perfecting this seemingly easy skill can actually be a long and demanding task.",
  "paraphrase_12": "Though it appears simple to learn, achieving mastery in this skill often takes a significant amount of time.",
  "paraphrase_13": "Initially, the skill may come across as effortless, but true proficiency is typically time-consuming.",
  "paraphrase_14": "Mastering this skill is a lengthy pursuit, despite its initial simplicity.",
  "paraphrase_15": "While it looks uncomplicated at first, gaining full mastery of this skill can be a long journey.",
  "paraphrase_16": "Even though this skill seems straightforward, becoming proficient usually takes an extended period.",
  "paraphrase_17": "Mastery of this seemingly simple skill often requires more time than one might expect.",
  "paraphrase_18": "Though it may appear easy at first glance, mastering this skill can be a drawn-out process.",
  "paraphrase_19": "Although appearing effortless at first, this skill demands time and patience for true mastery.",
  "paraphrase_20": "While this skill may look easy initially, true expertise often requires a great deal of time to develop."
}
"""

# %%
df['temp_doc_id'] = df['doc_id'].apply(create_temp_doc_id)

# %%
df
# Out:
#              corpus                              doc_id  chunk_id  \
# 694   The Telegraph   known [AliceVincent - Text 3].txt         1
# 695   The Telegraph   known [AliceVincent - Text 3].txt         2
# 696   The Telegraph   known [AliceVincent - Text 3].txt         3
# 697   The Telegraph   known [AliceVincent - Text 3].txt         4
# 698   The Telegraph   known [AliceVincent - Text 3].txt         5
# ...             ...                                 ...       ...
# 6446  The Telegraph  known [HoratiaHarrod - Text 2].txt        37
# 6447  The Telegraph  known [HoratiaHarrod - Text 2].txt        38
# 6448  The Telegraph  known [HoratiaHarrod - Text 2].txt        39
# 6449  The Telegraph  known [HoratiaHarrod - Text 2].txt        40
# 6450  The Telegraph  known [HoratiaHarrod - Text 2].txt        41
#
#              author texttype  \
# 694    AliceVincent    known
# 695    AliceVincent    known
# 696    AliceVincent    known
# 697    AliceVincent    known
# 698    AliceVincent    known
# ...             ...      ...
# 6446  HoratiaHarrod    known
# 6447  HoratiaHarrod    known
# 6448  HoratiaHarrod    known
# 6449  HoratiaHarrod    known
# 6450  HoratiaHarrod    known
#
#                                                sentence  \
# 694                    One of the characters is female.
# 695         So, keep your eyes peeled for casting news.
# 696   That leaves Vaughn in prime position to be cas...
# 697   Michelle Forbes, who plays Mitch Larsen in the...
# 698   The Wrap also claim to have further plot infor...
# ...                                                 ...
# 6446                              So that was a relief.
# 6447                      A relief on my lungs as well.
# 6448  Later this month Pearce will release his debut...
# 6449            He took a part in Iron Man 3 last year.
# 6450  The Rover is on general release from August 15...
#
#                      temp_doc_id
# 694    batch_alicevincent_text_3
# 695    batch_alicevincent_text_3
# 696    batch_alicevincent_text_3
# 697    batch_alicevincent_text_3
# 698    batch_alicevincent_text_3
# ...                          ...
# 6446  batch_horatiaharrod_text_2
# 6447  batch_horatiaharrod_text_2
# 6448  batch_horatiaharrod_text_2
# 6449  batch_horatiaharrod_text_2
# 6450  batch_horatiaharrod_text_2
#
# [2544 rows x 7 columns]

# %%
df.iloc[0, 5]
# Out:
# 'One of the characters is female.'

# %%
def paraphrase_call(text, system_prompt, client, n=10):

    completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": text}
    ],
    response_format={ "type": "json_object" },
    n = n
    )

    return completion

# %%
def openai_paraphrase_generation(text, system_prompt, client, n=10):
    # Call the paraphrase generation function
    result = paraphrase_call(text, system_prompt, client, n=n)
    
    # Initialize variables for the final result
    final_result = {
        'original': None,
        'unique_paraphrases': set()  # Use a set to ensure uniqueness
    }
    
    for i in range(len(result.choices)):
        # Parse the JSON content from each choice
        json_object = json.loads(result.choices[i].message.content)
        
        # Extract the original text (only set once)
        if final_result['original'] is None:
            final_result['original'] = json_object.get('original', '')
        
        # Collect paraphrases
        for key, value in json_object.items():
            if key.startswith('paraphrase_'):
                final_result['unique_paraphrases'].add(value)
    
    # Convert the set of unique paraphrases back to a list
    final_result['unique_paraphrases'] = list(final_result['unique_paraphrases'])
    
    return final_result

# %%
def openai_paraphrase_generation(text, system_prompt, client, n=10):
    try:
        # Call the paraphrase generation function
        result = paraphrase_call(text, system_prompt, client, n=n)
        
        # Initialize the final result with defaults
        final_result = {
            'original_sentence': text,  # Use the input text as the default original
            'rephrased': []  # Default to an empty list
        }
        
        # Check if result.choices exists and contains valid choices
        if not result or not hasattr(result, 'choices') or not result.choices:
            return final_result  # Return the default if the response is invalid
        
        # Use a set to collect unique paraphrases
        unique_paraphrases = set()
        
        for choice in result.choices:
            # Parse the JSON content from each choice
            try:
                json_object = json.loads(choice.message.content)
            except (json.JSONDecodeError, AttributeError):
                continue  # Skip invalid JSON or missing content
            
            # Set the original text (only set once)
            if not final_result['original_sentence']:
                final_result['original_sentence'] = json_object.get('original', text)
            
            # Collect paraphrases
            for key, value in json_object.items():
                if key.startswith('paraphrase_'):
                    unique_paraphrases.add(value)
        
        # Update the final result
        final_result['rephrased'] = list(unique_paraphrases)
        return final_result
    
    except Exception as e:
        # Handle unexpected errors and return a default result
        print(f"Error during paraphrase generation: {e}")
        return {
            'original_sentence': text,
            'rephrased': []
        }

# %%
result = openai_paraphrase_generation('One of the characters is female.', system_prompt, client)

# %%
result
# Out:
# {'original_sentence': 'One of the characters is female.',
#  'rephrased': ['In this cast, one character is a woman.',
#   'One character in the ensemble is a female figure.',
#   'A character represented is of the female sex.',
#   'Among the ensemble, there is at least one character who is female.',
#   'Included in the roster of characters is a female figure.',
#   'Among the various characters introduced, one is a female.',
#   'A female presence is part of the character array.',
#   'One of the characters is of the female variety.',
#   'One of the roles features a female character.',
#   'There exists a female character among the roster.',
#   'One character depicted in the work is female.',
#   'Included in the lineup of characters is one who is female.',
#   'Among the roster of characters, one is a woman.',
#   'A character portrayed is of the female variety.',
#   'There is a woman among the characters.',
#   'The cast features a female character.',
#   'There is a woman included as one of the characters.',
#   'Included in the lineup of characters is a female figure.',
#   'Within the group of characters, one is identified as female.',
#   'In the ensemble, one character is of the female persuasion.',
#   'The cast includes a character that is female.',
#   'Among those featured, one character is of the female gender.',
#   'A female character is included among the ensemble.',
#   'One of the individuals characterized is a female.',
#   'One character is identified as female.',
#   'In the storyline, there is a character who is a female.',
#   'In the narrative, one character is portrayed as female.',
#   'One character is identified as a woman.',
#   'Among the various characters, one belongs to the female category.',
#   'Among the characters, there is one who is female.',
#   "There's an inclusion of a female character amongst them.",
#   'The story showcases a character who is a woman.',
#   'Within the character set, there is at least one female figure.',
#   'A female character is among them.',
#   'One character is portrayed as a woman.',
#   'A certain character is of the female gender.',
#   'Included in the cast is a character of the female gender.',
#   'The ensemble includes a character who is a woman.',
#   'One character in the narrative identifies as female.',
#   "Among the cast, there's a character who is a woman.",
#   'A female presence is found among the characters.',
#   'A character within the story is identified as female.',
#   'There is a character who identifies as female.',
#   'Among the cast, there is a female character.',
#   'A female is included among the characters.',
#   'Included among the characters is a female figure.',
#   'Among the characters, there is a female.',
#   'There is a female figure among the character lineup.',
#   'There is one female character featured in the ensemble.',
#   'Among the various characters is a female.',
#   'One individual in the character roster is female.',
#   'In the ensemble, there is a female character.',
#   'In the mix of characters, there’s a female figure.',
#   'One character represented is identified as female.',
#   'Among the characters, there is one who is a woman.',
#   "There is a presence of a female character within the story's roster.",
#   'Among those depicted, one character is a woman.',
#   'There exists a character within the story who identifies as female.',
#   'In the cast of characters, one is identified as female.',
#   'One character happens to be of the female gender.',
#   'Included in the character roster is a woman.',
#   'A woman appears as one of the featured characters.',
#   'One of the characters portrays a woman.',
#   'The ensemble features at least one character who is of the female sex.',
#   'A woman forms part of the character lineup.',
#   'There is a female entity among the characters.',
#   'Among the various characters, one is a female.',
#   'Among the characters, one is a woman.',
#   'A female figure is represented among the characters.',
#   'A woman is among the characters that populate the story.',
#   'Included in this group of characters is a female representation.',
#   'One of the roles is filled by a female character.',
#   'Notably, there is a character of the female variety.',
#   'There exists a female character within the group.',
#   'A female presence can be found within the character lineup.',
#   'A character in the narrative is female.',
#   'A female presence can be found among the characters.',
#   'A female character is included in the list of characters.',
#   'A woman is represented as one of the characters.',
#   'A female character is included in the ensemble.',
#   'There is a woman among the cast of characters.',
#   'There’s a character in the group that is a female.',
#   'One character is designated as female.',
#   'There exists a female character among those portrayed.',
#   'In the group of characters, one happens to be a woman.',
#   'A female individual is part of the character lineup.',
#   'In the mix of characters, one is distinctly female.',
#   'Among the characters, one is a female figure.',
#   'Within the cast of characters, there is a notable female figure.',
#   'The story features a character who is female.',
#   'Among the ensemble is a female character.',
#   'There exists a female among the characters.',
#   'Included in the cast is a female character.',
#   'One character within the narrative is of the female gender.',
#   'One of the individuals depicted is a female.',
#   'In the character set, there is a female member.',
#   'One of the depicted characters is of the female gender.',
#   'One of the personas in the narrative is that of a woman.',
#   'A character of the female gender is included in the story.',
#   'One character happens to be a woman.',
#   'Among those in the narrative, one character is female.',
#   'One character stands out as being female.',
#   'One character within the story is distinctly female.',
#   'Included in the character lineup is a female figure.',
#   'In the array of characters presented, one is female.',
#   'One individual in the cast is a woman.',
#   'Among the featured characters, one is female.',
#   'Within the characters, one is acknowledged as female.',
#   'A character is depicted as a woman.',
#   'There is a female presence among the characters.',
#   'A single character in the ensemble is female.',
#   'Included in the narrative is a character who is female.',
#   'One character is distinctly female.',
#   'A female character is among the cast.',
#   'A woman serves as one of the characters involved.',
#   'Among the various characters, there stands a woman.',
#   'In the group of characters, one is identified as female.',
#   'The cast includes at least one female character.',
#   'One member of the cast is a female character.',
#   'A female character is included among the cast.',
#   'Among the characters, there is a woman.',
#   'A woman represents one of the characters.',
#   'Included among the characters is a feminine figure.',
#   'Within the characters, one of them is female.',
#   'One character stands out as female.',
#   'In this assembly of characters, one is identified as female.',
#   'Included in the characters is a woman.',
#   'The cast features a character that is a woman.',
#   'A character with a female identity is part of the story.',
#   'One of the individuals in the narrative is a woman.',
#   'In the cast of characters, one is female.',
#   'One of the individuals in the narrative is female.',
#   'One of the individuals depicted is a woman.',
#   'One character distinctly belongs to the female gender.',
#   'One character represented is of the female gender.',
#   'Within the character list, a female presence can be found.',
#   'In this narrative, there is a character that is a woman.',
#   'There is one female character in the lineup.',
#   'Among the characters depicted, one of them is female.',
#   'One of the roles is portrayed by a woman.',
#   "Among the various characters, there's one who is a female.",
#   'In this tale, one character stands out as a woman.',
#   'There is a female character featured in the story.',
#   'A character with a female identity is present.',
#   'A woman features as one of the personalities in the tale.',
#   'There is one character who is depicted as a woman.',
#   'A woman features as one of the characters.',
#   'Among the individuals in the story, one is a woman.',
#   'One character in the story identifies as female.',
#   'The lineup encompasses a character who is female.',
#   'One character stands out as a female.',
#   'A woman is represented among the characters.',
#   'The story contains a female character.',
#   'There exists a female character in the narrative.',
#   'One of the personalities introduced is female.',
#   'A character in the story is a woman.',
#   'The character roster includes a woman.',
#   'One of the individuals in the story is a woman.',
#   'The cast includes a character who identifies as female.',
#   'There is a woman among the characters depicted.',
#   'There exists a character who is female.',
#   'One individual in the character lineup is female.',
#   'One character in the story is portrayed as female.',
#   'Included among the characters is a woman.',
#   'Among the different roles, one is portrayed by a female.',
#   'Within the cast, one character is of the female persuasion.',
#   'There exists a female character among them.',
#   'The cast includes a character who is female.',
#   'One of the roles is played by a female character.',
#   'Featured among the characters is a female individual.',
#   'One character in the story is a female.',
#   'In the narrative, a character of the female gender exists.',
#   'One of the roles in the story is played by a woman.',
#   'One of the portrayed characters happens to be a woman.',
#   'Among the personalities depicted, one is a woman.',
#   'A woman is featured as one of the characters.',
#   'One character, specifically, is female.',
#   'Included in the cast is a woman character.',
#   'One character in the story is of the female gender.',
#   'A character of the female sex appears in the story.',
#   'Among the characters, at least one is a woman.']}
