# %%
import json
import os
import shutil
import glob
import time

import pandas as pd

from io import StringIO
from openai import OpenAI

# %%
credential_loc = "../../credentials.json"
batch_loc = "../../../../datasets/blogger/batch/"
batch_sent_loc = "../../../../datasets/blogger/batch_sent/"
batch_complete_loc = "../../../../datasets/blogger/batch_complete/"

# %%
with open(credential_loc, 'r') as f:
    data = json.load(f)
    
os.environ["OPENAI_API_KEY"] = data['OPENAI_API_KEY']

client = OpenAI()

# %%
# List all .jsonl files in the batch_loc directory
files_to_be_processed = [
    f for f in os.listdir(batch_loc)
    if os.path.isfile(os.path.join(batch_loc, f)) and f.endswith('.jsonl')
]

# %%
len(files_to_be_processed)
# Out:
# 100

# %%
# Function to process a single file with a custom description
def process_file(file_path, description):
    # Open the file and create a batch input file
    with open(file_path, "rb") as f:
        batch_input_file = client.files.create(file=f, purpose="batch")
    
    batch_input_file_id = batch_input_file.id

    # Create a batch job with the batch input file and custom description
    client.batches.create(
        input_file_id=batch_input_file_id,
        endpoint="/v1/chat/completions",
        completion_window="24h",
        metadata={
            "description": description
        }
    )
    print(f"Processed file: {file_path} with description: {description}")

# %%
def process_all_files(batch_loc, batch_sent_loc, files, batch_size=5, wait_time=600):

    total_files = len(files)
    
    for i in range(0, total_files, batch_size):
        batch_files = files[i:i+batch_size]
        
        for file_name in batch_files:
            file_path = os.path.join(batch_loc, file_name)
            description = os.path.splitext(file_name)[0]
            process_file(file_path, description)
            
            # Move the processed file to batch_sent_loc directory
            shutil.move(file_path, os.path.join(batch_sent_loc, file_name))
            print(f"Moved file: {file_name} to {batch_sent_loc}")
        
        print(f"Processed {len(batch_files)} files. Waiting for {wait_time} seconds...")
        time.sleep(wait_time)  # Wait for the specified time before processing the next batch

    print("All files processed and moved successfully.")

# %%
def save_as_jsonl(data, output_file_path):
    with open(output_file_path, 'w') as file:
        for _, row in data.iterrows():
            json.dump(row.to_dict(), file)
            file.write('\n')

# %%
process_all_files(batch_loc, batch_sent_loc, files_to_be_processed)
# Out:
# Processed file: ../../../../datasets/blogger/batch/batch_617540.jsonl with description: batch_617540
# Moved file: batch_617540.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_579188.jsonl with description: batch_579188
# Moved file: batch_579188.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_448015.jsonl with description: batch_448015
# Moved file: batch_448015.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_671397.jsonl with description: batch_671397
# Moved file: batch_671397.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_543206.jsonl with description: batch_543206
# Moved file: batch_543206.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_17850.jsonl with description: batch_17850
# Moved file: batch_17850.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_429760.jsonl with description: batch_429760
# Moved file: batch_429760.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_357437.jsonl with description: batch_357437
# Moved file: batch_357437.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_445957.jsonl with description: batch_445957
# Moved file: batch_445957.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_349665.jsonl with description: batch_349665
# Moved file: batch_349665.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_323518.jsonl with description: batch_323518
# Moved file: batch_323518.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_214228.jsonl with description: batch_214228
# Moved file: batch_214228.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_526719.jsonl with description: batch_526719
# Moved file: batch_526719.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_350617.jsonl with description: batch_350617
# Moved file: batch_350617.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_184355.jsonl with description: batch_184355
# Moved file: batch_184355.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_202213.jsonl with description: batch_202213
# Moved file: batch_202213.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_334376.jsonl with description: batch_334376
# Moved file: batch_334376.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_530975.jsonl with description: batch_530975
# Moved file: batch_530975.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_341238.jsonl with description: batch_341238
# Moved file: batch_341238.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_678838.jsonl with description: batch_678838
# Moved file: batch_678838.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_144356.jsonl with description: batch_144356
# Moved file: batch_144356.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_297972.jsonl with description: batch_297972
# Moved file: batch_297972.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_481359.jsonl with description: batch_481359
# Moved file: batch_481359.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_343349.jsonl with description: batch_343349
# Moved file: batch_343349.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_175880.jsonl with description: batch_175880
# Moved file: batch_175880.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_18516.jsonl with description: batch_18516
# Moved file: batch_18516.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_57262.jsonl with description: batch_57262
# Moved file: batch_57262.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_542822.jsonl with description: batch_542822
# Moved file: batch_542822.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_288775.jsonl with description: batch_288775
# Moved file: batch_288775.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_306438.jsonl with description: batch_306438
# Moved file: batch_306438.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_125908.jsonl with description: batch_125908
# Moved file: batch_125908.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_207710.jsonl with description: batch_207710
# Moved file: batch_207710.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_124522.jsonl with description: batch_124522
# Moved file: batch_124522.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_506923.jsonl with description: batch_506923
# Moved file: batch_506923.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_37303.jsonl with description: batch_37303
# Moved file: batch_37303.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_402496.jsonl with description: batch_402496
# Moved file: batch_402496.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_560732.jsonl with description: batch_560732
# Moved file: batch_560732.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_621278.jsonl with description: batch_621278
# Moved file: batch_621278.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_397139.jsonl with description: batch_397139
# Moved file: batch_397139.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_99088.jsonl with description: batch_99088
# Moved file: batch_99088.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_16188.jsonl with description: batch_16188
# Moved file: batch_16188.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_597056.jsonl with description: batch_597056
# Moved file: batch_597056.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_110133.jsonl with description: batch_110133
# Moved file: batch_110133.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_274759.jsonl with description: batch_274759
# Moved file: batch_274759.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_483447.jsonl with description: batch_483447
# Moved file: batch_483447.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_452954.jsonl with description: batch_452954
# Moved file: batch_452954.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_67056.jsonl with description: batch_67056
# Moved file: batch_67056.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_623524.jsonl with description: batch_623524
# Moved file: batch_623524.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_207833.jsonl with description: batch_207833
# Moved file: batch_207833.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_26252.jsonl with description: batch_26252
# Moved file: batch_26252.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_544873.jsonl with description: batch_544873
# Moved file: batch_544873.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_317636.jsonl with description: batch_317636
# Moved file: batch_317636.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_433589.jsonl with description: batch_433589
# Moved file: batch_433589.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_505205.jsonl with description: batch_505205
# Moved file: batch_505205.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_425775.jsonl with description: batch_425775
# Moved file: batch_425775.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_49343.jsonl with description: batch_49343
# Moved file: batch_49343.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_490831.jsonl with description: batch_490831
# Moved file: batch_490831.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_183047.jsonl with description: batch_183047
# Moved file: batch_183047.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_669029.jsonl with description: batch_669029
# Moved file: batch_669029.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_270402.jsonl with description: batch_270402
# Moved file: batch_270402.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_148224.jsonl with description: batch_148224
# Moved file: batch_148224.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_488822.jsonl with description: batch_488822
# Moved file: batch_488822.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_398279.jsonl with description: batch_398279
# Moved file: batch_398279.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_178480.jsonl with description: batch_178480
# Moved file: batch_178480.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_279772.jsonl with description: batch_279772
# Moved file: batch_279772.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...
# Processed file: ../../../../datasets/blogger/batch/batch_509577.jsonl with description: batch_509577
# Moved file: batch_509577.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_325534.jsonl with description: batch_325534
# Moved file: batch_325534.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_116471.jsonl with description: batch_116471
# Moved file: batch_116471.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_274492.jsonl with description: batch_274492
# Moved file: batch_274492.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed file: ../../../../datasets/blogger/batch/batch_222624.jsonl with description: batch_222624
# Moved file: batch_222624.jsonl to ../../../../datasets/blogger/batch_sent/
# Processed 5 files. Waiting for 600 seconds...

# %%
def fetch_batches(client, after=None):
    """
    Fetch batches from the client, optionally using an 'after' parameter to paginate.
    
    :param client: API client instance.
    :param after: The ID to paginate after.
    :return: List of batch data.
    """
    response = client.batches.list(limit=100, after=after)
    return response.data

def process_batches(client):
    """
    Process batches by fetching data, sorting, and paginating until no new data is retrieved.
    
    :param client: API client instance.
    :return: DataFrame containing all batch data.
    """
    batch_data = []
    after = None

    while True:
        # Fetch the current batch of data
        current_batches = fetch_batches(client, after)
        if not current_batches:
            print("No more batches to fetch.")
            break
        
        # Extract attributes and convert to DataFrame
        for batch in current_batches:
            batch_dict = {
                "id": batch.id,
                "completion_window": batch.completion_window,
                "created_at": batch.created_at,
                "endpoint": batch.endpoint,
                "input_file_id": batch.input_file_id,
                "object": batch.object,
                "status": batch.status,
                "cancelled_at": batch.cancelled_at,
                "cancelling_at": batch.cancelling_at,
                "completed_at": batch.completed_at,
                "error_file_id": batch.error_file_id,
                "errors": batch.errors,
                "expired_at": batch.expired_at,
                "expires_at": batch.expires_at,
                "failed_at": batch.failed_at,
                "finalizing_at": batch.finalizing_at,
                "in_progress_at": batch.in_progress_at,
                "metadata_description": batch.metadata.get('description', ''),
                "output_file_id": batch.output_file_id,
                "request_counts_completed": batch.request_counts.completed,
                "request_counts_failed": batch.request_counts.failed,
                "request_counts_total": batch.request_counts.total
            }
            batch_data.append(batch_dict)
        
        # Create a DataFrame from the current batch data
        batch_df = pd.DataFrame(batch_data)

        # Remove duplicate rows based on 'id'
        batch_df.drop_duplicates(subset='id', keep='last', inplace=True)
        
        # Sort DataFrame by 'created_at' column
        batch_df.sort_values(by='created_at', ascending=True, inplace=True)
        
        # Print the current DataFrame state for debugging
        print(f"Current DataFrame shape: {batch_df.shape}")
        
        # Update the 'after' parameter with the last batch ID for pagination
        last_batch_id = batch_df['id'].iloc[-1] if not batch_df.empty else None
        if last_batch_id == after:
            print("No new batches found.")
            break
        after = last_batch_id
    
    return batch_df

# %%
fetch_batches(client)
# Out:
# [Batch(id='batch_jRRojB26n3wM9pkna1Tamd69', completion_window='24h', created_at=1721670154, endpoint='/v1/chat/completions', input_file_id='file-mmClbX7uN1plVQhK4BmFT6sN', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721673102, error_file_id=None, errors=None, expired_at=None, expires_at=1721756554, failed_at=None, finalizing_at=1721673082, in_progress_at=1721670155, metadata={'description': 'batch_175880'}, output_file_id='file-QYD7udnx7EQvDBuKYqKnVGvl', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_dMm2cYSOrJPyxHNx6bipGaHT', completion_window='24h', created_at=1721670152, endpoint='/v1/chat/completions', input_file_id='file-QSRermrzFeyAJW3cT90zjCty', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721673047, error_file_id=None, errors=None, expired_at=None, expires_at=1721756552, failed_at=None, finalizing_at=1721673032, in_progress_at=1721670153, metadata={'description': 'batch_343349'}, output_file_id='file-dASMHkiUHWwNlSp1PTFFx0ms', request_counts=BatchRequestCounts(completed=220, failed=0, total=220)),
#  Batch(id='batch_K6ana5hWUwcOT46nXpNTEaMZ', completion_window='24h', created_at=1721670150, endpoint='/v1/chat/completions', input_file_id='file-LZlnJiCcoue67WwpbZXmECET', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721673100, error_file_id=None, errors=None, expired_at=None, expires_at=1721756550, failed_at=None, finalizing_at=1721673072, in_progress_at=1721670151, metadata={'description': 'batch_481359'}, output_file_id='file-jRElURO8kUTHsvQzbw7rzkKe', request_counts=BatchRequestCounts(completed=420, failed=0, total=420)),
#  Batch(id='batch_qGxqVjbUgI9SmD5tiNaPLATq', completion_window='24h', created_at=1721670149, endpoint='/v1/chat/completions', input_file_id='file-5B1Q1LqUAKDgSJwmGFkySe3T', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721673005, error_file_id=None, errors=None, expired_at=None, expires_at=1721756549, failed_at=None, finalizing_at=1721672988, in_progress_at=1721670150, metadata={'description': 'batch_297972'}, output_file_id='file-mhTquJhjIjZQubHuTuRkhRm4', request_counts=BatchRequestCounts(completed=240, failed=0, total=240)),
#  Batch(id='batch_SGYOGTikWGp8YGQAU5Mk6xAB', completion_window='24h', created_at=1721670147, endpoint='/v1/chat/completions', input_file_id='file-p6nTrVcQ7c1SJWaRuhiZs441', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721673007, error_file_id=None, errors=None, expired_at=None, expires_at=1721756547, failed_at=None, finalizing_at=1721672987, in_progress_at=1721670148, metadata={'description': 'batch_678838'}, output_file_id='file-vqynRBbBLwrbXHJQ7hn2a4OD', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_YPBvKKFhz41K76K05z3xhKUQ', completion_window='24h', created_at=1721611048, endpoint='/v1/chat/completions', input_file_id='file-cSS7JY5rEpp6GKGfWfQGn9dZ', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721611259, error_file_id=None, errors=None, expired_at=None, expires_at=1721697448, failed_at=None, finalizing_at=1721611245, in_progress_at=1721611049, metadata={'description': 'batch_171105'}, output_file_id='file-kVEVcCuRE0SukQE00Md76qDj', request_counts=BatchRequestCounts(completed=360, failed=0, total=360)),
#  Batch(id='batch_F3HkDhT9AIP5BXPY58MASKNJ', completion_window='24h', created_at=1721611047, endpoint='/v1/chat/completions', input_file_id='file-y76MpaM9qjCGnI4hvTxA1MnJ', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721611252, error_file_id=None, errors=None, expired_at=None, expires_at=1721697447, failed_at=None, finalizing_at=1721611245, in_progress_at=1721611047, metadata={'description': 'batch_463289'}, output_file_id='file-iKTMJJmMFWEv59M3CQk6Dd09', request_counts=BatchRequestCounts(completed=150, failed=0, total=150)),
#  Batch(id='batch_T1Ol5j2QePjqV0xNGoH0c7pM', completion_window='24h', created_at=1721610545, endpoint='/v1/chat/completions', input_file_id='file-1Uli9XRn7Ai9CJUdoHiu2vZW', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610839, error_file_id=None, errors=None, expired_at=None, expires_at=1721696945, failed_at=None, finalizing_at=1721610821, in_progress_at=1721610546, metadata={'description': 'batch_491687'}, output_file_id='file-0CiPpS2fmDbuJYCHpSbcJOe6', request_counts=BatchRequestCounts(completed=480, failed=0, total=480)),
#  Batch(id='batch_7PT7lqoPlGqx04jUhGPW0EsK', completion_window='24h', created_at=1721610543, endpoint='/v1/chat/completions', input_file_id='file-UWQF3oJm7HYJcLqQhStoc7U4', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610873, error_file_id=None, errors=None, expired_at=None, expires_at=1721696943, failed_at=None, finalizing_at=1721610863, in_progress_at=1721610544, metadata={'description': 'batch_551652'}, output_file_id='file-wZOAeKNCkOvxNcIE5UbBHnW4', request_counts=BatchRequestCounts(completed=250, failed=0, total=250)),
#  Batch(id='batch_s5QkFr2x6SKdt7RhXBQefBfR', completion_window='24h', created_at=1721610541, endpoint='/v1/chat/completions', input_file_id='file-bo6sV9FD8ZwWaadPQLtDJ4Ov', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610801, error_file_id=None, errors=None, expired_at=None, expires_at=1721696941, failed_at=None, finalizing_at=1721610790, in_progress_at=1721610542, metadata={'description': 'batch_585356'}, output_file_id='file-in1an4RiYXLWZyWPA6p1VXWh', request_counts=BatchRequestCounts(completed=300, failed=0, total=300)),
#  Batch(id='batch_0OVGSwg3M1uU1a1UKuVsikuL', completion_window='24h', created_at=1721610539, endpoint='/v1/chat/completions', input_file_id='file-v2agyYCtVVOVCpnDNMuY5Bb8', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610858, error_file_id=None, errors=None, expired_at=None, expires_at=1721696939, failed_at=None, finalizing_at=1721610824, in_progress_at=1721610541, metadata={'description': 'batch_552933'}, output_file_id='file-ksGl8jRKSUWVK626SCfxFPEa', request_counts=BatchRequestCounts(completed=940, failed=0, total=940)),
#  Batch(id='batch_WG5vExtdlp2mf5BF2aK8zxmz', completion_window='24h', created_at=1721610537, endpoint='/v1/chat/completions', input_file_id='file-aoPjRsJfiMZ6h4Mp5JVcWAlu', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610821, error_file_id=None, errors=None, expired_at=None, expires_at=1721696937, failed_at=None, finalizing_at=1721610809, in_progress_at=1721610538, metadata={'description': 'batch_327604'}, output_file_id='file-4EOTwyjrZHfojqTcME6OPCvU', request_counts=BatchRequestCounts(completed=330, failed=0, total=330)),
#  Batch(id='batch_6URha4x6ZxU6vUS68Dm4eAr5', completion_window='24h', created_at=1721610035, endpoint='/v1/chat/completions', input_file_id='file-iUVrbvqavUYcvbf0RMVJWKej', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610441, error_file_id=None, errors=None, expired_at=None, expires_at=1721696435, failed_at=None, finalizing_at=1721610426, in_progress_at=1721610036, metadata={'description': 'batch_611550'}, output_file_id='file-DOvnC1ikhZ2kl2ODLznZBari', request_counts=BatchRequestCounts(completed=400, failed=0, total=400)),
#  Batch(id='batch_JVzKVlzI5yQmw6wocl9oYaSu', completion_window='24h', created_at=1721610033, endpoint='/v1/chat/completions', input_file_id='file-TunD2LSOgFZ8e9438PxSYhkA', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610431, error_file_id=None, errors=None, expired_at=None, expires_at=1721696433, failed_at=None, finalizing_at=1721610423, in_progress_at=1721610035, metadata={'description': 'batch_291125'}, output_file_id='file-4K5ji697CdneAayQQ5zWR9qx', request_counts=BatchRequestCounts(completed=220, failed=0, total=220)),
#  Batch(id='batch_w1qhQr0PsVfuiqFryyKZv9c3', completion_window='24h', created_at=1721610031, endpoint='/v1/chat/completions', input_file_id='file-WCZfMaAMqR7xM7HyySxi6Di5', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610426, error_file_id=None, errors=None, expired_at=None, expires_at=1721696431, failed_at=None, finalizing_at=1721610416, in_progress_at=1721610033, metadata={'description': 'batch_331546'}, output_file_id='file-twXsdXAFd5t0robGI3vdma7l', request_counts=BatchRequestCounts(completed=230, failed=0, total=230)),
#  Batch(id='batch_bOV6gFIkdGhahZy0HU3y00dW', completion_window='24h', created_at=1721610029, endpoint='/v1/chat/completions', input_file_id='file-sikH4WFHq97xW3nYOvb0XFx6', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610425, error_file_id=None, errors=None, expired_at=None, expires_at=1721696429, failed_at=None, finalizing_at=1721610413, in_progress_at=1721610031, metadata={'description': 'batch_579184'}, output_file_id='file-qtilowTcscRL73DlOlCLz8LJ', request_counts=BatchRequestCounts(completed=320, failed=0, total=320)),
#  Batch(id='batch_0xAc9NqlWLrroybKc4QRhAJW', completion_window='24h', created_at=1721610027, endpoint='/v1/chat/completions', input_file_id='file-gVtzcmARIEmIjq327cPR1qM0', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610432, error_file_id=None, errors=None, expired_at=None, expires_at=1721696427, failed_at=None, finalizing_at=1721610423, in_progress_at=1721610028, metadata={'description': 'batch_394143'}, output_file_id='file-0A7qLUdP6D1E2XAE7qtI79Me', request_counts=BatchRequestCounts(completed=230, failed=0, total=230)),
#  Batch(id='batch_tHWNbhq7nLJyiOfnPGKp2Ri9', completion_window='24h', created_at=1721609525, endpoint='/v1/chat/completions', input_file_id='file-gEZvldSe7joUJfo17pEBIDPw', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721609641, error_file_id=None, errors=None, expired_at=None, expires_at=1721695925, failed_at=None, finalizing_at=1721609628, in_progress_at=1721609526, metadata={'description': 'batch_219981'}, output_file_id='file-L8Zw1Fl9UXHVUI3L8Wll4oHL', request_counts=BatchRequestCounts(completed=350, failed=0, total=350)),
#  Batch(id='batch_KFR3zAXCfUYU9DeVXjIqYERW', completion_window='24h', created_at=1721609523, endpoint='/v1/chat/completions', input_file_id='file-fYADc1aEaS2jExiv3z5V57d1', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721609657, error_file_id=None, errors=None, expired_at=None, expires_at=1721695923, failed_at=None, finalizing_at=1721609641, in_progress_at=1721609525, metadata={'description': 'batch_363388'}, output_file_id='file-0gPlWhnIdkiI5ZNnRlJXDeTw', request_counts=BatchRequestCounts(completed=440, failed=0, total=440)),
#  Batch(id='batch_vCZIEqbKH1l5q1HrlVD2yZzD', completion_window='24h', created_at=1721609521, endpoint='/v1/chat/completions', input_file_id='file-bTvT9rSX9DmsMWzabawTnQmO', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721609642, error_file_id=None, errors=None, expired_at=None, expires_at=1721695921, failed_at=None, finalizing_at=1721609625, in_progress_at=1721609522, metadata={'description': 'batch_183886'}, output_file_id='file-cvZHQNrIxP3xNoKVnwxtSOcG', request_counts=BatchRequestCounts(completed=490, failed=0, total=490)),
#  Batch(id='batch_6m6uX9xoMQ0wQsk8M4Rh6Xa3', completion_window='24h', created_at=1721609519, endpoint='/v1/chat/completions', input_file_id='file-0HedBcJuegJwgc1KPf0UtR0o', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721609700, error_file_id=None, errors=None, expired_at=None, expires_at=1721695919, failed_at=None, finalizing_at=1721609624, in_progress_at=1721609519, metadata={'description': 'batch_82243'}, output_file_id='file-Gc8d2XAXWVCEugfScDyz92Qq', request_counts=BatchRequestCounts(completed=480, failed=0, total=480)),
#  Batch(id='batch_EFwmw7aTd02j9Or2uCSmUuGL', completion_window='24h', created_at=1721609517, endpoint='/v1/chat/completions', input_file_id='file-hAPoUQeapq7texZqZp68OFJ7', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721609640, error_file_id=None, errors=None, expired_at=None, expires_at=1721695917, failed_at=None, finalizing_at=1721609626, in_progress_at=1721609518, metadata={'description': 'batch_496050'}, output_file_id='file-EkUIGO0fMjvhYhnOgUEVH7HZ', request_counts=BatchRequestCounts(completed=390, failed=0, total=390)),
#  Batch(id='batch_g72dSaEl7VqWYFWSqKhLJxLO', completion_window='24h', created_at=1721609015, endpoint='/v1/chat/completions', input_file_id='file-t27xGV2zCssF5hZNShDi5adM', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610202, error_file_id=None, errors=None, expired_at=None, expires_at=1721695415, failed_at=None, finalizing_at=1721610187, in_progress_at=1721609015, metadata={'description': 'batch_272513'}, output_file_id='file-clp69VnKTgYQMbGflsRKABsU', request_counts=BatchRequestCounts(completed=230, failed=0, total=230)),
#  Batch(id='batch_UeCrJii8Tuqy1vFNeDWcLYVz', completion_window='24h', created_at=1721609014, endpoint='/v1/chat/completions', input_file_id='file-tnKUdHfAC9BjgACbBATdvvrJ', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610205, error_file_id=None, errors=None, expired_at=None, expires_at=1721695414, failed_at=None, finalizing_at=1721610187, in_progress_at=1721609014, metadata={'description': 'batch_607120'}, output_file_id='file-YkqtDsFuLVQSLkpcurlEzomB', request_counts=BatchRequestCounts(completed=270, failed=0, total=270)),
#  Batch(id='batch_x439tuQUvYYTfqSLMFr3yz5I', completion_window='24h', created_at=1721609012, endpoint='/v1/chat/completions', input_file_id='file-pQrcfFbawrH1SHYTxv2AaeUK', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610165, error_file_id=None, errors=None, expired_at=None, expires_at=1721695412, failed_at=None, finalizing_at=1721610133, in_progress_at=1721609013, metadata={'description': 'batch_306449'}, output_file_id='file-uEtRqQ2rMWQ5iwoHcO9m1h1F', request_counts=BatchRequestCounts(completed=590, failed=0, total=590)),
#  Batch(id='batch_WabGVPn88d4awPH7zOXdKJzi', completion_window='24h', created_at=1721609011, endpoint='/v1/chat/completions', input_file_id='file-lQYzk7r9CgMNAbIHEHN4uNuF', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721610190, error_file_id=None, errors=None, expired_at=None, expires_at=1721695411, failed_at=None, finalizing_at=1721610178, in_progress_at=1721609012, metadata={'description': 'batch_676573'}, output_file_id='file-iWaYYi9M6LfJ4gIJ4aRtjvYW', request_counts=BatchRequestCounts(completed=190, failed=0, total=190)),
#  Batch(id='batch_N0WXxNlYIlJdxLwINncLtl6Z', completion_window='24h', created_at=1721609010, endpoint='/v1/chat/completions', input_file_id='file-X31ALm5AwaB8B8Pxb5NoMjkn', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721609707, error_file_id=None, errors=None, expired_at=None, expires_at=1721695410, failed_at=None, finalizing_at=1721609698, in_progress_at=1721609010, metadata={'description': 'batch_546588'}, output_file_id='file-Ae26JLsbafiPSBT9i748nzXw', request_counts=BatchRequestCounts(completed=190, failed=0, total=190)),
#  Batch(id='batch_jAiJ3LRdzfVMK4tqsiyYMn5T', completion_window='24h', created_at=1721608508, endpoint='/v1/chat/completions', input_file_id='file-RhPLNDOc4rWacalCnX1D0hsa', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608614, error_file_id=None, errors=None, expired_at=None, expires_at=1721694908, failed_at=None, finalizing_at=1721608566, in_progress_at=1721608509, metadata={'description': 'batch_517663'}, output_file_id='file-j0Y5qDYlrlpM1zLsy0EIgKWU', request_counts=BatchRequestCounts(completed=370, failed=0, total=370)),
#  Batch(id='batch_OODFPARuG6miDKQAKgMhrZ0D', completion_window='24h', created_at=1721608506, endpoint='/v1/chat/completions', input_file_id='file-c38lkBlkkhHyNtCOJ9Zkb7FN', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608573, error_file_id=None, errors=None, expired_at=None, expires_at=1721694906, failed_at=None, finalizing_at=1721608565, in_progress_at=1721608507, metadata={'description': 'batch_122748'}, output_file_id='file-ljOSBPQogWPsYiLEkyyBGRsk', request_counts=BatchRequestCounts(completed=210, failed=0, total=210)),
#  Batch(id='batch_76FszZz3wIQSdD8wguw4WhWx', completion_window='24h', created_at=1721608505, endpoint='/v1/chat/completions', input_file_id='file-823z6Hlw5CDNHvT3I9wPajRg', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608591, error_file_id=None, errors=None, expired_at=None, expires_at=1721694905, failed_at=None, finalizing_at=1721608578, in_progress_at=1721608506, metadata={'description': 'batch_114599'}, output_file_id='file-9WeVUVqZZ8nikWoA6kWbtQjQ', request_counts=BatchRequestCounts(completed=340, failed=0, total=340)),
#  Batch(id='batch_qRhRtMfjK3oQTS0QdtSAgQMV', completion_window='24h', created_at=1721608502, endpoint='/v1/chat/completions', input_file_id='file-w9JNcQaIQspr0aqYTqkn6myl', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608578, error_file_id=None, errors=None, expired_at=None, expires_at=1721694902, failed_at=None, finalizing_at=1721608565, in_progress_at=1721608503, metadata={'description': 'batch_174699'}, output_file_id='file-jWj3WuHTdWcv9itTQLA5ocRU', request_counts=BatchRequestCounts(completed=310, failed=0, total=310)),
#  Batch(id='batch_OVCDnLKvnT95TFfc8xY4ZpOD', completion_window='24h', created_at=1721608500, endpoint='/v1/chat/completions', input_file_id='file-iwItSwCD1og3ONYPCIdT3Gac', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608581, error_file_id=None, errors=None, expired_at=None, expires_at=1721694900, failed_at=None, finalizing_at=1721608569, in_progress_at=1721608502, metadata={'description': 'batch_155142'}, output_file_id='file-PV4q8l1B956GX8bMhLfdzN7r', request_counts=BatchRequestCounts(completed=290, failed=0, total=290)),
#  Batch(id='batch_dqcUBDx1fAKtzhHUaXsgBAWW', completion_window='24h', created_at=1721607998, endpoint='/v1/chat/completions', input_file_id='file-DLNEKO4IE6i0H5GCVSi8BgJc', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608071, error_file_id=None, errors=None, expired_at=None, expires_at=1721694398, failed_at=None, finalizing_at=1721608062, in_progress_at=1721608000, metadata={'description': 'batch_222624'}, output_file_id='file-CkFZtfi3cV402Mtwg7DF718e', request_counts=BatchRequestCounts(completed=260, failed=0, total=260)),
#  Batch(id='batch_CcEtHH81GaAEXSNFLIdGq5Mc', completion_window='24h', created_at=1721607996, endpoint='/v1/chat/completions', input_file_id='file-GlDdCTmH0FB5ScKztBS9hbn7', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608105, error_file_id=None, errors=None, expired_at=None, expires_at=1721694396, failed_at=None, finalizing_at=1721608062, in_progress_at=1721607997, metadata={'description': 'batch_274492'}, output_file_id='file-bddOntqDgJf2MOU8DS1C69Gu', request_counts=BatchRequestCounts(completed=370, failed=0, total=370)),
#  Batch(id='batch_Z8iSIFY7EQAK8SglgHehr7rN', completion_window='24h', created_at=1721607994, endpoint='/v1/chat/completions', input_file_id='file-unmkyusaFwJ1eWkkbhAT6c9i', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608075, error_file_id=None, errors=None, expired_at=None, expires_at=1721694394, failed_at=None, finalizing_at=1721608062, in_progress_at=1721607995, metadata={'description': 'batch_116471'}, output_file_id='file-QwBT9KSlyC5bZW3AAZ5POyKR', request_counts=BatchRequestCounts(completed=370, failed=0, total=370)),
#  Batch(id='batch_o8G264IVBJwHdU47vNarAYPX', completion_window='24h', created_at=1721607993, endpoint='/v1/chat/completions', input_file_id='file-Rfn6t9U9beDFSgjJ54NFFhxy', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608070, error_file_id=None, errors=None, expired_at=None, expires_at=1721694393, failed_at=None, finalizing_at=1721608062, in_progress_at=1721607994, metadata={'description': 'batch_325534'}, output_file_id='file-SduT0dobRfz11NGO8GkFIkyQ', request_counts=BatchRequestCounts(completed=200, failed=0, total=200)),
#  Batch(id='batch_KRrUTvw1zpQbnJCGdL6GOeoC', completion_window='24h', created_at=1721607991, endpoint='/v1/chat/completions', input_file_id='file-ylETCRgdNsoQkythBqv8rYFK', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721608071, error_file_id=None, errors=None, expired_at=None, expires_at=1721694391, failed_at=None, finalizing_at=1721608062, in_progress_at=1721607992, metadata={'description': 'batch_509577'}, output_file_id='file-VeOikVSPURApfzbZR6VNAHaf', request_counts=BatchRequestCounts(completed=240, failed=0, total=240)),
#  Batch(id='batch_bGyIyds3o90d4nu0c8yv7R6e', completion_window='24h', created_at=1721607489, endpoint='/v1/chat/completions', input_file_id='file-oY2VGZsoWyM48jQhUpqU9Be6', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607583, error_file_id=None, errors=None, expired_at=None, expires_at=1721693889, failed_at=None, finalizing_at=1721607573, in_progress_at=1721607490, metadata={'description': 'batch_279772'}, output_file_id='file-3f4x58Du30v8H4SfepfVqFGS', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_ybzR6snvNk5YxRyzZvwsLXV3', completion_window='24h', created_at=1721607488, endpoint='/v1/chat/completions', input_file_id='file-FOMS9ZYmaRo6SjCadQJ7ZgV1', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607583, error_file_id=None, errors=None, expired_at=None, expires_at=1721693888, failed_at=None, finalizing_at=1721607573, in_progress_at=1721607488, metadata={'description': 'batch_178480'}, output_file_id='file-fAgS0PiCABmyNDeE6Ehkks2j', request_counts=BatchRequestCounts(completed=300, failed=0, total=300)),
#  Batch(id='batch_ioFiYvS5bjvDyqbPvoQjW0cv', completion_window='24h', created_at=1721607486, endpoint='/v1/chat/completions', input_file_id='file-FooAYK5e0B6eBK5sppe2IZTN', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607658, error_file_id=None, errors=None, expired_at=None, expires_at=1721693886, failed_at=None, finalizing_at=1721607647, in_progress_at=1721607547, metadata={'description': 'batch_398279'}, output_file_id='file-OA4WvC95SBeWADiEQYOJ4FJ2', request_counts=BatchRequestCounts(completed=290, failed=0, total=290)),
#  Batch(id='batch_YG6TBiB1suGHsLgISMwMk8b9', completion_window='24h', created_at=1721607484, endpoint='/v1/chat/completions', input_file_id='file-aubYIIW9FT0eiQxrMP218v6x', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607579, error_file_id=None, errors=None, expired_at=None, expires_at=1721693884, failed_at=None, finalizing_at=1721607569, in_progress_at=1721607485, metadata={'description': 'batch_488822'}, output_file_id='file-Hfaex4KN9FSsWPhnn4aeSto2', request_counts=BatchRequestCounts(completed=250, failed=0, total=250)),
#  Batch(id='batch_NHH8j1Yp3t1nDiTaJgGRW0Nq', completion_window='24h', created_at=1721607483, endpoint='/v1/chat/completions', input_file_id='file-5QRYpZPP0axdGhbm5ONtWCqt', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607588, error_file_id=None, errors=None, expired_at=None, expires_at=1721693883, failed_at=None, finalizing_at=1721607574, in_progress_at=1721607483, metadata={'description': 'batch_148224'}, output_file_id='file-QgEajNQh9QgGIykDmtHSWVQn', request_counts=BatchRequestCounts(completed=400, failed=0, total=400)),
#  Batch(id='batch_rB5H3bccusgMgNrkpKXNicgt', completion_window='24h', created_at=1721606981, endpoint='/v1/chat/completions', input_file_id='file-U1LNu1WsvUEm6h6WQTYcgUEp', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607102, error_file_id=None, errors=None, expired_at=None, expires_at=1721693381, failed_at=None, finalizing_at=1721607089, in_progress_at=1721606982, metadata={'description': 'batch_270402'}, output_file_id='file-NIRhee7R4SuiEe1Mt6JAd76M', request_counts=BatchRequestCounts(completed=310, failed=0, total=310)),
#  Batch(id='batch_5wwA5GF1gfvAoB8EaWQgm0fM', completion_window='24h', created_at=1721606978, endpoint='/v1/chat/completions', input_file_id='file-OK9VZGQN5DFxGWpLvWX9sjgZ', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607062, error_file_id=None, errors=None, expired_at=None, expires_at=1721693378, failed_at=None, finalizing_at=1721607052, in_progress_at=1721606980, metadata={'description': 'batch_669029'}, output_file_id='file-l8OBxXgP2fD3DVRNS4OvUl5n', request_counts=BatchRequestCounts(completed=270, failed=0, total=270)),
#  Batch(id='batch_42D1fU8KVMHjAiZmxF3GmlKi', completion_window='24h', created_at=1721606977, endpoint='/v1/chat/completions', input_file_id='file-HDZvg0VUGyStOOwhipamVvEY', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607063, error_file_id=None, errors=None, expired_at=None, expires_at=1721693377, failed_at=None, finalizing_at=1721607053, in_progress_at=1721606978, metadata={'description': 'batch_183047'}, output_file_id='file-WH2EQxnMhXSp2u8Dn5PNQyVO', request_counts=BatchRequestCounts(completed=290, failed=0, total=290)),
#  Batch(id='batch_5ooN6gDkpXDVTJg5NseBdW9T', completion_window='24h', created_at=1721606975, endpoint='/v1/chat/completions', input_file_id='file-LaGiiJUyzWpqwzeDJibUF1U7', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607111, error_file_id=None, errors=None, expired_at=None, expires_at=1721693375, failed_at=None, finalizing_at=1721607091, in_progress_at=1721606977, metadata={'description': 'batch_490831'}, output_file_id='file-QQxFYk5H2AdT2grVc1Mmf6Af', request_counts=BatchRequestCounts(completed=460, failed=0, total=460)),
#  Batch(id='batch_6bfITkXyhqhr2tUKA8r6CA8b', completion_window='24h', created_at=1721606974, endpoint='/v1/chat/completions', input_file_id='file-gpmkWhWwOUDlEIK59mU2RSW3', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721607084, error_file_id=None, errors=None, expired_at=None, expires_at=1721693374, failed_at=None, finalizing_at=1721607074, in_progress_at=1721606975, metadata={'description': 'batch_49343'}, output_file_id='file-rkHZR3e5WRhxTIkuzQVNI7k0', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_kegVv9Rzo90e8weM7PSnTVzH', completion_window='24h', created_at=1721606472, endpoint='/v1/chat/completions', input_file_id='file-hnL3JgKYvZjmqbNzumUqsemH', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606897, error_file_id=None, errors=None, expired_at=None, expires_at=1721692872, failed_at=None, finalizing_at=1721606886, in_progress_at=1721606473, metadata={'description': 'batch_425775'}, output_file_id='file-kWOwFldqieSoT3BOmHcDCjjU', request_counts=BatchRequestCounts(completed=250, failed=0, total=250)),
#  Batch(id='batch_46VqJl6k4oNjDY43trotVzib', completion_window='24h', created_at=1721606470, endpoint='/v1/chat/completions', input_file_id='file-GkMCJxAgiZ8m59i8wIqjpHPs', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606937, error_file_id=None, errors=None, expired_at=None, expires_at=1721692870, failed_at=None, finalizing_at=1721606913, in_progress_at=1721606472, metadata={'description': 'batch_505205'}, output_file_id='file-CuXh48mkXY2Fh8FtoWloIpj7', request_counts=BatchRequestCounts(completed=550, failed=0, total=550)),
#  Batch(id='batch_A2i1nWd1Ds8KSTvei12ADh5l', completion_window='24h', created_at=1721606469, endpoint='/v1/chat/completions', input_file_id='file-zduBYbPCyjvaR1BJeMLUJvhk', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606946, error_file_id=None, errors=None, expired_at=None, expires_at=1721692869, failed_at=None, finalizing_at=1721606913, in_progress_at=1721606471, metadata={'description': 'batch_433589'}, output_file_id='file-AEW8WsbS27aK581T1rQrKCRV', request_counts=BatchRequestCounts(completed=870, failed=0, total=870)),
#  Batch(id='batch_w8SS7UijoLBr54HP6ZcdYQgr', completion_window='24h', created_at=1721606467, endpoint='/v1/chat/completions', input_file_id='file-lMjxn2RsHwpay2Ot8GJohche', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606899, error_file_id=None, errors=None, expired_at=None, expires_at=1721692867, failed_at=None, finalizing_at=1721606885, in_progress_at=1721606468, metadata={'description': 'batch_317636'}, output_file_id='file-dxHvKnGekFkBqBjX3xNl0ky4', request_counts=BatchRequestCounts(completed=310, failed=0, total=310)),
#  Batch(id='batch_kg8WpJegaaU9nIiWm9pWET9t', completion_window='24h', created_at=1721606465, endpoint='/v1/chat/completions', input_file_id='file-PzcSh8u2cGGBupiBJTnRVmyl', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606931, error_file_id=None, errors=None, expired_at=None, expires_at=1721692865, failed_at=None, finalizing_at=1721606913, in_progress_at=1721606466, metadata={'description': 'batch_544873'}, output_file_id='file-VVSkHfU45K4IgsHqrMC08PhG', request_counts=BatchRequestCounts(completed=430, failed=0, total=430)),
#  Batch(id='batch_P4QbJCWXCNTkBh9TMVmy1gs2', completion_window='24h', created_at=1721605963, endpoint='/v1/chat/completions', input_file_id='file-Gofs5cUKwbNWtJmISjQMWBGi', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606055, error_file_id=None, errors=None, expired_at=None, expires_at=1721692363, failed_at=None, finalizing_at=1721606047, in_progress_at=1721605963, metadata={'description': 'batch_26252'}, output_file_id='file-Ieuw8HGCz2Rw5qaf78l7uur8', request_counts=BatchRequestCounts(completed=220, failed=0, total=220)),
#  Batch(id='batch_014iDnj6Wd0y85jLdipy1Fs1', completion_window='24h', created_at=1721605962, endpoint='/v1/chat/completions', input_file_id='file-Sh01hN2q5NYPy9W245lWJ7jF', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606055, error_file_id=None, errors=None, expired_at=None, expires_at=1721692362, failed_at=None, finalizing_at=1721606044, in_progress_at=1721605962, metadata={'description': 'batch_207833'}, output_file_id='file-c33YLU8vPSzRQEw3kVPKG7NH', request_counts=BatchRequestCounts(completed=320, failed=0, total=320)),
#  Batch(id='batch_bddkwkLXRFYZsO4I1XhFtQe2', completion_window='24h', created_at=1721605960, endpoint='/v1/chat/completions', input_file_id='file-poY9n3AjVAic3dmUmAy5UtGt', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606056, error_file_id=None, errors=None, expired_at=None, expires_at=1721692360, failed_at=None, finalizing_at=1721606047, in_progress_at=1721605960, metadata={'description': 'batch_623524'}, output_file_id='file-aweQENQlB38UVis5qf8gcrCH', request_counts=BatchRequestCounts(completed=230, failed=0, total=230)),
#  Batch(id='batch_XuZG0teb8SxHb8aiHxcD6p6N', completion_window='24h', created_at=1721605959, endpoint='/v1/chat/completions', input_file_id='file-r3OU9rN0fWu2WPCoxZlWzYDA', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606066, error_file_id=None, errors=None, expired_at=None, expires_at=1721692359, failed_at=None, finalizing_at=1721606053, in_progress_at=1721605959, metadata={'description': 'batch_67056'}, output_file_id='file-VtIrwaj9s0A3dOG3BJsBDci3', request_counts=BatchRequestCounts(completed=320, failed=0, total=320)),
#  Batch(id='batch_hhqeEyBgH1hvmgSkDXoh2sEM', completion_window='24h', created_at=1721605957, endpoint='/v1/chat/completions', input_file_id='file-NCzdIseKQrO15RyqJ6b1m0i6', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721606064, error_file_id=None, errors=None, expired_at=None, expires_at=1721692357, failed_at=None, finalizing_at=1721606047, in_progress_at=1721605958, metadata={'description': 'batch_452954'}, output_file_id='file-JmOM0Rcq2BySG9zwnoXcST1P', request_counts=BatchRequestCounts(completed=490, failed=0, total=490)),
#  Batch(id='batch_0x0SG9RlLpkUklT9Wm425uqt', completion_window='24h', created_at=1721605455, endpoint='/v1/chat/completions', input_file_id='file-yWUcE4eJ9QLlq3ehaLBeJJz8', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605520, error_file_id=None, errors=None, expired_at=None, expires_at=1721691855, failed_at=None, finalizing_at=1721605506, in_progress_at=1721605455, metadata={'description': 'batch_483447'}, output_file_id='file-PPRkUoXNgc5ehXeW2mwhYav2', request_counts=BatchRequestCounts(completed=360, failed=0, total=360)),
#  Batch(id='batch_71Z5brbincRwSLY2msGu62yi', completion_window='24h', created_at=1721605453, endpoint='/v1/chat/completions', input_file_id='file-zxgBLz2EITrsr4ANpiU0ENJJ', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605527, error_file_id=None, errors=None, expired_at=None, expires_at=1721691853, failed_at=None, finalizing_at=1721605517, in_progress_at=1721605454, metadata={'description': 'batch_274759'}, output_file_id='file-nc2qZqDBI6gspihsYm0IfVNb', request_counts=BatchRequestCounts(completed=270, failed=0, total=270)),
#  Batch(id='batch_un8SnoHsyBITFZRtQ2o6hGeL', completion_window='24h', created_at=1721605452, endpoint='/v1/chat/completions', input_file_id='file-4FsFDdpUlvWwGB98upmMGsj2', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605522, error_file_id=None, errors=None, expired_at=None, expires_at=1721691852, failed_at=None, finalizing_at=1721605507, in_progress_at=1721605452, metadata={'description': 'batch_110133'}, output_file_id='file-byqXQVu4r6kxXtsaoWnOEiz7', request_counts=BatchRequestCounts(completed=440, failed=0, total=440)),
#  Batch(id='batch_fOLYjS2ekY6BYmbNtYbTJz3f', completion_window='24h', created_at=1721605450, endpoint='/v1/chat/completions', input_file_id='file-EKa50V544n9nM9rWOuBM7tDL', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605518, error_file_id=None, errors=None, expired_at=None, expires_at=1721691850, failed_at=None, finalizing_at=1721605507, in_progress_at=1721605451, metadata={'description': 'batch_597056'}, output_file_id='file-7HAQGHY8skQHa5lR8X24LI8U', request_counts=BatchRequestCounts(completed=320, failed=0, total=320)),
#  Batch(id='batch_s6rAqyiH8EIj5CrmMzUmwPZt', completion_window='24h', created_at=1721605449, endpoint='/v1/chat/completions', input_file_id='file-0nyuaHeOQpTAHztB2EVRrTnh', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605514, error_file_id=None, errors=None, expired_at=None, expires_at=1721691849, failed_at=None, finalizing_at=1721605507, in_progress_at=1721605450, metadata={'description': 'batch_16188'}, output_file_id='file-Ya9XfarY8VOd1zQCdnouV0pw', request_counts=BatchRequestCounts(completed=230, failed=0, total=230)),
#  Batch(id='batch_qOYAFLMusXEJUtAGmDoeBg43', completion_window='24h', created_at=1721604948, endpoint='/v1/chat/completions', input_file_id='file-dh5h7yaWgXxnxEt1ysLlSgLk', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605016, error_file_id=None, errors=None, expired_at=None, expires_at=1721691348, failed_at=None, finalizing_at=1721605007, in_progress_at=1721604948, metadata={'description': 'batch_99088'}, output_file_id='file-yB3Byshff7f1eJZ0mqZ0xwN7', request_counts=BatchRequestCounts(completed=240, failed=0, total=240)),
#  Batch(id='batch_p4B7qb0yUwB1y0GeCHtxJYlL', completion_window='24h', created_at=1721604946, endpoint='/v1/chat/completions', input_file_id='file-3CSHEzcWbwM5CBaq6JFuL8sm', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605027, error_file_id=None, errors=None, expired_at=None, expires_at=1721691346, failed_at=None, finalizing_at=1721605017, in_progress_at=1721604947, metadata={'description': 'batch_397139'}, output_file_id='file-IhGCI9MfPZoNAcZBtiObEB0o', request_counts=BatchRequestCounts(completed=320, failed=0, total=320)),
#  Batch(id='batch_YD5Bf27KSJpx8quObXOaUv0r', completion_window='24h', created_at=1721604945, endpoint='/v1/chat/completions', input_file_id='file-X9xjeylAGL3xwvDLzh2KO0sp', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605024, error_file_id=None, errors=None, expired_at=None, expires_at=1721691345, failed_at=None, finalizing_at=1721605017, in_progress_at=1721604945, metadata={'description': 'batch_621278'}, output_file_id='file-Y35gvYenBYhdHtkVMsVkSOfD', request_counts=BatchRequestCounts(completed=200, failed=0, total=200)),
#  Batch(id='batch_OP9KA2xdkAwFlX9UFRGpKgAT', completion_window='24h', created_at=1721604943, endpoint='/v1/chat/completions', input_file_id='file-mKvN4CC6GbpOBiLqWm1UkaED', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605029, error_file_id=None, errors=None, expired_at=None, expires_at=1721691343, failed_at=None, finalizing_at=1721605017, in_progress_at=1721604944, metadata={'description': 'batch_560732'}, output_file_id='file-2BHTvjtaSdB0p0JfltZ2Br33', request_counts=BatchRequestCounts(completed=390, failed=0, total=390)),
#  Batch(id='batch_QhyN1uS9e1g641rxnvfI7dDM', completion_window='24h', created_at=1721604942, endpoint='/v1/chat/completions', input_file_id='file-QYEpU3qifENHXSRYzMVVa170', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721605071, error_file_id=None, errors=None, expired_at=None, expires_at=1721691342, failed_at=None, finalizing_at=1721605006, in_progress_at=1721604942, metadata={'description': 'batch_402496'}, output_file_id='file-4tYl5WOslPZj6xKsj8p7CSYP', request_counts=BatchRequestCounts(completed=120, failed=0, total=120)),
#  Batch(id='batch_w8at35G581Cv0ZDy923449bH', completion_window='24h', created_at=1721604440, endpoint='/v1/chat/completions', input_file_id='file-81rcBIy5sdgVlONlxFwwEOOC', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604585, error_file_id=None, errors=None, expired_at=None, expires_at=1721690840, failed_at=None, finalizing_at=1721604571, in_progress_at=1721604441, metadata={'description': 'batch_37303'}, output_file_id='file-eS7KxAvgK3UFFjtZwZJPkJOC', request_counts=BatchRequestCounts(completed=410, failed=0, total=410)),
#  Batch(id='batch_LXnicMoZV9FTZ2lkR5LrO0vl', completion_window='24h', created_at=1721604439, endpoint='/v1/chat/completions', input_file_id='file-D2iRIOQCd5oOSbWspJkq1LS6', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604582, error_file_id=None, errors=None, expired_at=None, expires_at=1721690839, failed_at=None, finalizing_at=1721604571, in_progress_at=1721604439, metadata={'description': 'batch_506923'}, output_file_id='file-PpjrG3ViXkykCQZS5PqMGV8M', request_counts=BatchRequestCounts(completed=320, failed=0, total=320)),
#  Batch(id='batch_I4Vi6UxqdgX7ElsaOqN9EHzK', completion_window='24h', created_at=1721604437, endpoint='/v1/chat/completions', input_file_id='file-qs0ypfweYBAFtrL30f3DkCog', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604581, error_file_id=None, errors=None, expired_at=None, expires_at=1721690837, failed_at=None, finalizing_at=1721604571, in_progress_at=1721604438, metadata={'description': 'batch_124522'}, output_file_id='file-w2j14Ob5cYN6DhzEp5dFnkzY', request_counts=BatchRequestCounts(completed=300, failed=0, total=300)),
#  Batch(id='batch_rwWRQbnHTQFRG71zAdk1WcVU', completion_window='24h', created_at=1721604436, endpoint='/v1/chat/completions', input_file_id='file-HorpOOqi4Y5J9DZ1LTQtGMwf', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604580, error_file_id=None, errors=None, expired_at=None, expires_at=1721690836, failed_at=None, finalizing_at=1721604541, in_progress_at=1721604436, metadata={'description': 'batch_207710'}, output_file_id='file-uhSLL4DfOUZmI5kA8XTrmQrF', request_counts=BatchRequestCounts(completed=270, failed=0, total=270)),
#  Batch(id='batch_Ge3mgtw6JUx25TftiiqGfv4w', completion_window='24h', created_at=1721604435, endpoint='/v1/chat/completions', input_file_id='file-gBLy2eIaEiAmKq9SKWW7zJwk', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604580, error_file_id=None, errors=None, expired_at=None, expires_at=1721690835, failed_at=None, finalizing_at=1721604571, in_progress_at=1721604435, metadata={'description': 'batch_125908'}, output_file_id='file-wqdrwYKnzicoGIPNe92vYibJ', request_counts=BatchRequestCounts(completed=290, failed=0, total=290)),
#  Batch(id='batch_tGRK14AlvnO3Sk4H73QMTgUZ', completion_window='24h', created_at=1721603933, endpoint='/v1/chat/completions', input_file_id='file-iyB2Pcz4c9v14ptgRJUr6wHo', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604361, error_file_id=None, errors=None, expired_at=None, expires_at=1721690333, failed_at=None, finalizing_at=1721604350, in_progress_at=1721603934, metadata={'description': 'batch_306438'}, output_file_id='file-Yoe7tgMtr0VeRDibJkMwsk6g', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_Hp99xqW1v5CuAOEPR6VoBI4h', completion_window='24h', created_at=1721603932, endpoint='/v1/chat/completions', input_file_id='file-lg3514xUrirszI43yWRSlLch', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604017, error_file_id=None, errors=None, expired_at=None, expires_at=1721690332, failed_at=None, finalizing_at=1721604013, in_progress_at=1721603932, metadata={'description': 'batch_288775'}, output_file_id='file-rryJgCKQKn5iTOY0IFc2rEly', request_counts=BatchRequestCounts(completed=100, failed=0, total=100)),
#  Batch(id='batch_bvFWjeAE6EBQGcv0DA6DdUyZ', completion_window='24h', created_at=1721603930, endpoint='/v1/chat/completions', input_file_id='file-REqipaqbs90t85g9IJzbKH5t', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604130, error_file_id=None, errors=None, expired_at=None, expires_at=1721690330, failed_at=None, finalizing_at=1721604122, in_progress_at=1721603931, metadata={'description': 'batch_542822'}, output_file_id='file-VFQ1QeRCvcP3MvsDACwpHYrZ', request_counts=BatchRequestCounts(completed=260, failed=0, total=260)),
#  Batch(id='batch_ssY9R0cuqaDSoCAKKlhV3fga', completion_window='24h', created_at=1721603929, endpoint='/v1/chat/completions', input_file_id='file-NWfwMqZYNSG8SkvIzeQppjiR', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604342, error_file_id=None, errors=None, expired_at=None, expires_at=1721690329, failed_at=None, finalizing_at=1721604331, in_progress_at=1721603929, metadata={'description': 'batch_57262'}, output_file_id='file-5X2DTOUeXeAuYoDaOR1ood4K', request_counts=BatchRequestCounts(completed=290, failed=0, total=290)),
#  Batch(id='batch_OR7K9wrEjNY66r6X1TxmtKE3', completion_window='24h', created_at=1721603927, endpoint='/v1/chat/completions', input_file_id='file-vPHuSW7iSsxAQAV0gSsm0mad', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721604370, error_file_id=None, errors=None, expired_at=None, expires_at=1721690327, failed_at=None, finalizing_at=1721604351, in_progress_at=1721603928, metadata={'description': 'batch_18516'}, output_file_id='file-UqDbDqUERWdywA6dj8M1cRKn', request_counts=BatchRequestCounts(completed=570, failed=0, total=570)),
#  Batch(id='batch_75GvQaYufJDBs5l43hJkAdID', completion_window='24h', created_at=1721603425, endpoint='/v1/chat/completions', input_file_id='file-LXalrcs5Z9fKa5EObQ4VL2el', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603647, error_file_id=None, errors=None, expired_at=None, expires_at=1721689825, failed_at=None, finalizing_at=1721603636, in_progress_at=1721603426, metadata={'description': 'batch_175880'}, output_file_id='file-rpbdIV261atvHZhlM2b3IsUH', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_CzU2uA5rU461XbfwjlFz9Amf', completion_window='24h', created_at=1721603424, endpoint='/v1/chat/completions', input_file_id='file-7TqHdiDVMuRi23zL5Fc7cyFM', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603506, error_file_id=None, errors=None, expired_at=None, expires_at=1721689824, failed_at=None, finalizing_at=1721603498, in_progress_at=1721603424, metadata={'description': 'batch_343349'}, output_file_id='file-YF3MS6QkT536ZPCCqJ12zTtt', request_counts=BatchRequestCounts(completed=220, failed=0, total=220)),
#  Batch(id='batch_PVPlMUrTmbhDqZTBPJpuzBKf', completion_window='24h', created_at=1721603422, endpoint='/v1/chat/completions', input_file_id='file-jEoxJ7tF668RoNTTq041jUuD', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603653, error_file_id=None, errors=None, expired_at=None, expires_at=1721689822, failed_at=None, finalizing_at=1721603636, in_progress_at=1721603423, metadata={'description': 'batch_481359'}, output_file_id='file-fDE0OxrgcwRPOPQMWFJMC8ev', request_counts=BatchRequestCounts(completed=420, failed=0, total=420)),
#  Batch(id='batch_RuTat5DFREXgJfMELyqC893n', completion_window='24h', created_at=1721603421, endpoint='/v1/chat/completions', input_file_id='file-WseNfuWZ6bMAPXjyvaQNTUtV', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603645, error_file_id=None, errors=None, expired_at=None, expires_at=1721689821, failed_at=None, finalizing_at=1721603636, in_progress_at=1721603421, metadata={'description': 'batch_297972'}, output_file_id='file-FCTafpjLhfNZ4jQjj9ZXxj26', request_counts=BatchRequestCounts(completed=240, failed=0, total=240)),
#  Batch(id='batch_RmRm1gmpYa8IZa5T7W6RIpFn', completion_window='24h', created_at=1721603419, endpoint='/v1/chat/completions', input_file_id='file-7MmRskzjp4FvhbY0MW5bymuj', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603647, error_file_id=None, errors=None, expired_at=None, expires_at=1721689819, failed_at=None, finalizing_at=1721603637, in_progress_at=1721603420, metadata={'description': 'batch_678838'}, output_file_id='file-6prwenjIh7FXucXeULvtQYly', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_OWvxhOmCyFAKN5Zah7TLRBPd', completion_window='24h', created_at=1721603129, endpoint='/v1/chat/completions', input_file_id='file-Cl02HLbRTcL1tE5KSgvEXYba', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603235, error_file_id=None, errors=None, expired_at=None, expires_at=1721689529, failed_at=None, finalizing_at=1721603225, in_progress_at=1721603130, metadata={'description': 'batch_175880'}, output_file_id='file-DdALwCRFdoYSeAxVBnIqg3Jr', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_4fam9nhzOUFIMXkDVhnh1Fnc', completion_window='24h', created_at=1721603128, endpoint='/v1/chat/completions', input_file_id='file-Qbz4rxbtM0nft2RABWb6TpS7', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603232, error_file_id=None, errors=None, expired_at=None, expires_at=1721689528, failed_at=None, finalizing_at=1721603224, in_progress_at=1721603128, metadata={'description': 'batch_343349'}, output_file_id='file-u6PEYgfXKY3LR6LEyoDxkJZP', request_counts=BatchRequestCounts(completed=220, failed=0, total=220)),
#  Batch(id='batch_IkYJrAxChXY2drYK7mtWmQiW', completion_window='24h', created_at=1721603126, endpoint='/v1/chat/completions', input_file_id='file-2X0uhFqv5UiOzSwU75t7ZZPG', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603242, error_file_id=None, errors=None, expired_at=None, expires_at=1721689526, failed_at=None, finalizing_at=1721603226, in_progress_at=1721603127, metadata={'description': 'batch_481359'}, output_file_id='file-RNadYnalHje7YvOepWXf9v9x', request_counts=BatchRequestCounts(completed=420, failed=0, total=420)),
#  Batch(id='batch_Ml1N39r3Vvw4Z9k9TxdmDuxn', completion_window='24h', created_at=1721603124, endpoint='/v1/chat/completions', input_file_id='file-vJ4ytmGBPpAZNopWsabIcUld', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603234, error_file_id=None, errors=None, expired_at=None, expires_at=1721689524, failed_at=None, finalizing_at=1721603225, in_progress_at=1721603125, metadata={'description': 'batch_297972'}, output_file_id='file-hqgO5pzx8JwSB9T01mfM9e6R', request_counts=BatchRequestCounts(completed=240, failed=0, total=240)),
#  Batch(id='batch_Gt9bbhp2okkxdKKoxF45oNCv', completion_window='24h', created_at=1721603123, endpoint='/v1/chat/completions', input_file_id='file-KHzkcGHukepipdL3kagsUYJR', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603233, error_file_id=None, errors=None, expired_at=None, expires_at=1721689523, failed_at=None, finalizing_at=1721603224, in_progress_at=1721603124, metadata={'description': 'batch_678838'}, output_file_id='file-YsUFYpdmlwUD5milCVyElkWT', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_5ebf4K9x0Fcd1GenblVtM0ag', completion_window='24h', created_at=1721602941, endpoint='/v1/chat/completions', input_file_id='file-UaESAc3MV73RC8qjmgCPsSeK', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603052, error_file_id=None, errors=None, expired_at=None, expires_at=1721689341, failed_at=None, finalizing_at=1721603043, in_progress_at=1721602942, metadata={'description': 'batch_341238'}, output_file_id='file-reJ13XAMmtKJrfp2e9RgrsfY', request_counts=BatchRequestCounts(completed=280, failed=0, total=280)),
#  Batch(id='batch_bytUoNLsND0FjzgQZUN0E2Om', completion_window='24h', created_at=1721602940, endpoint='/v1/chat/completions', input_file_id='file-7VIEGcvSD3reuIlxNZocm1NK', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603050, error_file_id=None, errors=None, expired_at=None, expires_at=1721689340, failed_at=None, finalizing_at=1721603042, in_progress_at=1721602940, metadata={'description': 'batch_530975'}, output_file_id='file-T8EF4kc5D7yv4X60xAzffrD1', request_counts=BatchRequestCounts(completed=240, failed=0, total=240)),
#  Batch(id='batch_AH5QWd6Qiaho0IHvIOCbPozC', completion_window='24h', created_at=1721602938, endpoint='/v1/chat/completions', input_file_id='file-cWJBrb51kDge7lWLMxcmDrtj', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603051, error_file_id=None, errors=None, expired_at=None, expires_at=1721689338, failed_at=None, finalizing_at=1721603043, in_progress_at=1721602939, metadata={'description': 'batch_334376'}, output_file_id='file-TNq1eQ3o1z8XLVrfD8Kqbac4', request_counts=BatchRequestCounts(completed=210, failed=0, total=210)),
#  Batch(id='batch_VPSBhhtutcbV8zv1FBdVHaXo', completion_window='24h', created_at=1721602937, endpoint='/v1/chat/completions', input_file_id='file-3Qiel55Jx4eFTWo5dU3m9pfL', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603057, error_file_id=None, errors=None, expired_at=None, expires_at=1721689337, failed_at=None, finalizing_at=1721603042, in_progress_at=1721602938, metadata={'description': 'batch_202213'}, output_file_id='file-6w34KmMekLaL7MZO7aJdZXxW', request_counts=BatchRequestCounts(completed=450, failed=0, total=450)),
#  Batch(id='batch_RgeR64qxJl9VTapDBVETA24W', completion_window='24h', created_at=1721602935, endpoint='/v1/chat/completions', input_file_id='file-iQ7mrvDzCc8NaqG7sXIx0hHb', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721603054, error_file_id=None, errors=None, expired_at=None, expires_at=1721689335, failed_at=None, finalizing_at=1721603042, in_progress_at=1721602935, metadata={'description': 'batch_184355'}, output_file_id='file-xvI7BNO4xQtpxfMj4QJghLQg', request_counts=BatchRequestCounts(completed=360, failed=0, total=360)),
#  Batch(id='batch_PHEFfCuaFSYQcbcG2cqSjt10', completion_window='24h', created_at=1721602040, endpoint='/v1/chat/completions', input_file_id='file-EtN4NLEbkmEPuT1MDUHLj6Ih', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721602101, error_file_id=None, errors=None, expired_at=None, expires_at=1721688440, failed_at=None, finalizing_at=1721602095, in_progress_at=1721602040, metadata={'description': 'batch_350617'}, output_file_id='file-aakhASlKcAfZMnFQlywE0x1D', request_counts=BatchRequestCounts(completed=150, failed=0, total=150)),
#  Batch(id='batch_rfoWSbvzrYMfQFRmg3jKirRp', completion_window='24h', created_at=1721602038, endpoint='/v1/chat/completions', input_file_id='file-riAtghuDfJNv6aU8WYDiWTxQ', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721602121, error_file_id=None, errors=None, expired_at=None, expires_at=1721688438, failed_at=None, finalizing_at=1721602105, in_progress_at=1721602039, metadata={'description': 'batch_526719'}, output_file_id='file-ZFFJ9DYMUMTrYwzJnKH3qjJi', request_counts=BatchRequestCounts(completed=410, failed=0, total=410)),
#  Batch(id='batch_dbkjOb0dIxRYJCCb4zMLvwT6', completion_window='24h', created_at=1721602037, endpoint='/v1/chat/completions', input_file_id='file-UkEg0oDACYUvMxXC4Mj02zb9', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721602105, error_file_id=None, errors=None, expired_at=None, expires_at=1721688437, failed_at=None, finalizing_at=1721602093, in_progress_at=1721602037, metadata={'description': 'batch_214228'}, output_file_id='file-2Ax4kPbzFqTcW7wbTLmEO9fD', request_counts=BatchRequestCounts(completed=340, failed=0, total=340)),
#  Batch(id='batch_pW9H6GloJ22shGWUxFYtmGIW', completion_window='24h', created_at=1721602035, endpoint='/v1/chat/completions', input_file_id='file-RkS8ygO9eHRH1TpOpIsi4FB3', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721602114, error_file_id=None, errors=None, expired_at=None, expires_at=1721688435, failed_at=None, finalizing_at=1721602107, in_progress_at=1721602036, metadata={'description': 'batch_323518'}, output_file_id='file-4hI5UGHDptcr7cSD2MCpnOik', request_counts=BatchRequestCounts(completed=170, failed=0, total=170)),
#  Batch(id='batch_013eSRVWLKWmtIMpBWhHhSLl', completion_window='24h', created_at=1721602034, endpoint='/v1/chat/completions', input_file_id='file-hZsyYqcUisNUpHkbFrER9i88', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721602148, error_file_id=None, errors=None, expired_at=None, expires_at=1721688434, failed_at=None, finalizing_at=1721602122, in_progress_at=1721602035, metadata={'description': 'batch_445957'}, output_file_id='file-Dlhu1lHh1AT5NHYFoKsjcuB9', request_counts=BatchRequestCounts(completed=750, failed=0, total=750)),
#  Batch(id='batch_uKMKE6DVqPchT5vmgQcJ1XmN', completion_window='24h', created_at=1721599579, endpoint='/v1/chat/completions', input_file_id='file-HJKxnBpyXKTrKj3tMxrc0ayW', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-mini in organization org-mw1MHdn3I3J49ocyVeQGQyRB. Limit: 400,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1721685979, failed_at=1721599579, finalizing_at=None, in_progress_at=None, metadata={'description': 'batch_171105'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_hzJOTPbYOPSDYyBPiNjbPkrR', completion_window='24h', created_at=1721599577, endpoint='/v1/chat/completions', input_file_id='file-yAT2QpBBOElAx0LjdjwscxFb', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-mini in organization org-mw1MHdn3I3J49ocyVeQGQyRB. Limit: 400,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1721685977, failed_at=1721599578, finalizing_at=None, in_progress_at=None, metadata={'description': 'batch_463289'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_aSvmbAxRriIh6vAjwjuG2Waj', completion_window='24h', created_at=1721599576, endpoint='/v1/chat/completions', input_file_id='file-2iEYlEqTzEY8UUGqgh9HnL1f', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-mini in organization org-mw1MHdn3I3J49ocyVeQGQyRB. Limit: 400,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1721685976, failed_at=1721599577, finalizing_at=None, in_progress_at=None, metadata={'description': 'batch_491687'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))]

# %%
batch_df = process_batches(client)
# Out:
# Current DataFrame shape: (100, 22)
# Current DataFrame shape: (101, 22)
# No new batches found.

# %%
failed_df = batch_df[batch_df['status']== 'failed']

# %%
completed_df = batch_df[batch_df['status']== 'completed']

# %%
print(f"Failed: {len(failed_df)} - Completed: {len(completed_df)}")
# Out:
# Failed: 4 - Completed: 92

# %%
completed_df
# Out:
#                                  id completion_window  created_at  \
# 195  batch_013eSRVWLKWmtIMpBWhHhSLl               24h  1721602034
# 194  batch_pW9H6GloJ22shGWUxFYtmGIW               24h  1721602035
# 193  batch_dbkjOb0dIxRYJCCb4zMLvwT6               24h  1721602037
# 192  batch_rfoWSbvzrYMfQFRmg3jKirRp               24h  1721602038
# 191  batch_PHEFfCuaFSYQcbcG2cqSjt10               24h  1721602040
# ..                              ...               ...         ...
# 108  batch_s5QkFr2x6SKdt7RhXBQefBfR               24h  1721610541
# 107  batch_7PT7lqoPlGqx04jUhGPW0EsK               24h  1721610543
# 106  batch_T1Ol5j2QePjqV0xNGoH0c7pM               24h  1721610545
# 105  batch_F3HkDhT9AIP5BXPY58MASKNJ               24h  1721611047
# 104  batch_YPBvKKFhz41K76K05z3xhKUQ               24h  1721611048
#
#                  endpoint                  input_file_id object     status  \
# 195  /v1/chat/completions  file-hZsyYqcUisNUpHkbFrER9i88  batch  completed
# 194  /v1/chat/completions  file-RkS8ygO9eHRH1TpOpIsi4FB3  batch  completed
# 193  /v1/chat/completions  file-UkEg0oDACYUvMxXC4Mj02zb9  batch  completed
# 192  /v1/chat/completions  file-riAtghuDfJNv6aU8WYDiWTxQ  batch  completed
# 191  /v1/chat/completions  file-EtN4NLEbkmEPuT1MDUHLj6Ih  batch  completed
# ..                    ...                            ...    ...        ...
# 108  /v1/chat/completions  file-bo6sV9FD8ZwWaadPQLtDJ4Ov  batch  completed
# 107  /v1/chat/completions  file-UWQF3oJm7HYJcLqQhStoc7U4  batch  completed
# 106  /v1/chat/completions  file-1Uli9XRn7Ai9CJUdoHiu2vZW  batch  completed
# 105  /v1/chat/completions  file-y76MpaM9qjCGnI4hvTxA1MnJ  batch  completed
# 104  /v1/chat/completions  file-cSS7JY5rEpp6GKGfWfQGn9dZ  batch  completed
#
#     cancelled_at cancelling_at  completed_at  ... expired_at  expires_at  \
# 195         None          None  1.721602e+09  ...       None  1721688434
# 194         None          None  1.721602e+09  ...       None  1721688435
# 193         None          None  1.721602e+09  ...       None  1721688437
# 192         None          None  1.721602e+09  ...       None  1721688438
# 191         None          None  1.721602e+09  ...       None  1721688440
# ..           ...           ...           ...  ...        ...         ...
# 108         None          None  1.721611e+09  ...       None  1721696941
# 107         None          None  1.721611e+09  ...       None  1721696943
# 106         None          None  1.721611e+09  ...       None  1721696945
# 105         None          None  1.721611e+09  ...       None  1721697447
# 104         None          None  1.721611e+09  ...       None  1721697448
#
#     failed_at  finalizing_at  in_progress_at  metadata_description  \
# 195       NaN   1.721602e+09    1.721602e+09          batch_445957
# 194       NaN   1.721602e+09    1.721602e+09          batch_323518
# 193       NaN   1.721602e+09    1.721602e+09          batch_214228
# 192       NaN   1.721602e+09    1.721602e+09          batch_526719
# 191       NaN   1.721602e+09    1.721602e+09          batch_350617
# ..        ...            ...             ...                   ...
# 108       NaN   1.721611e+09    1.721611e+09          batch_585356
# 107       NaN   1.721611e+09    1.721611e+09          batch_551652
# 106       NaN   1.721611e+09    1.721611e+09          batch_491687
# 105       NaN   1.721611e+09    1.721611e+09          batch_463289
# 104       NaN   1.721611e+09    1.721611e+09          batch_171105
#
#                     output_file_id request_counts_completed  \
# 195  file-Dlhu1lHh1AT5NHYFoKsjcuB9                      750
# 194  file-4hI5UGHDptcr7cSD2MCpnOik                      170
# 193  file-2Ax4kPbzFqTcW7wbTLmEO9fD                      340
# 192  file-ZFFJ9DYMUMTrYwzJnKH3qjJi                      410
# 191  file-aakhASlKcAfZMnFQlywE0x1D                      150
# ..                             ...                      ...
# 108  file-in1an4RiYXLWZyWPA6p1VXWh                      300
# 107  file-wZOAeKNCkOvxNcIE5UbBHnW4                      250
# 106  file-0CiPpS2fmDbuJYCHpSbcJOe6                      480
# 105  file-iKTMJJmMFWEv59M3CQk6Dd09                      150
# 104  file-kVEVcCuRE0SukQE00Md76qDj                      360
#
#     request_counts_failed  request_counts_total
# 195                     0                   750
# 194                     0                   170
# 193                     0                   340
# 192                     0                   410
# 191                     0                   150
# ..                    ...                   ...
# 108                     0                   300
# 107                     0                   250
# 106                     0                   480
# 105                     0                   150
# 104                     0                   360
#
# [92 rows x 22 columns]

# %%
# Define the function to process files
def process_batch_files(batch_complete_loc, batch_sent_loc, completed_df):
    # Define the function to extract the content from the response
    def extract_content(response):
        try:
            content = response['body']['choices'][0]['message']['content']
            return content
        except (KeyError, TypeError):
            return None

    # Get the list of files already in the batch_complete_loc
    existing_files = [f.replace('.jsonl', '') for f in os.listdir(batch_complete_loc) if f.endswith('.jsonl')]

    # Filter out rows in completed_df where metadata_description matches existing files
    df_to_process = completed_df[~completed_df['metadata_description'].isin(existing_files)]

    # Loop through the rows in the filtered DataFrame
    for index, row in df_to_process.iterrows():
        metadata_description = row['metadata_description']
        output_file_id = row['output_file_id']

        # Call the API to get the file content
        file_response = client.files.content(output_file_id)
        jsonl_io = StringIO(file_response.text)
        df = pd.read_json(jsonl_io, lines=True)

        # Apply the function to extract the 'content' from the 'response' column
        df['response'] = df['response'].apply(extract_content)

        # Select only the required columns
        df = df[['id', 'custom_id', 'response']]

        # Save the DataFrame as a jsonl file in batch_complete_loc
        output_filepath = os.path.join(batch_complete_loc, f"{metadata_description}.jsonl")
        df.to_json(output_filepath, orient='records', lines=True)

        # Move the file from batch_sent_loc to batch_complete_loc
        sent_filepath = os.path.join(batch_sent_loc, f"{metadata_description}.jsonl")
        if os.path.exists(sent_filepath):
            os.remove(sent_filepath)
            print(f"File {sent_filepath} moved to {batch_complete_loc}")

# %%
process_batch_files(batch_complete_loc, batch_sent_loc, completed_df)

# %%
failed_df
# Out:
#                                  id completion_window  created_at  \
# 199  batch_zibO1jsIbRslkYvbS3vThvdl               24h  1721599575
# 198  batch_aSvmbAxRriIh6vAjwjuG2Waj               24h  1721599576
# 197  batch_hzJOTPbYOPSDYyBPiNjbPkrR               24h  1721599577
# 196  batch_uKMKE6DVqPchT5vmgQcJ1XmN               24h  1721599579
#
#                  endpoint                  input_file_id object  status  \
# 199  /v1/chat/completions  file-vodz9cJrx83pXL50FHufIhyp  batch  failed
# 198  /v1/chat/completions  file-2iEYlEqTzEY8UUGqgh9HnL1f  batch  failed
# 197  /v1/chat/completions  file-yAT2QpBBOElAx0LjdjwscxFb  batch  failed
# 196  /v1/chat/completions  file-HJKxnBpyXKTrKj3tMxrc0ayW  batch  failed
#
#     cancelled_at cancelling_at  completed_at  ... expired_at  expires_at  \
# 199         None          None           NaN  ...       None  1721685975
# 198         None          None           NaN  ...       None  1721685976
# 197         None          None           NaN  ...       None  1721685977
# 196         None          None           NaN  ...       None  1721685979
#
#         failed_at  finalizing_at  in_progress_at  metadata_description  \
# 199  1.721600e+09            NaN             NaN          batch_551652
# 198  1.721600e+09            NaN             NaN          batch_491687
# 197  1.721600e+09            NaN             NaN          batch_463289
# 196  1.721600e+09            NaN             NaN          batch_171105
#
#      output_file_id request_counts_completed request_counts_failed  \
# 199            None                        0                     0
# 198            None                        0                     0
# 197            None                        0                     0
# 196            None                        0                     0
#
#      request_counts_total
# 199                     0
# 198                     0
# 197                     0
# 196                     0
#
# [4 rows x 22 columns]

# %%
# Define the function to handle failed files
def handle_failed_files(batch_loc, batch_sent, failed_df):
    # Loop through the rows in the failed_df DataFrame
    for index, row in failed_df.iterrows():
        metadata_description = row['metadata_description']
        filename = f"{metadata_description}.jsonl"
        
        # Define the source and destination file paths
        sent_filepath = os.path.join(batch_sent, filename)
        loc_filepath = os.path.join(batch_loc, filename)
        
        # Check if the file exists in batch_sent
        if os.path.exists(sent_filepath):
            # Move the file to batch_loc
            shutil.move(sent_filepath, loc_filepath)
            print(f"File {filename} moved from {batch_sent} to {batch_loc}")

# %%
handle_failed_files(batch_loc, batch_sent_loc, failed_df)
