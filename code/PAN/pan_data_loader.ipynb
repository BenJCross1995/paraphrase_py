# %% [markdown]
# # PAN Data Loader
#
# In this notebook we are able to load the PAN AV data, split the relevant columns and save as two seperate data frames.

# %%
import json
import os

import pandas as pd

# %%
def read_jsonl(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
            
    data = pd.DataFrame(data)
    return data

def write_jsonl(data, output_file_path):
    with open(output_file_path, 'w') as file:
        for _, row in data.iterrows():
            json.dump(row.to_dict(), file)
            file.write('\n')

# %%
base_loc = "/Volumes/ExternalHDD/datasets/Authorship Verification/PAN/"
base_loc = "../../../../datasets/PAN/"
file_loc = f"{base_loc}PAN 21/pan21-raw.jsonl"
known_loc = f"{base_loc}PAN 21/pan21-known.jsonl"
unknown_loc = f"{base_loc}PAN 21/pan21-unknown.jsonl"
truth_loc = f"{base_loc}PAN 21/pan21-truth.jsonl"
txt_samples = f"{base_loc}PAN 21/sample_texts/"

# %%
df = read_jsonl(file_loc)

# %%
df
# Out:
#                                          id  \
# 0      c28e8b03-c02a-5184-b58a-12dd28b8ca74
# 1      b9326101-6352-56dd-9d1b-1f41466897b7
# 2      e2ac4453-bf54-53f2-bf68-6caae6aacded
# 3      a5e9a289-0999-5764-b597-dc1bf8c21ede
# 4      cb4054b1-d422-58d6-a137-dcfc70100df6
# ...                                     ...
# 19994  7b226a98-3d82-50c1-b6f3-ee682f580d27
# 19995  eed8a22b-c7cd-5adb-b530-88b9d5d30202
# 19996  07d9c529-6fd2-5cd1-b46f-bcfad1d58503
# 19997  88066615-7a7a-5f5b-adb9-f8c67a4c59a6
# 19998  a4b7b045-f0ff-5524-86af-c942e923bd42
#
#                                             fandoms  \
# 0                                [Death Note, Thor]
# 1               [Samurai Deeper Kyo, Yu Yu Hakusho]
# 2                 [West Side Story, Martin Mystery]
# 3                      [Get Backers, Yu Yu Hakusho]
# 4             [My Hero Academia/僕のヒーローアカデミア, Skins]
# ...                                             ...
# 19994                             [Mentalist, Thor]
# 19995            [Janet Evanovich, Gallagher Girls]
# 19996  [Skulduggery Pleasant series, Yu Yu Hakusho]
# 19997      [Jackie Chan Adventures, Justice League]
# 19998                  [Dragon Age, Pandora Hearts]
#
#                                                     pair
# 0      [talk because they hadn"t been exposed to comm...
# 1      [Zazuki nodded his head and got to his feet, k...
# 2      ["Oh we did lots of special things. On Christm...
# 3      ["Hey now, at least Shido brings home some mon...
# 4      [It was a mere five minutes" walk from third y...
# ...                                                  ...
# 19994  [They zipped through the formalities before fl...
# 19995  ["You"re taking me to a spa?" I asked eyeing h...
# 19996  [Vanessa: Hahaa! Shudder: Still here. This is ...
# 19997  [bountiful breasts pressed against his chest, ...
# 19998  [The plant was encouraged by the sound, slidin...
#
# [19999 rows x 3 columns]

# %%
truth = read_jsonl(truth_loc)

# %%
truth
# Out:
#                                          id   same             authors
# 0      c28e8b03-c02a-5184-b58a-12dd28b8ca74   True  [2072507, 2072507]
# 1      b9326101-6352-56dd-9d1b-1f41466897b7   True  [1404943, 1404943]
# 2      e2ac4453-bf54-53f2-bf68-6caae6aacded  False   [2406271, 929947]
# 3      a5e9a289-0999-5764-b597-dc1bf8c21ede   True    [189771, 189771]
# 4      cb4054b1-d422-58d6-a137-dcfc70100df6   True    [965626, 965626]
# ...                                     ...    ...                 ...
# 19994  7b226a98-3d82-50c1-b6f3-ee682f580d27   True  [2264834, 2264834]
# 19995  eed8a22b-c7cd-5adb-b530-88b9d5d30202  False  [1144417, 8582246]
# 19996  07d9c529-6fd2-5cd1-b46f-bcfad1d58503  False  [2733573, 1421642]
# 19997  88066615-7a7a-5f5b-adb9-f8c67a4c59a6   True    [787585, 787585]
# 19998  a4b7b045-f0ff-5524-86af-c942e923bd42   True  [2310029, 2310029]
#
# [19999 rows x 3 columns]

# %%
combined_df = df.merge(truth, on='id', how='left')

# %%
def pan_corpus_splitter(df):
    # Ensure the columns exist in the dataframe
    if 'id' not in df.columns or 'fandoms' not in df.columns or 'pair' not in df.columns or 'authors' not in df.columns:
        raise ValueError("DataFrame must contain 'id', 'fandoms', 'authors', and 'pair' columns")
    
    # Check if 'fandom' and 'pair' columns are lists with two elements
    if not all(df['fandoms'].apply(lambda x: isinstance(x, list) and len(x) == 2)) or not all(df['pair'].apply(lambda x: isinstance(x, list) and len(x) == 2)) or not all(df['authors'].apply(lambda x: isinstance(x, list) and len(x) == 2)):
        raise ValueError("'fandoms', 'authors', and 'pair' columns must contain lists with two elements each")
    
    # Create the 'x' dataframe
    x = df[['id']].copy()
    x['author'] = df['authors'].apply(lambda x: x[0])
    x['fandom'] = df['fandoms'].apply(lambda x: x[0])
    x['text'] = df['pair'].apply(lambda x: x[0])
    
    # Create the 'y' dataframe
    y = df[['id']].copy()
    y['author'] = df['authors'].apply(lambda x: x[1])
    y['fandom'] = df['fandoms'].apply(lambda x: x[1])
    y['text'] = df['pair'].apply(lambda x: x[1])
    
    return x, y

# %%
x, y = pan_corpus_splitter(combined_df)

# %%
x
# Out:
#                                          id   author  \
# 0      c28e8b03-c02a-5184-b58a-12dd28b8ca74  2072507
# 1      b9326101-6352-56dd-9d1b-1f41466897b7  1404943
# 2      e2ac4453-bf54-53f2-bf68-6caae6aacded  2406271
# 3      a5e9a289-0999-5764-b597-dc1bf8c21ede   189771
# 4      cb4054b1-d422-58d6-a137-dcfc70100df6   965626
# ...                                     ...      ...
# 19994  7b226a98-3d82-50c1-b6f3-ee682f580d27  2264834
# 19995  eed8a22b-c7cd-5adb-b530-88b9d5d30202  1144417
# 19996  07d9c529-6fd2-5cd1-b46f-bcfad1d58503  2733573
# 19997  88066615-7a7a-5f5b-adb9-f8c67a4c59a6   787585
# 19998  a4b7b045-f0ff-5524-86af-c942e923bd42  2310029
#
#                              fandom  \
# 0                        Death Note
# 1                Samurai Deeper Kyo
# 2                   West Side Story
# 3                       Get Backers
# 4      My Hero Academia/僕のヒーローアカデミア
# ...                             ...
# 19994                     Mentalist
# 19995               Janet Evanovich
# 19996   Skulduggery Pleasant series
# 19997        Jackie Chan Adventures
# 19998                    Dragon Age
#
#                                                     text
# 0      talk because they hadn"t been exposed to commu...
# 1      Zazuki nodded his head and got to his feet, kn...
# 2      "Oh we did lots of special things. On Christma...
# 3      "Hey now, at least Shido brings home some mone...
# 4      It was a mere five minutes" walk from third ye...
# ...                                                  ...
# 19994  They zipped through the formalities before fli...
# 19995  "You"re taking me to a spa?" I asked eyeing hi...
# 19996  Vanessa: Hahaa! Shudder: Still here. This is b...
# 19997  bountiful breasts pressed against his chest, i...
# 19998  The plant was encouraged by the sound, sliding...
#
# [19999 rows x 4 columns]

# %%
y
# Out:
#                                          id   author           fandom  \
# 0      c28e8b03-c02a-5184-b58a-12dd28b8ca74  2072507             Thor
# 1      b9326101-6352-56dd-9d1b-1f41466897b7  1404943    Yu Yu Hakusho
# 2      e2ac4453-bf54-53f2-bf68-6caae6aacded   929947   Martin Mystery
# 3      a5e9a289-0999-5764-b597-dc1bf8c21ede   189771    Yu Yu Hakusho
# 4      cb4054b1-d422-58d6-a137-dcfc70100df6   965626            Skins
# ...                                     ...      ...              ...
# 19994  7b226a98-3d82-50c1-b6f3-ee682f580d27  2264834             Thor
# 19995  eed8a22b-c7cd-5adb-b530-88b9d5d30202  8582246  Gallagher Girls
# 19996  07d9c529-6fd2-5cd1-b46f-bcfad1d58503  1421642    Yu Yu Hakusho
# 19997  88066615-7a7a-5f5b-adb9-f8c67a4c59a6   787585   Justice League
# 19998  a4b7b045-f0ff-5524-86af-c942e923bd42  2310029   Pandora Hearts
#
#                                                     text
# 0      Your brother, Loki wants to say, and instantly...
# 1      "Her name is Sayaka. She"s with Botan." He ans...
# 2      "Get it out! Get it out!' Martin was trying ha...
# 3      Ookami Sarah Yay, and that is it so far. The n...
# 4      "Go on, Liv. I wanna take a picture of you thr...
# ...                                                  ...
# 19994  He didn"t prevail. His brother was now in our ...
# 19995  You"re the fear, I don"t care"Cause I"ve never...
# 19996  Authoress starts dancing around happily. Darkf...
# 19997  "Have you ever heard of the Turing test?" "No ...
# 19998  Myra smiled happily, "Yes, it"s a lovely dress...
#
# [19999 rows x 4 columns]

# %%
write_jsonl(x, known_loc)

# %%
write_jsonl(y, unknown_loc)

# %%
def save_text_samples(combined_df, folder_location, sample_size=100):
    # Ensure the folder exists
    os.makedirs(folder_location, exist_ok=True)
    
    # Take a sample of the specified size
    sample_df = combined_df.sample(n=sample_size, random_state=42)
    
    # Save each text column to a separate .txt file
    for idx, row in sample_df.iterrows():
        file_path = os.path.join(folder_location, f"{row['id']}.txt")
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(row['text'])

# %%
# save_text_samples(x, txt_samples)
