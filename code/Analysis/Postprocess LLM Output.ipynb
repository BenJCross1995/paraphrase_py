# %% [markdown]
# # Script to PostProcess LLM Output
#
# This script allows us to postprocess the output from an LLM, we are able to use verbose to print statements for each level and document.

# %%
# 1) Set the location
# %cd ../../code/
# Out:
# /Users/user/Documents/GitHub/paraphrase_py/code
# /Users/user/Documents/GitHub/Video-from-Script/youtube_env/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from postprocessing import process_records, print_summary
from read_and_write_docs import read_jsonl, write_jsonl
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## Set Locations for PostProcessing

# %%
base_loc = "/Volumes/BCross/datasets/author_verification"
data_type = "training"
corpus = "Wiki"
model_dir = "Qwen_2.5_1.5B"
data_base_loc = f"{base_loc}/{data_type}/{corpus}/{model_dir}"

# %%
in_dir  = Path(f"{data_base_loc}/full_doc_paraphrase")
out_dir = Path(f"{data_base_loc}/full_doc_paraphrase_clean")
out_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Loop Through Generated Files
#
# Loop through the generated files in the directory given above, it will process each file and print out whether it was successfull or not. It will skip a file if it is already found in the output location.

# %%
for infile in sorted(in_dir.glob("*.jsonl")):
    outfile = out_dir / infile.name

    # ── 1) skip if we’ve already processed this file ────────────
    if outfile.exists():
        print(f"⏭️   skipping {infile.name} (already in output dir)")
        continue

    try:
        df_in  = read_jsonl(infile)
        df_out = process_records(df_in)
        write_jsonl(df_out, outfile)

        print(f"✅  wrote {outfile.relative_to(out_dir.parent)} "
              f"({len(df_out):,} rows)")

    except Exception as exc:
        # log the filename and the exception, then move on
        print(f"❌  FAILED on {infile.name}: {type(exc).__name__}: {exc}")

print("\n🎉  Directory pass complete.")
# Out:
# ⏭️   skipping 142_196_88_228_text_1.jsonl (already in output dir)
# ⏭️   skipping 142_196_88_228_text_3.jsonl (already in output dir)
# ⏭️   skipping 142_196_88_228_text_4.jsonl (already in output dir)
# ⏭️   skipping a_man_in_black_text_1.jsonl (already in output dir)
# ⏭️   skipping a_man_in_black_text_2.jsonl (already in output dir)
# ⏭️   skipping a_man_in_black_text_5.jsonl (already in output dir)
# ⏭️   skipping aban1313_text_1.jsonl (already in output dir)
# ⏭️   skipping aban1313_text_2.jsonl (already in output dir)
# ⏭️   skipping aban1313_text_5.jsonl (already in output dir)
# ⏭️   skipping akuri_text_1.jsonl (already in output dir)
# ⏭️   skipping akuri_text_2.jsonl (already in output dir)
# ⏭️   skipping akuri_text_3.jsonl (already in output dir)
# ⏭️   skipping alanbarnet_text_10.jsonl (already in output dir)
# ⏭️   skipping alanbarnet_text_3.jsonl (already in output dir)
# ⏭️   skipping alanbarnet_text_4.jsonl (already in output dir)
# ⏭️   skipping alanyst_text_1.jsonl (already in output dir)
# ⏭️   skipping alanyst_text_12.jsonl (already in output dir)
# ⏭️   skipping alanyst_text_13.jsonl (already in output dir)
# ⏭️   skipping alasdairgreen27_text_1.jsonl (already in output dir)
# ⏭️   skipping alasdairgreen27_text_2.jsonl (already in output dir)
# ⏭️   skipping alasdairgreen27_text_3.jsonl (already in output dir)
# ⏭️   skipping alienus_text_10.jsonl (already in output dir)
# ⏭️   skipping alienus_text_11.jsonl (already in output dir)
# ⏭️   skipping alienus_text_2.jsonl (already in output dir)
# ⏭️   skipping amalthea_text_2.jsonl (already in output dir)
# ⏭️   skipping amalthea_text_3.jsonl (already in output dir)
# ⏭️   skipping amalthea_text_4.jsonl (already in output dir)
# ⏭️   skipping amorrow_text_1.jsonl (already in output dir)
# ⏭️   skipping amorrow_text_3.jsonl (already in output dir)
# ⏭️   skipping amorrow_text_4.jsonl (already in output dir)
# ⏭️   skipping anir1uph_text_3.jsonl (already in output dir)
# ⏭️   skipping anir1uph_text_4.jsonl (already in output dir)
# ⏭️   skipping anir1uph_text_5.jsonl (already in output dir)
# ⏭️   skipping antidiskriminator_text_1.jsonl (already in output dir)
# ⏭️   skipping antidiskriminator_text_2.jsonl (already in output dir)
# ⏭️   skipping antidiskriminator_text_3.jsonl (already in output dir)
# ⏭️   skipping atama_text_1.jsonl (already in output dir)
# ⏭️   skipping atama_text_3.jsonl (already in output dir)
# ⏭️   skipping atama_text_4.jsonl (already in output dir)
# ⏭️   skipping athenean_text_1.jsonl (already in output dir)
# ⏭️   skipping athenean_text_3.jsonl (already in output dir)
# ⏭️   skipping athenean_text_4.jsonl (already in output dir)
# ⏭️   skipping avraham_text_2.jsonl (already in output dir)
# ⏭️   skipping avraham_text_4.jsonl (already in output dir)
# ⏭️   skipping avraham_text_5.jsonl (already in output dir)
# ⏭️   skipping bankhallbretherton_text_2.jsonl (already in output dir)
# ⏭️   skipping bankhallbretherton_text_4.jsonl (already in output dir)
# ⏭️   skipping bankhallbretherton_text_5.jsonl (already in output dir)
# ⏭️   skipping bfigura_text_1.jsonl (already in output dir)
# ⏭️   skipping bfigura_text_3.jsonl (already in output dir)
# ⏭️   skipping bfigura_text_4.jsonl (already in output dir)
# ⏭️   skipping bielle_text_2.jsonl (already in output dir)
# ⏭️   skipping bielle_text_3.jsonl (already in output dir)
# ⏭️   skipping bielle_text_5.jsonl (already in output dir)
# ⏭️   skipping bigdaddy1981_text_2.jsonl (already in output dir)
# ⏭️   skipping bigdaddy1981_text_3.jsonl (already in output dir)
# ⏭️   skipping bigdaddy1981_text_4.jsonl (already in output dir)
# ⏭️   skipping bjenks_text_3.jsonl (already in output dir)
# ⏭️   skipping bjenks_text_4.jsonl (already in output dir)
# ⏭️   skipping bjenks_text_5.jsonl (already in output dir)
# ⏭️   skipping bonewah_text_1.jsonl (already in output dir)
# ⏭️   skipping bonewah_text_2.jsonl (already in output dir)
# ⏭️   skipping bonewah_text_3.jsonl (already in output dir)
# ⏭️   skipping boson_text_10.jsonl (already in output dir)
# ⏭️   skipping boson_text_11.jsonl (already in output dir)
# ⏭️   skipping boson_text_12.jsonl (already in output dir)
# ✅  wrote full_doc_paraphrase_clean/britmax_text_1.jsonl (1,000 rows)
# ✅  wrote full_doc_paraphrase_clean/britmax_text_3.jsonl (1,000 rows)
#
# 🎉  Directory pass complete.

# %% [markdown]
# ## Check Which Files Still to Process
#
# Here we check the two locations and see which files are present in the input directory but not in the output directory. Any that are in this printout have failed and must be looked at further.

# %%
pending = sorted(
    infile.name
    for infile in in_dir.glob("*.jsonl")
    if not (out_dir / infile.name).exists()
)

if pending:
    print(f"{len(pending)} JSONL file(s) still to process:\n")
    for name in pending:
        print("  •", name)
else:
    print("✅  All *.jsonl files in", in_dir, "already have outputs.")
# Out:
# ✅  All *.jsonl files in /Volumes/BCross/datasets/author_verification/training/Wiki/Qwen_2.5_1.5B/full_doc_paraphrase already have outputs.

# %% [markdown]
# ## Failed Files
#
# The code now works to skip certain reasons why a file may fail on a row by row basis, if you wish to go into more detail look at the file still to process above and run code similar to what is given.
# If any rows fail they will be printed out in the output shown below as a python list at the end of the output. This allows you to print out the rows which are failing.

# %%
failed_df = read_jsonl(f"{data_base_loc}/full_doc_paraphrase/alienus_text_2.jsonl")

# %%
processed_failed_df = process_records(failed_df, verbose=True)
# Out:
# [    0] ✔︎  stage=wrap_plain_text
# [    1] ✔︎  stage=wrap_plain_text
# [    2] ✔︎  stage=wrap_plain_text
# [    3] ✔︎  stage=fix_salvage_quotes
# [    4] ✔︎  stage=wrap_plain_text
# [    5] ✔︎  stage=wrap_plain_text
# [    6] ✔︎  stage=wrap_plain_text
# [    7] ✔︎  stage=wrap_plain_text
# [    8] ✔︎  stage=wrap_plain_text
# [    9] ✔︎  stage=wrap_plain_text
# [   10] ✔︎  stage=wrap_plain_text
# [   11] ✔︎  stage=fix_salvage_quotes
# [   12] ✔︎  stage=wrap_plain_text
# [   13] ✔︎  stage=wrap_plain_text
# [   14] ✔︎  stage=wrap_plain_text
# [   15] ✔︎  stage=wrap_plain_text
# [   16] ✔︎  stage=wrap_plain_text
# [   17] ✔︎  stage=wrap_plain_text
# [   18] ✔︎  stage=wrap_plain_text
# [   19] ✔︎  stage=wrap_plain_text
# [   20] ✔︎  stage=wrap_plain_text
# [   21] ✔︎  stage=fix_salvage_quotes
# [   22] ✔︎  stage=wrap_plain_text
# [   23] ✔︎  stage=wrap_plain_text
# [   24] ✔︎  stage=fix_salvage_quotes
# [   25] ✔︎  stage=wrap_plain_text
# [   26] ✔︎  stage=wrap_plain_text
# [   27] ✔︎  stage=wrap_plain_text
# [   28] ✔︎  stage=wrap_plain_text
# [   29] ✔︎  stage=wrap_plain_text
# [   30] ✔︎  stage=wrap_plain_text
# [   31] ✔︎  stage=wrap_plain_text
# [   32] ✔︎  stage=wrap_plain_text
# [   33] ✔︎  stage=wrap_plain_text
# [   34] ✔︎  stage=wrap_plain_text
# [   35] ✔︎  stage=wrap_plain_text
# [   36] ✔︎  stage=wrap_plain_text
# [   37] ✔︎  stage=wrap_plain_text
# [   38] ✔︎  stage=wrap_plain_text
# [   39] ✔︎  stage=wrap_plain_text
# [   40] ✔︎  stage=wrap_plain_text
# [   41] ✔︎  stage=fix_salvage_quotes
# [   42] ✔︎  stage=wrap_plain_text
# [   43] ✔︎  stage=wrap_plain_text
# [   44] ✔︎  stage=fix_salvage_quotes
# [   45] ✔︎  stage=wrap_plain_text
# [   46] ✔︎  stage=fix_salvage_quotes
# [   47] ✔︎  stage=wrap_plain_text
# [   48] ✔︎  stage=fix_salvage_quotes
# [   49] ✔︎  stage=wrap_plain_text
# [   50] ✔︎  stage=wrap_plain_text
# [   51] ✔︎  stage=wrap_plain_text
# [   52] ✔︎  stage=wrap_plain_text
# [   53] ✔︎  stage=fix_salvage_quotes
# [   54] ✔︎  stage=wrap_plain_text
# [   55] ✔︎  stage=fix_pythonic
# [   56] ✔︎  stage=wrap_plain_text
# [   57] ✔︎  stage=wrap_plain_text
# [   58] ✔︎  stage=wrap_plain_text
# [   59] ✔︎  stage=wrap_plain_text
# [   60] ✔︎  stage=wrap_plain_text
# [   61] ✔︎  stage=wrap_plain_text
# [   62] ✔︎  stage=wrap_plain_text
# [   63] ✔︎  stage=wrap_plain_text
# [   64] ✔︎  stage=wrap_plain_text
# [   65] ✔︎  stage=wrap_plain_text
# [   66] ✔︎  stage=wrap_plain_text
# [   67] ✔︎  stage=wrap_plain_text
# [   68] ✔︎  stage=wrap_plain_text
# [   69] ✔︎  stage=wrap_plain_text
# [   70] ✔︎  stage=wrap_plain_text
# [   71] ✔︎  stage=fix_salvage_quotes
# [   72] ✔︎  stage=wrap_plain_text
# [   73] ✔︎  stage=wrap_plain_text
# [   74] ✔︎  stage=wrap_plain_text
# [   75] ✔︎  stage=fix_salvage_quotes
# [   76] ✔︎  stage=wrap_plain_text
# [   77] ✔︎  stage=wrap_plain_text
# [   78] ✔︎  stage=fix_salvage_quotes
# [   79] ✔︎  stage=wrap_plain_text
# [   80] ✔︎  stage=wrap_plain_text
# [   81] ✔︎  stage=fix_salvage_quotes
# [   82] ✔︎  stage=wrap_plain_text
# [   83] ✔︎  stage=wrap_plain_text
# [   84] ✔︎  stage=wrap_plain_text
# [   85] ✔︎  stage=wrap_plain_text
# [   86] ✔︎  stage=fix_salvage_quotes
# [   87] ✔︎  stage=wrap_plain_text
# [   88] ✔︎  stage=wrap_plain_text
# [   89] ✔︎  stage=fix_salvage_quotes
# [   90] ✔︎  stage=fix_salvage_quotes
# [   91] ✔︎  stage=wrap_plain_text
# [   92] ✔︎  stage=wrap_plain_text
# [   93] ✔︎  stage=fix_pythonic
# [   94] ✔︎  stage=wrap_plain_text
# [   95] ✔︎  stage=wrap_plain_text
# [   96] ✔︎  stage=wrap_plain_text
# [   97] ✔︎  stage=wrap_plain_text
# [   98] ✔︎  stage=wrap_plain_text
# [   99] ✔︎  stage=wrap_plain_text
# [  100] ✔︎  stage=wrap_plain_text
# [  101] ✔︎  stage=fix_salvage_quotes
# [  102] ✔︎  stage=wrap_plain_text
# [  103] ✔︎  stage=wrap_plain_text
# [  104] ✔︎  stage=fix_salvage_quotes
# [  105] ✔︎  stage=wrap_plain_text
# [  106] ✔︎  stage=wrap_plain_text
# [  107] ✔︎  stage=wrap_plain_text
# [  108] ✔︎  stage=wrap_plain_text
# [  109] ✔︎  stage=fix_salvage_quotes
# [  110] ✔︎  stage=wrap_plain_text
# [  111] ✔︎  stage=wrap_plain_text
# [  112] ✔︎  stage=wrap_plain_text
# [  113] ✔︎  stage=wrap_plain_text
# [  114] ✔︎  stage=wrap_plain_text
# [  115] ✔︎  stage=wrap_plain_text
# [  116] ✔︎  stage=fix_salvage_quotes
# [  117] ✔︎  stage=fix_salvage_quotes
# [  118] ✔︎  stage=wrap_plain_text
# [  119] ✔︎  stage=wrap_plain_text
# [  120] ✔︎  stage=fix_salvage_quotes
# [  121] ✔︎  stage=wrap_plain_text
# [  122] ✔︎  stage=fix_pythonic
# [  123] ✔︎  stage=fix_pythonic
# [  124] ✔︎  stage=wrap_plain_text
# [  125] ✔︎  stage=wrap_plain_text
# [  126] ✔︎  stage=wrap_plain_text
# [  127] ✔︎  stage=wrap_plain_text
# [  128] ✔︎  stage=wrap_plain_text
# [  129] ✔︎  stage=wrap_plain_text
# [  130] ✔︎  stage=wrap_plain_text
# [  131] ✔︎  stage=fix_salvage_quotes
# [  132] ✔︎  stage=wrap_plain_text
# [  133] ✔︎  stage=fix_salvage_quotes
# [  134] ✔︎  stage=wrap_plain_text
# [  135] ✔︎  stage=wrap_plain_text
# [  136] ✔︎  stage=wrap_plain_text
# [  137] ✔︎  stage=wrap_plain_text
# [  138] ✔︎  stage=fix_pythonic
# [  139] ✔︎  stage=wrap_plain_text
# [  140] ✔︎  stage=wrap_plain_text
# [  141] ✔︎  stage=wrap_plain_text
# [  142] ✔︎  stage=wrap_plain_text
# [  143] ✔︎  stage=wrap_plain_text
# [  144] ✔︎  stage=wrap_plain_text
# [  145] ✔︎  stage=wrap_plain_text
# [  146] ✔︎  stage=wrap_plain_text
# [  147] ✔︎  stage=wrap_plain_text
# [  148] ✔︎  stage=wrap_plain_text
# [  149] ✔︎  stage=fix_salvage_quotes
# [  150] ✔︎  stage=fix_salvage_quotes
# [  151] ✔︎  stage=wrap_plain_text
# [  152] ✔︎  stage=fix_salvage_quotes
# [  153] ✔︎  stage=fix_salvage_quotes
# [  154] ✔︎  stage=wrap_plain_text
# [  155] ✔︎  stage=wrap_plain_text
# [  156] ✔︎  stage=wrap_plain_text
# [  157] ✔︎  stage=wrap_plain_text
# [  158] ✔︎  stage=wrap_plain_text
# [  159] ✔︎  stage=wrap_plain_text
# [  160] ✔︎  stage=wrap_plain_text
# [  161] ✔︎  stage=wrap_plain_text
# [  162] ✔︎  stage=fix_salvage_quotes
# [  163] ✔︎  stage=fix_salvage_quotes
# [  164] ✔︎  stage=wrap_plain_text
# [  165] ✔︎  stage=wrap_plain_text
# [  166] ✔︎  stage=wrap_plain_text
# [  167] ✔︎  stage=wrap_plain_text
# [  168] ✔︎  stage=wrap_plain_text
# [  169] ✔︎  stage=wrap_plain_text
# [  170] ✔︎  stage=fix_salvage_quotes
# [  171] ✔︎  stage=fix_salvage_quotes
# [  172] ✔︎  stage=wrap_plain_text
# [  173] ✔︎  stage=fix_salvage_quotes
# [  174] ✔︎  stage=wrap_plain_text
# [  175] ✔︎  stage=fix_salvage_quotes
# [  176] ✔︎  stage=wrap_plain_text
# [  177] ✔︎  stage=wrap_plain_text
# [  178] ✔︎  stage=fix_salvage_quotes
# [  179] ✔︎  stage=wrap_plain_text
# [  180] ✔︎  stage=wrap_plain_text
# [  181] ✔︎  stage=wrap_plain_text
# [  182] ✔︎  stage=fix_pythonic
# [  183] ✔︎  stage=wrap_plain_text
# [  184] ✔︎  stage=wrap_plain_text
# [  185] ✔︎  stage=wrap_plain_text
# [  186] ✔︎  stage=wrap_plain_text
# [  187] ✔︎  stage=wrap_plain_text
# [  188] ✔︎  stage=fix_salvage_quotes
# [  189] ✔︎  stage=wrap_plain_text
# [  190] ✔︎  stage=wrap_plain_text
# [  191] ✔︎  stage=wrap_plain_text
# [  192] ✔︎  stage=fix_salvage_quotes
# [  193] ✔︎  stage=wrap_plain_text
# [  194] ✔︎  stage=wrap_plain_text
# [  195] ✔︎  stage=wrap_plain_text
# [  196] ✔︎  stage=wrap_plain_text
# [  197] ✔︎  stage=wrap_plain_text
# [  198] ✔︎  stage=wrap_plain_text
# [  199] ✔︎  stage=wrap_plain_text
# [  200] ✔︎  stage=wrap_plain_text
# [  201] ✔︎  stage=wrap_plain_text
# [  202] ✔︎  stage=wrap_plain_text
# [  203] ✔︎  stage=wrap_plain_text
# [  204] ✔︎  stage=wrap_plain_text
# [  205] ✔︎  stage=wrap_plain_text
# [  206] ✔︎  stage=wrap_plain_text
# [  207] ✔︎  stage=wrap_plain_text
# [  208] ✔︎  stage=fix_salvage_quotes
# [  209] ✔︎  stage=wrap_plain_text
# [  210] ✔︎  stage=wrap_plain_text
# [  211] ✔︎  stage=fix_pythonic
# [  212] ✔︎  stage=wrap_plain_text
# [  213] ✔︎  stage=wrap_plain_text
# [  214] ✔︎  stage=wrap_plain_text
# [  215] ✔︎  stage=fix_salvage_quotes
# [  216] ✔︎  stage=wrap_plain_text
# [  217] ✔︎  stage=wrap_plain_text
# [  218] ✔︎  stage=wrap_plain_text
# [  219] ✔︎  stage=wrap_plain_text
# [  220] ✔︎  stage=fix_salvage_quotes
# [  221] ✔︎  stage=wrap_plain_text
# [  222] ✔︎  stage=wrap_plain_text
# [  223] ✔︎  stage=wrap_plain_text
# [  224] ✔︎  stage=wrap_plain_text
# [  225] ✔︎  stage=fix_salvage_quotes
# [  226] ✔︎  stage=wrap_plain_text
# [  227] ✔︎  stage=wrap_plain_text
# [  228] ✔︎  stage=fix_salvage_quotes
# [  229] ✔︎  stage=fix_salvage_quotes
# [  230] ✔︎  stage=fix_salvage_quotes
# [  231] ✔︎  stage=fix_salvage_quotes
# [  232] ✔︎  stage=fix_salvage_quotes
# [  233] ✔︎  stage=fix_salvage_quotes
# [  234] ✔︎  stage=fix_salvage_quotes
# [  235] ✔︎  stage=wrap_plain_text
# [  236] ✔︎  stage=wrap_plain_text
# [  237] ✔︎  stage=wrap_plain_text
# [  238] ✔︎  stage=wrap_plain_text
# [  239] ✔︎  stage=wrap_plain_text
# [  240] ✔︎  stage=fix_pythonic
# [  241] ✔︎  stage=fix_salvage_quotes
# [  242] ✔︎  stage=wrap_plain_text
# [  243] ✔︎  stage=wrap_plain_text
# [  244] ✔︎  stage=wrap_plain_text
# [  245] ✔︎  stage=fix_pythonic
# [  246] ✔︎  stage=wrap_plain_text
# [  247] ✔︎  stage=wrap_plain_text
# [  248] ✔︎  stage=fix_salvage_quotes
# [  249] ✔︎  stage=wrap_plain_text
# [  250] ✔︎  stage=wrap_plain_text
# [  251] ✔︎  stage=fix_pythonic
# [  252] ✔︎  stage=wrap_plain_text
# [  253] ✔︎  stage=fix_salvage_quotes
# [  254] ✔︎  stage=fix_salvage_quotes
# [  255] ✔︎  stage=wrap_plain_text
# [  256] ✔︎  stage=wrap_plain_text
# [  257] ✔︎  stage=wrap_plain_text
# [  258] ✔︎  stage=wrap_plain_text
# [  259] ✔︎  stage=wrap_plain_text
# [  260] ✔︎  stage=wrap_plain_text
# [  261] ✔︎  stage=wrap_plain_text
# [  262] ✔︎  stage=fix_salvage_quotes
# [  263] ✔︎  stage=wrap_plain_text
# [  264] ✔︎  stage=wrap_plain_text
# [  265] ✔︎  stage=wrap_plain_text
# [  266] ✔︎  stage=fix_salvage_quotes
# [  267] ✔︎  stage=fix_salvage_quotes
# [  268] ✔︎  stage=wrap_plain_text
# [  269] ✔︎  stage=wrap_plain_text
# [  270] ✔︎  stage=wrap_plain_text
# [  271] ✔︎  stage=wrap_plain_text
# [  272] ✔︎  stage=wrap_plain_text
# [  273] ✔︎  stage=wrap_plain_text
# [  274] ✔︎  stage=fix_salvage_quotes
# [  275] ✔︎  stage=wrap_plain_text
# [  276] ✔︎  stage=wrap_plain_text
# [  277] ✔︎  stage=wrap_plain_text
# [  278] ✔︎  stage=wrap_plain_text
# [  279] ✔︎  stage=wrap_plain_text
# [  280] ✔︎  stage=wrap_plain_text
# [  281] ✔︎  stage=wrap_plain_text
# [  282] ✔︎  stage=wrap_plain_text
# [  283] ✔︎  stage=fix_salvage_quotes
# [  284] ✔︎  stage=fix_salvage_quotes
# [  285] ✔︎  stage=wrap_plain_text
# [  286] ✔︎  stage=fix_salvage_quotes
# [  287] ✔︎  stage=fix_salvage_quotes
# [  288] ✔︎  stage=fix_salvage_quotes
# [  289] ✔︎  stage=wrap_plain_text
# [  290] ✔︎  stage=wrap_plain_text
# [  291] ✔︎  stage=wrap_plain_text
# [  292] ✔︎  stage=wrap_plain_text
# [  293] ✔︎  stage=wrap_plain_text
# [  294] ✔︎  stage=wrap_plain_text
# [  295] ✔︎  stage=wrap_plain_text
# [  296] ✔︎  stage=wrap_plain_text
# [  297] ✔︎  stage=wrap_plain_text
# [  298] ✘  skipped (non_string_input)
# [  299] ✔︎  stage=wrap_plain_text
# [  300] ✔︎  stage=wrap_plain_text
# [  301] ✔︎  stage=fix_salvage_quotes
# [  302] ✔︎  stage=wrap_plain_text
# [  303] ✔︎  stage=fix_salvage_quotes
# [  304] ✔︎  stage=fix_salvage_quotes
# [  305] ✔︎  stage=wrap_plain_text
# [  306] ✔︎  stage=wrap_plain_text
# [  307] ✔︎  stage=wrap_plain_text
# [  308] ✔︎  stage=fix_outer_brace
# [  309] ✔︎  stage=wrap_plain_text
# [  310] ✔︎  stage=wrap_plain_text
# [  311] ✔︎  stage=fix_salvage_quotes
# [  312] ✔︎  stage=wrap_plain_text
# [  313] ✔︎  stage=wrap_plain_text
# [  314] ✔︎  stage=wrap_plain_text
# [  315] ✔︎  stage=fix_salvage_quotes
# [  316] ✔︎  stage=fix_salvage_quotes
# [  317] ✔︎  stage=wrap_plain_text
# [  318] ✔︎  stage=wrap_plain_text
# [  319] ✔︎  stage=wrap_plain_text
# [  320] ✔︎  stage=fix_pythonic
# [  321] ✔︎  stage=wrap_plain_text
# [  322] ✔︎  stage=fix_salvage_quotes
# [  323] ✔︎  stage=wrap_plain_text
# [  324] ✔︎  stage=fix_salvage_quotes
# [  325] ✔︎  stage=wrap_plain_text
# [  326] ✔︎  stage=wrap_plain_text
# [  327] ✔︎  stage=wrap_plain_text
# [  328] ✔︎  stage=wrap_plain_text
# [  329] ✔︎  stage=wrap_plain_text
# [  330] ✔︎  stage=wrap_plain_text
# [  331] ✔︎  stage=fix_salvage_quotes
# [  332] ✔︎  stage=wrap_plain_text
# [  333] ✔︎  stage=fix_salvage_quotes
# [  334] ✔︎  stage=wrap_plain_text
# [  335] ✔︎  stage=wrap_plain_text
# [  336] ✔︎  stage=wrap_plain_text
# [  337] ✔︎  stage=wrap_plain_text
# [  338] ✔︎  stage=fix_salvage_quotes
# [  339] ✔︎  stage=wrap_plain_text
# [  340] ✔︎  stage=fix_salvage_quotes
# [  341] ✔︎  stage=wrap_plain_text
# [  342] ✔︎  stage=wrap_plain_text
# [  343] ✔︎  stage=wrap_plain_text
# [  344] ✔︎  stage=wrap_plain_text
# [  345] ✔︎  stage=wrap_plain_text
# [  346] ✔︎  stage=wrap_plain_text
# [  347] ✔︎  stage=wrap_plain_text
# [  348] ✔︎  stage=wrap_plain_text
# [  349] ✔︎  stage=wrap_plain_text
# [  350] ✔︎  stage=wrap_plain_text
# [  351] ✔︎  stage=wrap_plain_text
# [  352] ✔︎  stage=wrap_plain_text
# [  353] ✔︎  stage=fix_salvage_quotes
# [  354] ✔︎  stage=fix_salvage_quotes
# [  355] ✔︎  stage=wrap_plain_text
# [  356] ✔︎  stage=wrap_plain_text
# [  357] ✔︎  stage=fix_salvage_quotes
# [  358] ✔︎  stage=wrap_plain_text
# [  359] ✔︎  stage=wrap_plain_text
# [  360] ✔︎  stage=wrap_plain_text
# [  361] ✔︎  stage=wrap_plain_text
# [  362] ✔︎  stage=wrap_plain_text
# [  363] ✔︎  stage=wrap_plain_text
# [  364] ✔︎  stage=wrap_plain_text
# [  365] ✔︎  stage=fix_pythonic
# [  366] ✔︎  stage=wrap_plain_text
# [  367] ✔︎  stage=wrap_plain_text
# [  368] ✔︎  stage=wrap_plain_text
# [  369] ✔︎  stage=wrap_plain_text
# [  370] ✔︎  stage=fix_salvage_quotes
# [  371] ✔︎  stage=wrap_plain_text
# [  372] ✔︎  stage=wrap_plain_text
# [  373] ✔︎  stage=wrap_plain_text
# [  374] ✔︎  stage=wrap_plain_text
# [  375] ✔︎  stage=wrap_plain_text
# [  376] ✔︎  stage=wrap_plain_text
# [  377] ✔︎  stage=fix_pythonic
# [  378] ✔︎  stage=wrap_plain_text
# [  379] ✔︎  stage=wrap_plain_text
# [  380] ✔︎  stage=wrap_plain_text
# [  381] ✔︎  stage=wrap_plain_text
# [  382] ✔︎  stage=wrap_plain_text
# [  383] ✔︎  stage=wrap_plain_text
# [  384] ✔︎  stage=fix_salvage_quotes
# [  385] ✔︎  stage=wrap_plain_text
# [  386] ✔︎  stage=wrap_plain_text
# [  387] ✔︎  stage=wrap_plain_text
# [  388] ✔︎  stage=wrap_plain_text
# [  389] ✔︎  stage=wrap_plain_text
# [  390] ✔︎  stage=fix_salvage_quotes
# [  391] ✔︎  stage=fix_salvage_quotes
# [  392] ✔︎  stage=wrap_plain_text
# [  393] ✔︎  stage=wrap_plain_text
# [  394] ✔︎  stage=wrap_plain_text
# [  395] ✔︎  stage=wrap_plain_text
# [  396] ✔︎  stage=wrap_plain_text
# [  397] ✔︎  stage=wrap_plain_text
# [  398] ✔︎  stage=wrap_plain_text
# [  399] ✔︎  stage=wrap_plain_text
# [  400] ✔︎  stage=wrap_plain_text
# [  401] ✔︎  stage=fix_pythonic
# [  402] ✔︎  stage=wrap_plain_text
# [  403] ✔︎  stage=fix_salvage_quotes
# [  404] ✔︎  stage=wrap_plain_text
# [  405] ✔︎  stage=fix_salvage_quotes
# [  406] ✔︎  stage=wrap_plain_text
# [  407] ✔︎  stage=wrap_plain_text
# [  408] ✔︎  stage=wrap_plain_text
# [  409] ✔︎  stage=wrap_plain_text
# [  410] ✔︎  stage=wrap_plain_text
# [  411] ✔︎  stage=fix_pythonic
# [  412] ✔︎  stage=fix_salvage_quotes
# [  413] ✔︎  stage=wrap_plain_text
# [  414] ✔︎  stage=wrap_plain_text
# [  415] ✔︎  stage=wrap_plain_text
# [  416] ✔︎  stage=wrap_plain_text
# [  417] ✔︎  stage=wrap_plain_text
# [  418] ✔︎  stage=fix_salvage_quotes
# [  419] ✔︎  stage=wrap_plain_text
# [  420] ✔︎  stage=wrap_plain_text
# [  421] ✔︎  stage=wrap_plain_text
# [  422] ✔︎  stage=wrap_plain_text
# [  423] ✔︎  stage=fix_salvage_quotes
# [  424] ✔︎  stage=wrap_plain_text
# [  425] ✔︎  stage=wrap_plain_text
# [  426] ✔︎  stage=wrap_plain_text
# [  427] ✔︎  stage=wrap_plain_text
# [  428] ✔︎  stage=wrap_plain_text
# [  429] ✔︎  stage=wrap_plain_text
# [  430] ✔︎  stage=wrap_plain_text
# [  431] ✔︎  stage=fix_pythonic
# [  432] ✔︎  stage=wrap_plain_text
# [  433] ✔︎  stage=fix_pythonic
# [  434] ✔︎  stage=wrap_plain_text
# [  435] ✔︎  stage=wrap_plain_text
# [  436] ✔︎  stage=wrap_plain_text
# [  437] ✔︎  stage=fix_salvage_quotes
# [  438] ✔︎  stage=wrap_plain_text
# [  439] ✔︎  stage=fix_salvage_quotes
# [  440] ✔︎  stage=wrap_plain_text
# [  441] ✔︎  stage=wrap_plain_text
# [  442] ✔︎  stage=fix_salvage_quotes
# [  443] ✔︎  stage=wrap_plain_text
# [  444] ✔︎  stage=wrap_plain_text
# [  445] ✔︎  stage=wrap_plain_text
# [  446] ✔︎  stage=fix_salvage_quotes
# [  447] ✔︎  stage=wrap_plain_text
# [  448] ✔︎  stage=wrap_plain_text
# [  449] ✔︎  stage=wrap_plain_text
# [  450] ✔︎  stage=wrap_plain_text
# [  451] ✔︎  stage=fix_salvage_quotes
# [  452] ✔︎  stage=wrap_plain_text
# [  453] ✔︎  stage=fix_salvage_quotes
# [  454] ✔︎  stage=fix_salvage_quotes
# [  455] ✔︎  stage=wrap_plain_text
# [  456] ✔︎  stage=wrap_plain_text
# [  457] ✔︎  stage=fix_salvage_quotes
# [  458] ✔︎  stage=fix_salvage_quotes
# [  459] ✔︎  stage=wrap_plain_text
# [  460] ✔︎  stage=wrap_plain_text
# [  461] ✔︎  stage=wrap_plain_text
# [  462] ✔︎  stage=fix_salvage_quotes
# [  463] ✔︎  stage=wrap_plain_text
# [  464] ✔︎  stage=fix_salvage_quotes
# [  465] ✔︎  stage=wrap_plain_text
# [  466] ✔︎  stage=fix_salvage_quotes
# [  467] ✔︎  stage=fix_salvage_quotes
# [  468] ✔︎  stage=wrap_plain_text
# [  469] ✔︎  stage=fix_salvage_quotes
# [  470] ✔︎  stage=wrap_plain_text
# [  471] ✔︎  stage=wrap_plain_text
# [  472] ✔︎  stage=wrap_plain_text
# [  473] ✔︎  stage=wrap_plain_text
# [  474] ✔︎  stage=wrap_plain_text
# [  475] ✔︎  stage=wrap_plain_text
# [  476] ✔︎  stage=fix_salvage_quotes
# [  477] ✔︎  stage=fix_salvage_quotes
# [  478] ✔︎  stage=wrap_plain_text
# [  479] ✔︎  stage=wrap_plain_text
# [  480] ✔︎  stage=wrap_plain_text
# [  481] ✔︎  stage=fix_salvage_quotes
# [  482] ✔︎  stage=wrap_plain_text
# [  483] ✔︎  stage=wrap_plain_text
# [  484] ✔︎  stage=fix_salvage_quotes
# [  485] ✔︎  stage=wrap_plain_text
# [  486] ✔︎  stage=wrap_plain_text
# [  487] ✔︎  stage=wrap_plain_text
# [  488] ✔︎  stage=fix_salvage_quotes
# [  489] ✔︎  stage=wrap_plain_text
# [  490] ✔︎  stage=fix_salvage_quotes
# [  491] ✔︎  stage=fix_salvage_quotes
# [  492] ✔︎  stage=wrap_plain_text
# [  493] ✔︎  stage=wrap_plain_text
# [  494] ✔︎  stage=wrap_plain_text
# [  495] ✔︎  stage=wrap_plain_text
# [  496] ✔︎  stage=wrap_plain_text
# [  497] ✔︎  stage=wrap_plain_text
# [  498] ✔︎  stage=wrap_plain_text
# [  499] ✔︎  stage=wrap_plain_text
# [  500] ✔︎  stage=fix_salvage_quotes
# [  501] ✔︎  stage=fix_salvage_quotes
# [  502] ✔︎  stage=wrap_plain_text
# [  503] ✔︎  stage=fix_salvage_quotes
# [  504] ✔︎  stage=wrap_plain_text
# [  505] ✔︎  stage=wrap_plain_text
# [  506] ✔︎  stage=fix_salvage_quotes
# [  507] ✔︎  stage=fix_salvage_quotes
# [  508] ✔︎  stage=fix_salvage_quotes
# [  509] ✔︎  stage=wrap_plain_text
# [  510] ✔︎  stage=wrap_plain_text
# [  511] ✔︎  stage=fix_salvage_quotes
# [  512] ✔︎  stage=wrap_plain_text
# [  513] ✔︎  stage=wrap_plain_text
# [  514] ✔︎  stage=wrap_plain_text
# [  515] ✔︎  stage=fix_salvage_quotes
# [  516] ✔︎  stage=wrap_plain_text
# [  517] ✔︎  stage=wrap_plain_text
# [  518] ✔︎  stage=fix_salvage_quotes
# [  519] ✔︎  stage=wrap_plain_text
# [  520] ✔︎  stage=wrap_plain_text
# [  521] ✔︎  stage=wrap_plain_text
# [  522] ✔︎  stage=fix_salvage_quotes
# [  523] ✔︎  stage=wrap_plain_text
# [  524] ✔︎  stage=fix_salvage_quotes
# [  525] ✔︎  stage=wrap_plain_text
# [  526] ✔︎  stage=wrap_plain_text
# [  527] ✔︎  stage=wrap_plain_text
# [  528] ✔︎  stage=wrap_plain_text
# [  529] ✔︎  stage=wrap_plain_text
# [  530] ✔︎  stage=wrap_plain_text
# [  531] ✔︎  stage=wrap_plain_text
# [  532] ✔︎  stage=wrap_plain_text
# [  533] ✔︎  stage=wrap_plain_text
# [  534] ✔︎  stage=wrap_plain_text
# [  535] ✔︎  stage=wrap_plain_text
# [  536] ✔︎  stage=wrap_plain_text
# [  537] ✔︎  stage=wrap_plain_text
# [  538] ✔︎  stage=wrap_plain_text
# [  539] ✔︎  stage=wrap_plain_text
# [  540] ✔︎  stage=wrap_plain_text
# [  541] ✔︎  stage=wrap_plain_text
# [  542] ✔︎  stage=wrap_plain_text
# [  543] ✔︎  stage=wrap_plain_text
# [  544] ✔︎  stage=wrap_plain_text
# [  545] ✔︎  stage=wrap_plain_text
# [  546] ✔︎  stage=wrap_plain_text
# [  547] ✔︎  stage=wrap_plain_text
# [  548] ✔︎  stage=wrap_plain_text
# [  549] ✔︎  stage=wrap_plain_text
# [  550] ✔︎  stage=wrap_plain_text
# [  551] ✔︎  stage=wrap_plain_text
# [  552] ✔︎  stage=wrap_plain_text
# [  553] ✔︎  stage=wrap_plain_text
# [  554] ✔︎  stage=wrap_plain_text
# [  555] ✔︎  stage=wrap_plain_text
# [  556] ✔︎  stage=wrap_plain_text
# [  557] ✔︎  stage=wrap_plain_text
# [  558] ✔︎  stage=wrap_plain_text
# [  559] ✔︎  stage=wrap_plain_text
# [  560] ✔︎  stage=wrap_plain_text
# [  561] ✔︎  stage=wrap_plain_text
# [  562] ✔︎  stage=wrap_plain_text
# [  563] ✔︎  stage=wrap_plain_text
# [  564] ✔︎  stage=wrap_plain_text
# [  565] ✔︎  stage=fix_salvage_quotes
# [  566] ✔︎  stage=wrap_plain_text
# [  567] ✔︎  stage=wrap_plain_text
# [  568] ✔︎  stage=wrap_plain_text
# [  569] ✔︎  stage=wrap_plain_text
# [  570] ✔︎  stage=wrap_plain_text
# [  571] ✔︎  stage=wrap_plain_text
# [  572] ✔︎  stage=wrap_plain_text
# [  573] ✔︎  stage=wrap_plain_text
# [  574] ✔︎  stage=wrap_plain_text
# [  575] ✔︎  stage=fix_pythonic
# [  576] ✔︎  stage=wrap_plain_text
# [  577] ✔︎  stage=wrap_plain_text
# [  578] ✔︎  stage=wrap_plain_text
# [  579] ✔︎  stage=wrap_plain_text
# [  580] ✔︎  stage=wrap_plain_text
# [  581] ✔︎  stage=wrap_plain_text
# [  582] ✔︎  stage=fix_salvage_quotes
# [  583] ✔︎  stage=wrap_plain_text
# [  584] ✔︎  stage=wrap_plain_text
# [  585] ✔︎  stage=wrap_plain_text
# [  586] ✔︎  stage=fix_pythonic
# [  587] ✔︎  stage=wrap_plain_text
# [  588] ✔︎  stage=wrap_plain_text
# [  589] ✔︎  stage=wrap_plain_text
# [  590] ✔︎  stage=fix_salvage_quotes
# [  591] ✔︎  stage=wrap_plain_text
# [  592] ✔︎  stage=wrap_plain_text
# [  593] ✔︎  stage=wrap_plain_text
# [  594] ✔︎  stage=wrap_plain_text
# [  595] ✔︎  stage=wrap_plain_text
# [  596] ✔︎  stage=wrap_plain_text
# [  597] ✔︎  stage=wrap_plain_text
# [  598] ✔︎  stage=wrap_plain_text
# [  599] ✔︎  stage=wrap_plain_text
# [  600] ✔︎  stage=wrap_plain_text
# [  601] ✔︎  stage=wrap_plain_text
# [  602] ✔︎  stage=wrap_plain_text
# [  603] ✔︎  stage=wrap_plain_text
# [  604] ✔︎  stage=wrap_plain_text
# [  605] ✔︎  stage=wrap_plain_text
# [  606] ✔︎  stage=wrap_plain_text
# [  607] ✔︎  stage=fix_salvage_quotes
# [  608] ✔︎  stage=wrap_plain_text
# [  609] ✔︎  stage=wrap_plain_text
# [  610] ✔︎  stage=wrap_plain_text
# [  611] ✔︎  stage=wrap_plain_text
# [  612] ✔︎  stage=fix_salvage_quotes
# [  613] ✔︎  stage=wrap_plain_text
# [  614] ✔︎  stage=wrap_plain_text
# [  615] ✔︎  stage=wrap_plain_text
# [  616] ✔︎  stage=fix_salvage_quotes
# [  617] ✔︎  stage=fix_salvage_quotes
# [  618] ✔︎  stage=wrap_plain_text
# [  619] ✔︎  stage=wrap_plain_text
# [  620] ✔︎  stage=wrap_plain_text
# [  621] ✔︎  stage=wrap_plain_text
# [  622] ✔︎  stage=wrap_plain_text
# [  623] ✔︎  stage=wrap_plain_text
# [  624] ✔︎  stage=wrap_plain_text
# [  625] ✔︎  stage=fix_pythonic
# [  626] ✔︎  stage=wrap_plain_text
# [  627] ✔︎  stage=wrap_plain_text
# [  628] ✔︎  stage=fix_salvage_quotes
# [  629] ✔︎  stage=fix_salvage_quotes
# [  630] ✔︎  stage=wrap_plain_text
# [  631] ✔︎  stage=fix_salvage_quotes
# [  632] ✔︎  stage=wrap_plain_text
# [  633] ✔︎  stage=wrap_plain_text
# [  634] ✔︎  stage=wrap_plain_text
# [  635] ✔︎  stage=fix_salvage_quotes
# [  636] ✔︎  stage=fix_pythonic
# [  637] ✔︎  stage=wrap_plain_text
# [  638] ✔︎  stage=wrap_plain_text
# [  639] ✔︎  stage=wrap_plain_text
# [  640] ✔︎  stage=wrap_plain_text
# [  641] ✔︎  stage=fix_salvage_quotes
# [  642] ✔︎  stage=wrap_plain_text
# [  643] ✔︎  stage=fix_salvage_quotes
# [  644] ✔︎  stage=wrap_plain_text
# [  645] ✔︎  stage=wrap_plain_text
# [  646] ✔︎  stage=wrap_plain_text
# [  647] ✔︎  stage=fix_salvage_quotes
# [  648] ✔︎  stage=wrap_plain_text
# [  649] ✔︎  stage=wrap_plain_text
# [  650] ✔︎  stage=wrap_plain_text
# [  651] ✔︎  stage=fix_salvage_quotes
# [  652] ✔︎  stage=wrap_plain_text
# [  653] ✔︎  stage=wrap_plain_text
# [  654] ✔︎  stage=wrap_plain_text
# [  655] ✔︎  stage=wrap_plain_text
# [  656] ✔︎  stage=wrap_plain_text
# [  657] ✔︎  stage=wrap_plain_text
# [  658] ✔︎  stage=wrap_plain_text
# [  659] ✔︎  stage=wrap_plain_text
# [  660] ✔︎  stage=fix_salvage_quotes
# [  661] ✔︎  stage=wrap_plain_text
# [  662] ✔︎  stage=wrap_plain_text
# [  663] ✔︎  stage=wrap_plain_text
# [  664] ✔︎  stage=wrap_plain_text
# [  665] ✔︎  stage=wrap_plain_text
# [  666] ✔︎  stage=wrap_plain_text
# [  667] ✔︎  stage=fix_salvage_quotes
# [  668] ✔︎  stage=wrap_plain_text
# [  669] ✔︎  stage=fix_salvage_quotes
# [  670] ✔︎  stage=wrap_plain_text
# [  671] ✔︎  stage=wrap_plain_text
# [  672] ✔︎  stage=wrap_plain_text
# [  673] ✔︎  stage=wrap_plain_text
# [  674] ✔︎  stage=wrap_plain_text
# [  675] ✔︎  stage=fix_salvage_quotes
# [  676] ✔︎  stage=wrap_plain_text
# [  677] ✔︎  stage=wrap_plain_text
# [  678] ✔︎  stage=fix_salvage_quotes
# [  679] ✔︎  stage=wrap_plain_text
# [  680] ✔︎  stage=wrap_plain_text
# [  681] ✔︎  stage=wrap_plain_text
# [  682] ✔︎  stage=fix_salvage_quotes
# [  683] ✔︎  stage=wrap_plain_text
# [  684] ✔︎  stage=wrap_plain_text
# [  685] ✔︎  stage=wrap_plain_text
# [  686] ✔︎  stage=wrap_plain_text
# [  687] ✔︎  stage=wrap_plain_text
# [  688] ✔︎  stage=wrap_plain_text
# [  689] ✔︎  stage=fix_salvage_quotes
# [  690] ✔︎  stage=wrap_plain_text
# [  691] ✔︎  stage=wrap_plain_text
# [  692] ✔︎  stage=wrap_plain_text
# [  693] ✔︎  stage=wrap_plain_text
# [  694] ✔︎  stage=wrap_plain_text
# [  695] ✔︎  stage=wrap_plain_text
# [  696] ✔︎  stage=wrap_plain_text
# [  697] ✔︎  stage=wrap_plain_text
# [  698] ✔︎  stage=fix_salvage_quotes
# [  699] ✔︎  stage=wrap_plain_text
# [  700] ✔︎  stage=fix_salvage_quotes
# [  701] ✔︎  stage=wrap_plain_text
# [  702] ✔︎  stage=wrap_plain_text
# [  703] ✔︎  stage=wrap_plain_text
# [  704] ✔︎  stage=fix_salvage_quotes
# [  705] ✔︎  stage=fix_salvage_quotes
# [  706] ✔︎  stage=fix_salvage_quotes
# [  707] ✔︎  stage=wrap_plain_text
# [  708] ✔︎  stage=wrap_plain_text
# [  709] ✔︎  stage=wrap_plain_text
# [  710] ✔︎  stage=wrap_plain_text
# [  711] ✔︎  stage=wrap_plain_text
# [  712] ✔︎  stage=fix_salvage_quotes
# [  713] ✔︎  stage=wrap_plain_text
# [  714] ✔︎  stage=wrap_plain_text
# [  715] ✔︎  stage=wrap_plain_text
# [  716] ✔︎  stage=fix_salvage_quotes
# [  717] ✔︎  stage=wrap_plain_text
# [  718] ✔︎  stage=wrap_plain_text
# [  719] ✔︎  stage=wrap_plain_text
# [  720] ✔︎  stage=wrap_plain_text
# [  721] ✔︎  stage=wrap_plain_text
# [  722] ✔︎  stage=fix_salvage_quotes
# [  723] ✔︎  stage=wrap_plain_text
# [  724] ✔︎  stage=fix_salvage_quotes
# [  725] ✔︎  stage=wrap_plain_text
# [  726] ✔︎  stage=wrap_plain_text
# [  727] ✔︎  stage=wrap_plain_text
# [  728] ✔︎  stage=wrap_plain_text
# [  729] ✔︎  stage=wrap_plain_text
# [  730] ✔︎  stage=wrap_plain_text
# [  731] ✔︎  stage=wrap_plain_text
# [  732] ✔︎  stage=wrap_plain_text
# [  733] ✔︎  stage=wrap_plain_text
# [  734] ✔︎  stage=wrap_plain_text
# [  735] ✔︎  stage=wrap_plain_text
# [  736] ✔︎  stage=wrap_plain_text
# [  737] ✔︎  stage=fix_pythonic
# [  738] ✔︎  stage=wrap_plain_text
# [  739] ✔︎  stage=wrap_plain_text
# [  740] ✔︎  stage=wrap_plain_text
# [  741] ✔︎  stage=fix_salvage_quotes
# [  742] ✔︎  stage=wrap_plain_text
# [  743] ✔︎  stage=wrap_plain_text
# [  744] ✔︎  stage=fix_pythonic
# [  745] ✔︎  stage=wrap_plain_text
# [  746] ✔︎  stage=fix_salvage_quotes
# [  747] ✔︎  stage=wrap_plain_text
# [  748] ✔︎  stage=wrap_plain_text
# [  749] ✔︎  stage=wrap_plain_text
# [  750] ✔︎  stage=wrap_plain_text
# [  751] ✔︎  stage=fix_salvage_quotes
# [  752] ✔︎  stage=wrap_plain_text
# [  753] ✔︎  stage=fix_pythonic
# [  754] ✔︎  stage=wrap_plain_text
# [  755] ✔︎  stage=wrap_plain_text
# [  756] ✔︎  stage=wrap_plain_text
# [  757] ✔︎  stage=fix_salvage_quotes
# [  758] ✔︎  stage=wrap_plain_text
# [  759] ✔︎  stage=fix_salvage_quotes
# [  760] ✔︎  stage=wrap_plain_text
# [  761] ✔︎  stage=wrap_plain_text
# [  762] ✔︎  stage=wrap_plain_text
# [  763] ✔︎  stage=fix_salvage_quotes
# [  764] ✔︎  stage=fix_salvage_quotes
# [  765] ✔︎  stage=fix_salvage_quotes
# [  766] ✔︎  stage=wrap_plain_text
# [  767] ✔︎  stage=fix_salvage_quotes
# [  768] ✔︎  stage=wrap_plain_text
# [  769] ✔︎  stage=fix_salvage_quotes
# [  770] ✔︎  stage=wrap_plain_text
# [  771] ✔︎  stage=fix_pythonic
# [  772] ✔︎  stage=fix_salvage_quotes
# [  773] ✔︎  stage=wrap_plain_text
# [  774] ✔︎  stage=wrap_plain_text
# [  775] ✔︎  stage=wrap_plain_text
# [  776] ✔︎  stage=wrap_plain_text
# [  777] ✔︎  stage=wrap_plain_text
# [  778] ✔︎  stage=fix_salvage_quotes
# [  779] ✔︎  stage=wrap_plain_text
# [  780] ✔︎  stage=wrap_plain_text
# [  781] ✔︎  stage=wrap_plain_text
# [  782] ✔︎  stage=fix_pythonic
# [  783] ✔︎  stage=wrap_plain_text
# [  784] ✔︎  stage=wrap_plain_text
# [  785] ✔︎  stage=wrap_plain_text
# [  786] ✔︎  stage=wrap_plain_text
# [  787] ✔︎  stage=wrap_plain_text
# [  788] ✔︎  stage=fix_salvage_quotes
# [  789] ✔︎  stage=wrap_plain_text
# [  790] ✔︎  stage=wrap_plain_text
# [  791] ✔︎  stage=wrap_plain_text
# [  792] ✔︎  stage=wrap_plain_text
# [  793] ✔︎  stage=fix_salvage_quotes
# [  794] ✔︎  stage=wrap_plain_text
# [  795] ✔︎  stage=wrap_plain_text
# [  796] ✔︎  stage=wrap_plain_text
# [  797] ✔︎  stage=wrap_plain_text
# [  798] ✔︎  stage=fix_salvage_quotes
# [  799] ✔︎  stage=wrap_plain_text
# [  800] ✔︎  stage=wrap_plain_text
# [  801] ✔︎  stage=fix_salvage_quotes
# [  802] ✔︎  stage=wrap_plain_text
# [  803] ✔︎  stage=fix_pythonic
# [  804] ✔︎  stage=wrap_plain_text
# [  805] ✔︎  stage=fix_salvage_quotes
# [  806] ✔︎  stage=fix_salvage_quotes
# [  807] ✔︎  stage=wrap_plain_text
# [  808] ✔︎  stage=fix_salvage_quotes
# [  809] ✔︎  stage=wrap_plain_text
# [  810] ✔︎  stage=fix_salvage_quotes
# [  811] ✔︎  stage=wrap_plain_text
# [  812] ✔︎  stage=wrap_plain_text
# [  813] ✔︎  stage=wrap_plain_text
# [  814] ✔︎  stage=wrap_plain_text
# [  815] ✔︎  stage=fix_salvage_quotes
# [  816] ✔︎  stage=fix_salvage_quotes
# [  817] ✔︎  stage=wrap_plain_text
# [  818] ✔︎  stage=wrap_plain_text
# [  819] ✔︎  stage=wrap_plain_text
# [  820] ✔︎  stage=wrap_plain_text
# [  821] ✔︎  stage=wrap_plain_text
# [  822] ✘  skipped (non_string_input)
# [  823] ✔︎  stage=fix_salvage_quotes
# [  824] ✔︎  stage=wrap_plain_text
# [  825] ✔︎  stage=wrap_plain_text
# [  826] ✔︎  stage=wrap_plain_text
# [  827] ✔︎  stage=wrap_plain_text
# [  828] ✔︎  stage=wrap_plain_text
# [  829] ✔︎  stage=wrap_plain_text
# [  830] ✔︎  stage=wrap_plain_text
# [  831] ✔︎  stage=wrap_plain_text
# [  832] ✔︎  stage=wrap_plain_text
# [  833] ✔︎  stage=fix_salvage_quotes
# [  834] ✔︎  stage=wrap_plain_text
# [  835] ✔︎  stage=wrap_plain_text
# [  836] ✔︎  stage=fix_salvage_quotes
# [  837] ✔︎  stage=fix_pythonic
# [  838] ✔︎  stage=wrap_plain_text
# [  839] ✔︎  stage=wrap_plain_text
# [  840] ✔︎  stage=wrap_plain_text
# [  841] ✔︎  stage=wrap_plain_text
# [  842] ✔︎  stage=wrap_plain_text
# [  843] ✔︎  stage=fix_salvage_quotes
# [  844] ✔︎  stage=wrap_plain_text
# [  845] ✔︎  stage=wrap_plain_text
# [  846] ✔︎  stage=wrap_plain_text
# [  847] ✔︎  stage=wrap_plain_text
# [  848] ✔︎  stage=wrap_plain_text
# [  849] ✔︎  stage=wrap_plain_text
# [  850] ✔︎  stage=wrap_plain_text
# [  851] ✔︎  stage=wrap_plain_text
# [  852] ✔︎  stage=wrap_plain_text
# [  853] ✔︎  stage=fix_salvage_quotes
# [  854] ✔︎  stage=wrap_plain_text
# [  855] ✔︎  stage=wrap_plain_text
# [  856] ✔︎  stage=wrap_plain_text
# [  857] ✔︎  stage=wrap_plain_text
# [  858] ✔︎  stage=fix_salvage_quotes
# [  859] ✔︎  stage=wrap_plain_text
# [  860] ✔︎  stage=fix_salvage_quotes
# [  861] ✔︎  stage=wrap_plain_text
# [  862] ✔︎  stage=wrap_plain_text
# [  863] ✔︎  stage=wrap_plain_text
# [  864] ✔︎  stage=wrap_plain_text
# [  865] ✔︎  stage=wrap_plain_text
# [  866] ✔︎  stage=wrap_plain_text
# [  867] ✔︎  stage=wrap_plain_text
# [  868] ✔︎  stage=wrap_plain_text
# [  869] ✔︎  stage=fix_salvage_quotes
# [  870] ✔︎  stage=wrap_plain_text
# [  871] ✔︎  stage=fix_salvage_quotes
# [  872] ✔︎  stage=wrap_plain_text
# [  873] ✔︎  stage=fix_pythonic
# [  874] ✔︎  stage=fix_salvage_quotes
# [  875] ✔︎  stage=wrap_plain_text
# [  876] ✔︎  stage=fix_pythonic
# [  877] ✔︎  stage=wrap_plain_text
# [  878] ✔︎  stage=wrap_plain_text
# [  879] ✔︎  stage=wrap_plain_text
# [  880] ✔︎  stage=wrap_plain_text
# [  881] ✔︎  stage=wrap_plain_text
# [  882] ✔︎  stage=fix_salvage_quotes
# [  883] ✔︎  stage=wrap_plain_text
# [  884] ✔︎  stage=wrap_plain_text
# [  885] ✔︎  stage=wrap_plain_text
# [  886] ✔︎  stage=wrap_plain_text
# [  887] ✔︎  stage=wrap_plain_text
# [  888] ✔︎  stage=fix_salvage_quotes
# [  889] ✔︎  stage=fix_salvage_quotes
# [  890] ✔︎  stage=wrap_plain_text
# [  891] ✔︎  stage=fix_salvage_quotes
# [  892] ✔︎  stage=wrap_plain_text
# [  893] ✔︎  stage=wrap_plain_text
# [  894] ✔︎  stage=wrap_plain_text
# [  895] ✔︎  stage=fix_salvage_quotes
# [  896] ✔︎  stage=wrap_plain_text
# [  897] ✔︎  stage=wrap_plain_text
# [  898] ✔︎  stage=wrap_plain_text
# [  899] ✔︎  stage=wrap_plain_text
# [  900] ✔︎  stage=wrap_plain_text
# [  901] ✔︎  stage=wrap_plain_text
# [  902] ✔︎  stage=wrap_plain_text
# [  903] ✔︎  stage=wrap_plain_text
# [  904] ✔︎  stage=wrap_plain_text
# [  905] ✔︎  stage=wrap_plain_text
# [  906] ✔︎  stage=wrap_plain_text
# [  907] ✔︎  stage=fix_salvage_quotes
# [  908] ✔︎  stage=wrap_plain_text
# [  909] ✔︎  stage=wrap_plain_text
# [  910] ✔︎  stage=fix_salvage_quotes
# [  911] ✔︎  stage=wrap_plain_text
# [  912] ✔︎  stage=fix_salvage_quotes
# [  913] ✔︎  stage=fix_pythonic
# [  914] ✔︎  stage=wrap_plain_text
# [  915] ✔︎  stage=wrap_plain_text
# [  916] ✔︎  stage=wrap_plain_text
# [  917] ✔︎  stage=wrap_plain_text
# [  918] ✔︎  stage=wrap_plain_text
# [  919] ✔︎  stage=wrap_plain_text
# [  920] ✔︎  stage=wrap_plain_text
# [  921] ✔︎  stage=wrap_plain_text
# [  922] ✔︎  stage=wrap_plain_text
# [  923] ✔︎  stage=wrap_plain_text
# [  924] ✔︎  stage=wrap_plain_text
# [  925] ✔︎  stage=fix_pythonic
# [  926] ✔︎  stage=wrap_plain_text
# [  927] ✔︎  stage=fix_salvage_quotes
# [  928] ✔︎  stage=fix_salvage_quotes
# [  929] ✔︎  stage=wrap_plain_text
# [  930] ✔︎  stage=wrap_plain_text
# [  931] ✔︎  stage=wrap_plain_text
# [  932] ✔︎  stage=wrap_plain_text
# [  933] ✔︎  stage=wrap_plain_text
# [  934] ✔︎  stage=wrap_plain_text
# [  935] ✔︎  stage=wrap_plain_text
# [  936] ✔︎  stage=wrap_plain_text
# [  937] ✔︎  stage=wrap_plain_text
# [  938] ✔︎  stage=wrap_plain_text
# [  939] ✔︎  stage=wrap_plain_text
# [  940] ✔︎  stage=wrap_plain_text
# [  941] ✔︎  stage=wrap_plain_text
# [  942] ✔︎  stage=wrap_plain_text
# [  943] ✔︎  stage=wrap_plain_text
# [  944] ✔︎  stage=wrap_plain_text
# [  945] ✔︎  stage=fix_salvage_quotes
# [  946] ✔︎  stage=wrap_plain_text
# [  947] ✔︎  stage=wrap_plain_text
# [  948] ✔︎  stage=wrap_plain_text
# [  949] ✔︎  stage=wrap_plain_text
# [  950] ✔︎  stage=wrap_plain_text
# [  951] ✔︎  stage=wrap_plain_text
# [  952] ✔︎  stage=wrap_plain_text
# [  953] ✔︎  stage=wrap_plain_text
# [  954] ✔︎  stage=wrap_plain_text
# [  955] ✔︎  stage=wrap_plain_text
# [  956] ✔︎  stage=fix_salvage_quotes
# [  957] ✔︎  stage=wrap_plain_text
# [  958] ✔︎  stage=fix_salvage_quotes
# [  959] ✔︎  stage=fix_salvage_quotes
# [  960] ✔︎  stage=wrap_plain_text
# [  961] ✔︎  stage=wrap_plain_text
# [  962] ✔︎  stage=fix_salvage_quotes
# [  963] ✔︎  stage=fix_salvage_quotes
# [  964] ✔︎  stage=wrap_plain_text
# [  965] ✔︎  stage=wrap_plain_text
# [  966] ✔︎  stage=wrap_plain_text
# [  967] ✔︎  stage=wrap_plain_text
# [  968] ✔︎  stage=wrap_plain_text
# [  969] ✔︎  stage=wrap_plain_text
# [  970] ✔︎  stage=wrap_plain_text
# [  971] ✔︎  stage=wrap_plain_text
# [  972] ✔︎  stage=fix_salvage_quotes
# [  973] ✔︎  stage=wrap_plain_text
# [  974] ✔︎  stage=wrap_plain_text
# [  975] ✔︎  stage=wrap_plain_text
# [  976] ✔︎  stage=wrap_plain_text
# [  977] ✔︎  stage=wrap_plain_text
# [  978] ✔︎  stage=wrap_plain_text
# [  979] ✔︎  stage=wrap_plain_text
# [  980] ✔︎  stage=wrap_plain_text
# [  981] ✔︎  stage=wrap_plain_text
# [  982] ✔︎  stage=wrap_plain_text
# [  983] ✔︎  stage=wrap_plain_text
# [  984] ✔︎  stage=fix_salvage_quotes
# [  985] ✔︎  stage=wrap_plain_text
# [  986] ✔︎  stage=wrap_plain_text
# [  987] ✔︎  stage=wrap_plain_text
# [  988] ✔︎  stage=wrap_plain_text
# [  989] ✔︎  stage=wrap_plain_text
# [  990] ✔︎  stage=wrap_plain_text
# [  991] ✔︎  stage=wrap_plain_text
# [  992] ✔︎  stage=wrap_plain_text
# [  993] ✔︎  stage=wrap_plain_text
# [  994] ✔︎  stage=wrap_plain_text
# [  995] ✔︎  stage=wrap_plain_text
# [  996] ✔︎  stage=wrap_plain_text
# [  997] ✔︎  stage=wrap_plain_text
# [  998] ✔︎  stage=wrap_plain_text
# [  999] ✔︎  stage=wrap_plain_text
#
# ␡  Skipped 2 non-string row(s). [298, 822]

# %%
failed_df.iloc[[298, 822]]
# Out:
#              doc_id                   orig_doc_id corpus   author texttype  \
# 298  alienus_text_2  known [Alienus - Text-2].txt   Wiki  Alienus    known
# 822  alienus_text_2  known [Alienus - Text-2].txt   Wiki  Alienus    known
#
#                                                   text  \
# 298  Sadly, in addition to your constant edit-warri...
# 822  Sadly, in addition to your constant edit-warri...
#
#                                         generated_text   time_sec  \
# 298  {'version': 2, 'new_title': '', 'new_author': ...  13.782775
# 822  {'language_code': 'en', 'original_text': 'Sadl...  18.445308
#
#      tokens_per_sec
# 298      113.112200
# 822       93.411287

# %%
read_jsonl(f"{data_base_loc}/full_doc_paraphrase_clean/alienus_text_2.jsonl")
# Out:
#              doc_id                   orig_doc_id corpus   author texttype  \
# 0    amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 1    amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 2    amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 3    amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 4    amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# ..              ...                           ...    ...      ...      ...
# 995  amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 996  amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 997  amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 998  amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
# 999  amorrow_text_3  known [Amorrow - Text-3].txt   Wiki  Amorrow    known
#
#                                               original  \
# 0    It may be that in some cases, the creative pro...
# 1    It may be that in some cases, the creative pro...
# 2    It may be that in some cases, the creative pro...
# 3    It may be that in some cases, the creative pro...
# 4    It may be that in some cases, the creative pro...
# ..                                                 ...
# 995  It may be that in some cases, the creative pro...
# 996  It may be that in some cases, the creative pro...
# 997  It may be that in some cases, the creative pro...
# 998  It may be that in some cases, the creative pro...
# 999  It may be that in some cases, the creative pro...
#
#                                         generated_text   time_sec  \
# 0    {"new_document": "There could potentially be i...   8.985760
# 1    {"new_document": "In certain instances, it cou...  12.024543
# 2    {\n  "new_document": "There might be instances...   8.248974
# 3    {"new_document": "Perhaps in certain instances...   8.044627
# 4    {"new_document": "In certain instances, it mig...   7.581503
# ..                                                 ...        ...
# 995  {"new_document": "In certain instances, it mig...  11.701552
# 996  {"new_document": "In certain instances, it mig...  11.709669
# 997  {"new_document": "In certain instances, the cr...   8.163703
# 998  Here's a highly paraphrased version of the pro...   8.018374
# 999  {"new_document": "In certain instances, it cou...  10.835579
#
#      tokens_per_sec                                          rephrased  \
# 0        120.190173  There could potentially be instances where the...
# 1         99.213751  In certain instances, it could be that our und...
# 2        128.985744  There might be instances where the creative pr...
# 3        131.392046  Perhaps in certain instances, the creative pro...
# 4        137.307859  In certain instances, it might be that the cre...
# ..              ...                                                ...
# 995      101.952288  In certain instances, it might be possible tha...
# 996      101.881616  In certain instances, it might be the case tha...
# 997      130.945477  In certain instances, the creative process mig...
# 998      132.570524  Here's a highly paraphrased version of the pro...
# 999      107.239311  In certain instances, it could be that our kno...
#
#      text_cleaned         clean_stage  \
# 0               1        fix_pythonic
# 1               1  fix_salvage_quotes
# 2               1        fix_pythonic
# 3               1  fix_salvage_quotes
# 4               1        fix_pythonic
# ..            ...                 ...
# 995             1  fix_salvage_quotes
# 996             1  fix_salvage_quotes
# 997             1        fix_pythonic
# 998             1     wrap_plain_text
# 999             1        fix_pythonic
#
#                                         parsing_errors  parascore_free
# 0    [original: Expecting ',' delimiter: line 3 col...        0.733986
# 1    [original: Expecting ',' delimiter: line 3 col...        0.739425
# 2    [original: Expecting ',' delimiter: line 4 col...        0.758149
# 3    [original: Expecting ',' delimiter: line 3 col...        0.705020
# 4    [original: Expecting ',' delimiter: line 3 col...        0.751076
# ..                                                 ...             ...
# 995  [original: Expecting ',' delimiter: line 3 col...        0.720895
# 996  [original: Expecting ',' delimiter: line 3 col...        0.737539
# 997  [original: Expecting ',' delimiter: line 3 col...        0.737201
# 998  [original: Expecting value: line 1 column 1 (c...        0.734868
# 999  [original: Expecting ',' delimiter: line 3 col...        0.732796
#
# [1000 rows x 14 columns]
